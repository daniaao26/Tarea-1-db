# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Daniela Aguilar - 202111060-7
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: six in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: prettytable in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: ipython-genutils in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: colorama in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: exceptiongroup in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (1.2.1)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: stack-data in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: decorator in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: wcwidth in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: pure-eval in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: psycopg2 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (2.9.4)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB
# Out:
# env: DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tareaDB',
   password="Quintero"
)
print(conn)
# Out:
# <connection object at 0x000002192D42ABD0; dsn: 'user=postgres password=xxx dbname=tareaDB host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE Director(
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
#
# CREATE TABLE Actor(
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
#
# CREATE TABLE Pelicula(
#     id_pelicula INT GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula, id_director),
#     FOREIGN KEY (id_director) REFERENCES Director(id_director),
#     UNIQUE(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula(
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_director(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES Director(id_director)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_actor(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_actor) REFERENCES Actor(id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_pelicula(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula(id_pelicula)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1965, 'director': 17, 'genero': 'Documental', 'cast': [73], 'mejor pelicula': 'no'}, 2: {'año': 1971, 'director': 38, 'genero': 'Animación', 'cast': [154, 141], 'mejor pelicula': 'no'}, 3: {'año': 1964, 'director': 196, 'genero': 'Western', 'cast': [198, 168, 96, 82], 'mejor pelicula': 'no'}, 4: {'año': 1998, 'director': 22, 'genero': 'Romance', 'cast': [79, 14], 'mejor pelicula': 'no'}, 5: {'año': 1976, 'director': 125, 'genero': 'Acción', 'cast': [29], 'mejor pelicula': 'no'}, 6: {'año': 2010, 'director': 8, 'genero': 'Documental', 'cast': [83], 'mejor pelicula': 'no'}, 7: {'año': 1998, 'director': 170, 'genero': 'Suspense', 'cast': [128], 'mejor pelicula': 'no'}, 8: {'año': 2006, 'director': 127, 'genero': 'Terror', 'cast': [74, 173, 109], 'mejor pelicula': 'no'}, 9: {'año': 1976, 'director': 63, 'genero': 'Aventura', 'cast': [163, 107], 'mejor pelicula': 'no'}, 10: {'año': 1983, 'director': 133, 'genero': 'Fantasía', 'cast': [60, 116], 'mejor pelicula': 'no'}, 11: {'año': 1992, 'director': 41, 'genero': 'Musical', 'cast': [27, 74], 'mejor pelicula': 'no'}, 12: {'año': 2009, 'director': 113, 'genero': 'Romance', 'cast': [149], 'mejor pelicula': 'no'}, 13: {'año': 2023, 'director': 47, 'genero': 'Acción', 'cast': [24, 162], 'mejor pelicula': 'no'}, 14: {'año': 1982, 'director': 159, 'genero': 'Musical', 'cast': [161, 118, 14], 'mejor pelicula': 'no'}, 15: {'año': 1963, 'director': 52, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 16: {'año': 1968, 'director': 47, 'genero': 'Documental', 'cast': [61, 179, 168], 'mejor pelicula': 'no'}, 17: {'año': 2015, 'director': 133, 'genero': 'Animación', 'cast': [], 'mejor pelicula': 'no'}, 18: {'año': 1967, 'director': 33, 'genero': 'Documental', 'cast': [96], 'mejor pelicula': 'no'}, 19: {'año': 1968, 'director': 50, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 20: {'año': 2010, 'director': 133, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 21: {'año': 1987, 'director': 117, 'genero': 'Drama', 'cast': [79], 'mejor pelicula': 'no'}, 22: {'año': 1967, 'director': 5, 'genero': 'Misterio', 'cast': [99], 'mejor pelicula': 'no'}, 23: {'año': 2009, 'director': 59, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 24: {'año': 2015, 'director': 50, 'genero': 'Ciencia ficción', 'cast': [125], 'mejor pelicula': 'no'}, 25: {'año': 1963, 'director': 116, 'genero': 'Comedia', 'cast': [36, 27, 88], 'mejor pelicula': 'no'}, 26: {'año': 2023, 'director': 8, 'genero': 'Comedia', 'cast': [57, 188, 99], 'mejor pelicula': 'no'}, 27: {'año': 2008, 'director': 97, 'genero': 'Drama', 'cast': [26, 16], 'mejor pelicula': 'no'}, 28: {'año': 1963, 'director': 157, 'genero': 'Misterio', 'cast': [53, 160], 'mejor pelicula': 'no'}, 29: {'año': 2003, 'director': 97, 'genero': 'Western', 'cast': [70, 167, 137, 110], 'mejor pelicula': 'no'}, 30: {'año': 2003, 'director': 115, 'genero': 'Aventura', 'cast': [133], 'mejor pelicula': 'no'}, 31: {'año': 2015, 'director': 192, 'genero': 'Documental', 'cast': [98], 'mejor pelicula': 'no'}, 32: {'año': 1972, 'director': 29, 'genero': 'Misterio', 'cast': [49, 134], 'mejor pelicula': 'no'}, 33: {'año': 1984, 'director': 192, 'genero': 'Acción', 'cast': [130, 200, 163], 'mejor pelicula': 'no'}, 34: {'año': 1970, 'director': 145, 'genero': 'Fantasía', 'cast': [193, 34], 'mejor pelicula': 'no'}, 35: {'año': 2019, 'director': 30, 'genero': 'Ciencia ficción', 'cast': [118, 72], 'mejor pelicula': 'no'}, 36: {'año': 1960, 'director': 109, 'genero': 'Terror', 'cast': [79], 'mejor pelicula': 'no'}, 37: {'año': 2014, 'director': 108, 'genero': 'Documental', 'cast': [7, 166, 104], 'mejor pelicula': 'no'}, 38: {'año': 1960, 'director': 166, 'genero': 'Ciencia ficción', 'cast': [43, 77, 181], 'mejor pelicula': 'no'}, 39: {'año': 1997, 'director': 124, 'genero': 'Drama', 'cast': [173, 35, 107, 7], 'mejor pelicula': 'no'}, 40: {'año': 1979, 'director': 54, 'genero': 'Drama', 'cast': [163, 72, 194], 'mejor pelicula': 'no'}, 41: {'año': 198 ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nombre as "Nombre"
# FROM
#     Pelicula
# WHERE
#     extract(Year from fecha_publicacion) >= 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 7 rows affected.
# [('La doncella de la mariposa',),
#  ('El canto de sirena de la guerra',),
#  ('La odisea de la caza',),
#  ('El bosque encantado de el faro',),
#  ('El tesoro de el mar',),
#  ('El último viaje de el hechicero',),
#  ('La estrella fugaz de la desgracia',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     nombre as "Nombre", fecha_publicacion as "Fecha de publicación"
# FROM
#     pelicula
# WHERE
#     genero = 'Drama' and extract(year from fecha_publicacion) = 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 1 rows affected.
# [('El tesoro de el mar', datetime.date(2023, 3, 6))]

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre as "Nombre"
# FROM
#     pelicula INNER JOIN actor_participa_en_pelicula
# ON
#     pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# WHERE
#     genero = 'Comedia'
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 36 rows affected.
# [('Kamala Hidalgo',),
#  ('Katarina Henriquez',),
#  ('Nadia Petrov',),
#  ('Genghis Qian',),
#  ('Genghis Nogueira',),
#  ('Natalia Esteves',),
#  ('Fabiana Xu',),
#  ('Khaled Velez',),
#  ('Lakshmi Figueiredo',),
#  ('Khaled Velez',),
#  ('Yuri Estevez',),
#  ('Fatemeh Yan',),
#  ('Sakura Santana',),
#  ('Irina Montenegro',),
#  ('Tatiana Gomes',),
#  ('Chiyoko Diniz',),
#  ('Alessandro Goncalves',),
#  ('Wilhelmina Jimenez',),
#  ('Beatriz Mendes',),
#  ('Yusef Lima',),
#  ('Quintus Duarte',),
#  ('Xin Etxebarria',),
#  ('Beatriz Mendes',),
#  ('Tatjana Inácio',),
#  ('Theresa Wu',),
#  ('Darya Borges',),
#  ('Nadia Petrov',),
#  ('Yuri Wu',),
#  ('Nina Diniz',),
#  ('Rania Vieira',),
#  ('Jin Abadi',),
#  ('Theresa Wu',),
#  ('Qiu Duarte',),
#  ('Beatriz Mendes',),
#  ('Han Santos',),
#  ('Dmitri Vargas',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.genero as "Género",COUNT(pelicula.genero) AS "Cantidad de premios"
# FROM
#     pelicula INNER JOIN premio_mejor_pelicula ON pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# GROUP BY
#     pelicula.genero
# ORDER BY
#     COUNT(pelicula.genero) DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 13 rows affected.
# [('Fantasía', 4),
#  ('Acción', 3),
#  ('Musical', 3),
#  ('Comedia', 3),
#  ('Misterio', 3),
#  ('Ciencia ficción', 2),
#  ('Animación', 2),
#  ('Aventura', 2),
#  ('Romance', 1),
#  ('Terror', 1),
#  ('Documental', 1),
#  ('Suspense', 1),
#  ('Western', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre", COUNT(premio_mejor_actor.id_actor) as "Cantidad de Premios Mejor Actor"
# FROM
#     pelicula
# INNER JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN
#     premio_mejor_actor ON actor_participa_en_pelicula.id_actor = premio_mejor_actor.id_actor
# GROUP BY
#     pelicula.nombre
# HAVING
#     COUNT(premio_mejor_actor.id_actor) >= 2
# ORDER BY
#     COUNT(premio_mejor_actor.id_actor) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 14 rows affected.
# [('El amanecer de el río', 3),
#  ('El canto de sirena de la guerra', 3),
#  ('La búsqueda del tesoro de la corona', 3),
#  ('El misterio de la tierra', 2),
#  ('La venganza de la leyenda', 2),
#  ('La doncella de la mariposa', 2),
#  ('La batalla de la bestia', 2),
#  ('El vuelo mágico de el peligro', 2),
#  ('La fuga de el cielo', 2),
#  ('El descubrimiento de el camino', 2),
#  ('El refugio de el mago', 2),
#  ('El castillo de la paz', 2),
#  ('La llegada de la flor', 2),
#  ('El pacto de la misión', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre",MIN(actor.edad) as "Edad del actor más joven",MAX(actor.edad) as "Edad del actor más viejo"
# FROM pelicula
# INNER JOIN actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# GROUP BY pelicula.nombre
# ORDER BY MAX(actor.edad) - MIN(actor.edad) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 1 rows affected.
# [('La historia de la verdad', 15, 68)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# (psycopg2.ProgrammingError) can't execute an empty query
# [SQL: /* Reemplace estas queries por las que resuelven las consultas pedidas. */]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre as "Nombre del actor",
#     COUNT(director.id_director) as "Cantidad de directores",
#     pelicula.nombre as "Nombre de una pelicula"
# FROM
#     actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# GROUP BY
#     actor.nombre, pelicula.nombre
# HAVING
#     COUNT(director.id_director) >= 2
# ORDER BY
#     COUNT(director.id_director) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 498 rows affected.
# [('Fadhila Correia', 1, 'La búsqueda de la senda'),
#  ('Theresa Urbina', 1, 'El secreto oscuro de la prisión'),
#  ('Oscar Lopez', 1, 'El misterio de la leyenda'),
#  ('Oscar Lopez', 1, 'La invasión de la huida'),
#  ('Natalia Vargas', 1, 'La doncella de la mariposa'),
#  ('Yasmin Rodriguez', 1, 'El tesoro de el mar'),
#  ('Ilya Yamamoto', 1, 'La metamorfosis de la profecía'),
#  ('Mina Teixeira', 1, 'La redención de el tesoro'),
#  ('Orhan Tan', 1, 'La fuente de el vuelo'),
#  ('Dmitri Vargas', 1, 'El bosque encantado de el faro'),
#  ('Wan Gao', 1, 'La tormenta de la criatura'),
#  ('Yuri Wu', 1, 'El arco iris de el río'),
#  ('Hiroko Lima', 1, 'La venganza de la leyenda'),
#  ('Mehmet Esteves', 1, 'El tesoro escondido de la caverna'),
#  ('Salim Carvalho', 1, 'La venganza de la leyenda'),
#  ('Wilhelmina Duarte', 1, 'La danza de la fortuna'),
#  ('Theresa Wu', 1, 'La llave de el puente'),
#  ('Dmitri Almeida', 1, 'El pacto de la sirena'),
#  ('Chiyoko Goncalves', 1, 'La leyenda perdida de la tormenta'),
#  ('Abdullah Petrov', 1, 'El último viaje de la luz'),
#  ('Chen Borges', 1, 'La venganza de la caverna'),
#  ('Fadhila Iglesias', 1, 'La resurrección de la batalla'),
#  ('Fatemeh Cruz', 1, 'La fuga de la bruma'),
#  ('Genghis Qian', 1, 'La venganza de la guerra'),
#  ('Bianca Cruz', 1, 'El bosque encantado de el faro'),
#  ('Valentina Goncalves', 1, 'La búsqueda del tesoro de la heroína'),
#  ('Salim Sousa', 1, 'El camino hacia la pesadilla'),
#  ('Rania Hidalgo', 1, 'La rebelión de la heroína'),
#  ('Katarina Cruz', 1, 'La búsqueda del tesoro de la verdad'),
#  ('Theresa Urbina', 1, 'El hechizo de la criatura'),
#  ('Qiu Duarte', 1, 'El eclipse de la nube'),
#  ('Qiu Nguyen', 1, 'La llegada de la academia'),
#  ('Quintus Correia', 1, 'La leyenda perdida de la heroína'),
#  ('Nina Velez', 1, 'La travesía del océano de la batalla'),
#  ('Wilhelmina Jimenez', 1, 'La travesura de la sirena'),
#  ('Fatemeh Yan', 1, 'El laberinto de la muralla'),
#  ('Patricia Borges', 1, 'El castillo de el viaje'),
#  ('Genghis Qian', 1, 'El espejismo de la nube'),
#  ('Xin Etxebarria', 1, 'La historia de la verdad'),
#  ('Wan Xu', 1, 'El misterio de la leyenda'),
#  ('Natalia Esteves', 1, 'El eclipse de la nube'),
#  ('Zoya Rodriguez', 1, 'El espejismo de la escuela'),
#  ('Wan Santos', 1, 'La leyenda perdida de el valle'),
#  ('Yuri Wu', 1, 'La búsqueda del tesoro de el ángel'),
#  ('Umberto Zhang', 1, 'La fuga de el cielo'),
#  ('Zara Ueno', 1, 'La venganza de la leyenda'),
#  ('Leonardo Rodriguez', 1, 'La danza macabra de el renacimiento'),
#  ('Bianca Cruz', 1, 'La travesía sin retorno de la pesadilla'),
#  ('Qiu Cruz', 1, 'La odisea de la caza'),
#  ('Umberto Olivares', 1, 'La escalada de la reina'),
#  ('Alessandro Goncalves', 1, 'El vuelo mágico de la senda'),
#  ('Fatemeh Pereira', 1, 'La estrella fugaz de la paz'),
#  ('Natalia Barros', 1, 'El vuelo de el destino'),
#  ('Leticia Vieira', 1, 'El resurgimiento de la corrupción'),
#  ('Alessandro Kumar', 1, 'La travesía sin retorno de la estrella fugaz'),
#  ('Leonardo Rocha', 1, 'El viaje de la batalla'),
#  ('Yusef Abadi', 1, 'La travesía sin retorno de la estrella fugaz'),
#  ('Dmitri Vargas', 1, 'El amanecer de el río'),
#  ('Darya Rocha', 1, 'La redención de la trampa'),
#  ('Emiko Hernandez', 1, 'La conquista de el árbol'),
#  ('Zoya Iglesias', 1, 'El ritual de la ciudad'),
#  ('Salim Sousa', 1, 'La venganza de la oscuridad'),
#  ('Leticia Vargas', 1, 'La travesía sin retorno de el puente'),
#  ('Nadia Petrov', 1, 'La batalla de la bestia'),
#  ('Genghis Nogueira', 1, 'La batalla de la batalla'),
#  ('Pilar Xia', 1, 'El bosque encantado de el laberinto'),
#  ('Salim Carvalho', 1, 'El resurgimiento de la aventura'),
#  ('Salim Sousa', 1, 'La llegada de la luz'),
#  ('Parvati Barros', 1, 'La danza macabra de la leyenda'),
#  ('Irina Goncalves', 1, 'El resurgimiento de la corrupción'),
#  ('Omar Duarte', 1, 'La travesura de el perdón'),
#  ('Fatemeh Yan', 1, 'El refugio de la luna'),
#  ('Dmitri Vargas', 1, 'La travesía de la expedición'),
#  ('Fadhila Henriquez', 1, 'El caballero de la espada mágica'),
#  ('Yusef Lima', 1, 'El tesoro de la traición'),
#  ('Wilhelmina Urbina', 1, 'El ritual de la misión'),
#  ('Emiko Henriquez', 1, 'El destino de la princesa'),
#  ('Aarav Mendes', 1, 'El despertar de el destino'),
#  ('Aarav Rocha', 1, 'La llegada de la flor'),
#  ('Theresa Figueiredo', 1, 'El vuelo mágico de la senda'),
#  ('Chen Borges', 1, 'El castillo de el viaje'),
#  ('Chiyoko Goncalves', 1, 'La travesía del océano de la batalla'),
#  ('Chen Quintana', 1, 'El espejismo de la escuela'),
#  ('Emiko Urbina', 1, 'La leyenda perdida de la tormenta'),
#  ('Yuri Kawaguchi', 1, 'Las aventuras de el guardián'),
#  ('Alessandro Goncalves', 1, 'El tesoro de la traición'),
#  ('Chiyoko Joaquim', 1, 'Las aventuras de el guardián'),
#  ('Fabiana Xu', 1, 'El arco iris de el río'),
#  ('Fatemeh Zhang', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Leticia Vieira', 1, 'La estrella fugaz de la paz'),
#  ('Akira Qian', 1, 'El enigma de el laberinto'),
#  ('Yusef Lima', 1, 'El canto de sirena de la guerra'),
#  ('Umberto Olivares', 1, 'El refugio de la luna'),
#  ('Leonardo Rodriguez', 1, 'El resurgimiento de la corrupción'),
#  ('Leticia Vargas', 1, 'La resurrección de la ley'),
#  ('Rania Kumar', 1, 'El pacto de la sirena'),
#  ('Aarav Mendes', 1, 'El pacto de el mito'),
#  ('Quintus Dutta', 1, 'La búsqueda de el sueño'),
#  ('Fadhila Ortega', 1, 'La tormenta de la criatura'),
#  ('Rania Vieira', 1, 'El espejismo de la nube'),
#  ('Katarina Cruz', 1, 'El vuelo de la muralla'),
#  ('Han Santos', 1, 'El canto de sirena de la estrella fugaz'),
#  ('Ursula Petrov', 1, 'El caballero de el viaje'),
#  ('Bianca Etxebarria', 1, 'La rebelión de el amor'),
#  ('Nadia Petrov', 1, 'El amanecer de el río'),
#  ('Patricia Esteves', 1, 'El amanecer de el sueño'),
#  ('Yuri Zhang', 1, 'La búsqueda del tesoro de la heroína'),
#  ('Fatemeh Yan', 1, 'La invasión de la selva'),
#  ('Qiu Barros', 1, 'La travesura de la sirena'),
#  ('Rania Ferreira', 1, 'El canto de sirena de el monstruo'),
#  ('Alessandro Lima', 1, 'La maldición del vampiro de la fortuna'),
#  ('Aarav Rocha', 1, 'El secreto oscuro de la prisión'),
#  ('Elif Gomes', 1, 'El descubrimiento de el camino'),
#  ('Hiroko Lima', 1, 'El pacto de la misión'),
#  ('Salim Sousa', 1, 'El laberinto de la traición'),
#  ('Bianca Etxebarria', 1, 'El enigma de el valle'),
#  ('Alessandro Goncalves', 1, 'El príncipe de la escuela'),
#  ('Nadia Petrov', 1, 'La redención de la fuga'),
#  ('Tatjana Xu', 1, 'El tesoro de el mar'),
#  ('Fadhila Xia', 1, 'La maldición de el sueño'),
#  ('Xin Etxebarria', 1, 'La danza de la fortuna'),
#  ('Umar Quintana', 1, 'El regreso de la trampa'),
#  ('Katarina Cruz', 1, 'El canto de sirena de la estrella fugaz'),
#  ('Leticia Vargas', 1, 'La llave de la huida'),
#  ('Alessandro Nguyen', 1, 'La travesía sin retorno de la prisión'),
#  ('Alessandro Nguyen', 1, 'La venganza de la leyenda'),
#  ('Mina Teixeira', 1, 'La búsqueda del tesoro de la esperanza'),
#  ('Yusef Inácio', 1, 'La travesía sin retorno de la ola'),
#  ('Xin Etxebarria', 1, 'La resurrección de el laberinto'),
#  ('Genghis Nogueira', 1, 'El espejismo de la caída'),
#  ('Rania Hidalgo', 1, 'La leyenda de la pesadilla'),
#  ('Ursula Petrov', 1, 'La búsqueda del tesoro de la verdad'),
#  ('Zafar Esteves', 1, 'El tesoro escondido de la fortuna'),
#  ('Wan Santos', 1, 'La misión de el adiós'),
#  ('Salim Sousa', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Zoya Rodriguez', 1, 'El vuelo mágico de el misterio'),
#  ('Hiroko Gao', 1, 'La rebelión de el puente'),
#  ('Tatjana Inácio', 1, 'La escalada de la revelación'),
#  ('Fadhila Kumar', 1, 'La fuga de el renacimiento'),
#  ('Lakshmi Montenegro', 1, 'El vuelo mágico de la senda'),
#  ('Tatiana Wu', 1, 'La profecía de la traición'),
#  ('Hiroko Gao', 1, 'La escalada de la revelación'),
#  ('Umar Quintana', 1, 'El pacto de la magia'),
#  ('Darya Borges', 1, 'El misterio de la tierra'),
#  ('Chiyoko Figueiredo', 1, 'El vuelo mágico de la senda'),
#  ('Parvati Barros', 1, 'La búsqueda del tesoro de el laberinto'),
#  ('Yasmin Ortega', 1, 'La rebelión de la sombra'),
#  ('Hiroko Lima', 1, 'La odisea de la oscuridad'),
#  ('Theresa Nunes', 1, 'La odisea de la despedida'),
#  ('Umberto Zhang', 1, 'El amanecer de el río'),
#  ('Leticia Vargas', 1, 'La búsqueda de el viaje'),
#  ('Darius Duarte', 1, 'La metamorfosis de el mar'),
#  ('Katarina Vieira', 1, 'La sombra de la tormenta'),
#  ('Yusef Lima', 1, 'La travesía del océano de la batalla'),
#  ('Tatjana Ferreira', 1, 'El lamento de la luz'),
#  ('Wang Urbina', 1, 'El castillo de la paz'),
#  ('Fadhila Henriquez', 1, 'La leyenda perdida de el valle'),
#  ('Bianca Cruz', 1, 'La búsqueda del tesoro de la esperanza'),
#  ('Bianca Etxebarria', 1, 'El misterio de la leyenda'),
#  ('Alessandro Nguyen', 1, 'El tesoro de el puente'),
#  ('Emiko Nogueira', 1, 'El príncipe de la guerra'),
#  ('Fadhila Correia', 1, 'La travesía sin retorno de la estrella fugaz'),
#  ('Sakura Nguyen', 1, 'La doncella de la mariposa'),
#  ('Quintus Dutta', 1, 'La conquista de la batalla'),
#  ('Fadhila Kumar', 1, 'La venganza de la leyenda'),
#  ('Xin Petrov', 1, 'El tesoro de la traición'),
#  ('Emiko Urbina', 1, 'La redención de la magia'),
#  ('Genghis Rocha', 1, 'El destino de la princesa'),
#  ('Tatjana Xu', 1, 'La sombra de la tormenta'),
#  ('Chen Pacheco', 1, 'El enigma de el valle'),
#  ('Orhan Tan', 1, 'El pacto de la magia'),
#  ('Zoya Bianchi', 1, 'El grito de el renacer'),
#  ('Hanako Quintana', 1, 'El vuelo mágico de el misterio'),
#  ('Alessandro Goncalves', 1, 'El espejismo de la nube'),
#  ('Wilhelmina Duarte', 1, 'La estrella fugaz de la desgracia'),
#  ('Chen Borges', 1, 'La historia de la fortuna'),
#  ('Orhan Tan', 1, 'La misión de el adiós'),
#  ('Valentina Olivares', 1, 'El despertar de la tormenta'),
#  ('Yuri Zhang', 1, 'La leyenda de el dragón'),
#  ('Darya Rocha', 1, 'El resurgimiento de la aventura'),
#  ('Fadhila Iglesias', 1, 'El arco iris de la muralla'),
#  ('Sakura Santana', 1, 'La fuente de la pesadilla'),
#  ('Chiyoko Uchoa', 1, 'El ritual de la oscuridad'),
#  ('Parvati Nunes', 1, 'El renacimiento de el amanecer'),
#  ('Jin Abadi', 1, 'El enigma de la misión'),
#  ('Yusef Barros', 1, 'La estrella fugaz de la corrupción'),
#  ('Chidike Xu', 1, 'El pacto de la magia'),
#  ('Zoya Rodriguez', 1, 'La leyenda de la criatura'),
#  ('Fabiana Xu', 1, 'La maldición de el secreto'),
#  ('Dmitri Vargas', 1, 'La rebelión de el amor'),
#  ('Genghis Nogueira', 1, 'La canción de la expedición'),
#  ('Zoya Bianchi', 1, 'El vuelo mágico de la senda'),
#  ('Dmitri Almeida', 1, 'La rebelión de la heroína'),
#  ('Jin Abadi', 1, 'La resurrección de el laberinto'),
#  ('Quentin Kumar', 1, 'La metamorfosis de la profecía'),
#  ('Wang Fernandes', 1, 'El príncipe de la guerra'),
#  ('Katarina Vieira', 1, 'La fuga de el cielo'),
#  ('Ilya Urbina', 1, 'El resurgimiento de la aventura'),
#  ('Sakura Santana', 1, 'El descubrimiento de el camino'),
#  ('Han Santos', 1, 'El amanecer de el sueño'),
#  ('Ursula Petrov', 1, 'La resurrección de la batalla'),
#  ('Javier Carvalho', 1, 'El viajero de la sonrisa'),
#  ('Chen Correia', 1, 'El bosque encantado de el faro'),
#  ('Tatiana Quintana', 1, 'La resurrección de el destino'),
#  ('Zoya Iglesias', 1, 'El pacto de la bailarina'),
#  ('Chiyoko Figueiredo', 1, 'La cripta de la selva'),
#  ('Rania Ferreira', 1, 'El despertar de la tormenta'),
#  ('Wan Gao', 1, 'La batalla de el puente'),
#  ('Fatemeh Yan', 1, 'La leyenda de la prisión'),
#  ('Fadhila Iglesias', 1, 'La batalla de el puente'),
#  ('Darya Rocha', 1, 'La fuga de la montaña'),
#  ('Beatriz Mendes', 1, 'El enigma de el laberinto'),
#  ('Fadhila Xia', 1, 'El lamento de el tesoro'),
#  ('Jasmin Rodriguez', 1, 'La trampa de el castillo'),
#  ('Rania Vieira', 1, 'La batalla de la paz'),
#  ('Irina Goncalves', 1, 'La travesía del océano de la senda'),
#  ('Han Santos', 1, 'El viaje de la bailarina'),
#  ('Wan Santos', 1, 'La resurrección de el laberinto'),
#  ('Yuri Estevez', 1, 'La rebelión de el amor'),
#  ('Alessandro Nguyen', 1, 'La doncella de la profecía'),
#  ('Salim Carvalho', 1, 'El amanecer de el río'),
#  ('Darya Borges', 1, 'La profecía de el adiós'),
#  ('Fadhila Xia', 1, 'La resurrección de la ley'),
#  ('Leticia Vargas', 1, 'La leyenda de el dragón'),
#  ('Beatriz Sousa', 1, 'El misterio de la traición'),
#  ('Parvati Barros', 1, 'La metamorfosis de la oscuridad'),
#  ('Natalia Vargas', 1, 'La batalla de el puente'),
#  ('Fabiana Hidalgo', 1, 'La búsqueda del tesoro de el laberinto'),
#  ('Zafar Kawaguchi', 1, 'El príncipe de la guerra'),
#  ('Rania Vieira', 1, 'La danza macabra de el renacimiento'),
#  ('Xavier Lopes', 1, 'La búsqueda del tesoro de la heroína'),
#  ('Jasmin Rodriguez', 1, 'El secreto oscuro de el camino'),
#  ('Chen Borges', 1, 'La metamorfosis de la oscuridad'),
#  ('Wan Xu', 1, 'El regreso de el océano'),
#  ('Katarina Cruz', 1, 'El grito de el rey'),
#  ('Hanako Quintana', 1, 'El vuelo de la muralla'),
#  ('Aarav Petrov', 1, 'El castillo de el árbol'),
#  ('Wilhelmina Urbina', 1, 'El castillo de el viaje'),
#  ('Umberto Gomes', 1, 'El último viaje de el hechicero'),
#  ('Leticia Vargas', 1, 'La venganza de la oscuridad'),
#  ('Qiu Barros', 1, 'La odisea de la despedida'),
#  ('Theresa Rodriguez', 1, 'La profecía de la luz'),
#  ('Quintus Duarte', 1, 'El vuelo mágico de el sueño'),
#  ('Quintus Duarte', 1, 'El canto de sirena de la guerra'),
#  ('Xavier Lopes', 1, 'El secreto oscuro de el destino'),
#  ('Tatjana Inácio', 1, 'El hechizo de la academia'),
#  ('Ilya Urbina', 1, 'La historia de la verdad'),
#  ('Quintus Duarte', 1, 'El caballero de la espada mágica'),
#  ('Wang Urbina', 1, 'La canción de el hechicero'),
#  ('Wan Gao', 1, 'El guardián de la traición'),
#  ('Chiyoko Santana', 1, 'El refugio de la luna'),
#  ('Darya Borges', 1, 'La búsqueda del tesoro de la corona'),
#  ('Zafar Kawaguchi', 1, 'La rebelión de la despedida'),
#  ('Chiyoko Figueiredo', 1, 'La estirpe de la sombra'),
#  ('Patricia Borges', 1, 'El caballero de la espada mágica'),
#  ('Fadhila Iglesias', 1, 'El tesoro escondido de la fortuna'),
#  ('Wan Santos', 1, 'El secreto oscuro de la prisión'),
#  ('Fadhila Correia', 1, 'La travesura de el pacto'),
#  ('Chiyoko Diniz', 1, 'El ritual de la misión'),
#  ('Omar Esteves', 1, 'El vuelo de la muralla'),
#  ('Hiroko Gao', 1, 'La danza macabra de la leyenda'),
#  ('Zoya Iglesias', 1, 'La travesura de la sirena'),
#  ('Fatemeh Yan', 1, 'El amanecer de el sueño'),
#  ('Chen Correia', 1, 'El vuelo mágico de el sueño'),
#  ('Rania Ferreira', 1, 'La fuga de el renacimiento'),
#  ('Ilya Ueno', 1, 'La trampa de el lobo'),
#  ('Yuri Kawaguchi', 1, 'El hechizo de la criatura'),
#  ('Oscar Iglesias', 1, 'El secreto de la tormenta'),
#  ('Umar Quintana', 1, 'La travesía del océano de la senda'),
#  ('Alessandro Nguyen', 1, 'La búsqueda de el río'),
#  ('Patricia Borges', 1, 'El ritual de la cascada'),
#  ('Tatjana Inácio', 1, 'El espejismo de la nube'),
#  ('Sakura Nguyen', 1, 'El arco iris de el sueño'),
#  ('Pilar Xia', 1, 'La búsqueda del tesoro de la verdad'),
#  ('Omar Esteves', 1, 'La historia de la verdad'),
#  ('Alessandro Lima', 1, 'La rebelión de la despedida'),
#  ('Elif Gomes', 1, 'El refugio de el mago'),
#  ('Wang Urbina', 1, 'La doncella de el fuego'),
#  ('Umar Quintana', 1, 'La sombra de la tormenta'),
#  ('Nina Diniz', 1, 'El cuento de hadas de el puente'),
#  ('Nadia Teixeira', 1, 'La travesura de el perdón'),
#  ('Aarav Petrov', 1, 'La fuga de el cielo'),
#  ('Chiyoko Diniz', 1, 'La fuente de la pesadilla'),
#  ('Lakshmi Figueiredo', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Xin Petrov', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Mikhail Ferreira', 1, 'La maldición de la paz'),
#  ('Chen Borges', 1, 'La senda de la profecía'),
#  ('Darius Ueno', 1, 'El secreto de la tormenta'),
#  ('Yusef Qian', 1, 'La danza macabra de el renacimiento'),
#  ('Theresa Henriquez', 1, 'La senda de el tesoro'),
#  ('Emiko Hernandez', 1, 'El pacto de la bailarina'),
#  ('Omar Duarte', 1, 'El espejismo de la fuga'),
#  ('Nadia Petrov', 1, 'El canto de sirena de la guerra'),
#  ('Nina Velez', 1, 'El pacto de la senda'),
#  ('Javier Esteves', 1, 'El secreto de la gruta'),
#  ('Leonardo Rocha', 1, 'La metamorfosis de la cascada'),
#  ('Emiko Hernandez', 1, 'La rebelión de el puente'),
#  ('Tatjana Xu', 1, 'La doncella de el fuego'),
#  ('Omar Esteves', 1, 'La maldición de la paz'),
#  ('Patricia Borges', 1, 'El lamento de el tesoro'),
#  ('Katarina Urbina', 1, 'El viaje de la batalla'),
#  ('Natalia Esteves', 1, 'El pacto de la isla'),
#  ('Mikhail Ferreira', 1, 'El secreto de la gruta'),
#  ('Leticia Vieira', 1, 'La fortuna de el explorador'),
#  ('Kamala Gao', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Chen Quintana', 1, 'La leyenda de el dragón'),
#  ('Fadhila Henriquez', 1, 'La danza de el sueño'),
#  ('Xin Etxebarria', 1, 'El arco iris de el río'),
#  ('Dmitri Zapata', 1, 'El secreto oscuro de la isla'),
#  ('Yasmin Rodriguez', 1, 'El grito de el rey'),
#  ('Hiroko Lima', 1, 'La redención de la trampa'),
#  ('Pilar Xia', 1, 'El arco iris de el sueño'),
#  ('Chen Borges', 1, 'El espejismo de el puente'),
#  ('Leonardo Martinez', 1, 'La búsqueda de el sueño'),
#  ('Sakura Santana', 1, 'El refugio de la batalla'),
#  ('Yuri Estevez', 1, 'La búsqueda de la criatura'),
#  ('Quintus Dutta', 1, 'El castillo de el ángel'),
#  ('Qiu Duarte', 1, 'El caballero de la espada mágica'),
#  ('Katarina Correia', 1, 'El resurgimiento de el destino'),
#  ('Mikhail Ferreira', 1, 'El lamento de la batalla'),
#  ('Irina Montenegro', 1, 'La venganza de la oscuridad'),
#  ('Kamala Hidalgo', 1, 'La fuente de el vuelo'),
#  ('Beatriz Sousa', 1, 'La trampa de el lobo'),
#  ('Nadia Petrov', 1, 'La búsqueda del tesoro de la corona'),
#  ('Tatjana Ferreira', 1, 'La tormenta de la caza'),
#  ('Khaled Velez', 1, 'El camino hacia el amanecer'),
#  ('Javier Esteves', 1, 'La misión de el adiós'),
#  ('Quentin Kumar', 1, 'El refugio de la batalla'),
#  ('Javier Carvalho', 1, 'El castillo de el árbol'),
#  ('Elif Gomes', 1, 'El tesoro escondido de el volcán'),
#  ('Javier Carvalho', 1, 'El castillo de el ángel'),
#  ('Leonardo Rocha', 1, 'El descubrimiento de el camino'),
#  ('Khaled Iglesias', 1, 'La tormenta de el viajero'),
#  ('Parvati Barros', 1, 'El secreto oscuro de la prisión'),
#  ('Aarav Mendes', 1, 'La maldición de la paz'),
#  ('Tatiana Quintana', 1, 'La estrella fugaz de la paz'),
#  ('Fadhila Xia', 1, 'El hechizo de la criatura'),
#  ('Leonardo Rodriguez', 1, 'El último viaje de la luz'),
#  ('Nadia Petrov', 1, 'El enigma de el misterio'),
#  ('Irina Goncalves', 1, 'El castillo de la paz'),
#  ('Wang Lopez', 1, 'La llave de la fortuna'),
#  ('Aarav Petrov', 1, 'El secreto de la tormenta'),
#  ('Yuri Estevez', 1, 'El resurgimiento de la oscuridad'),
#  ('Wilhelmina Urbina', 1, 'La invasión de el laberinto'),
#  ('Yusef Inácio', 1, 'El lamento de el tesoro'),
#  ('Orhan Tan', 1, 'El prisionero de la prisión'),
#  ('Quintus Duarte', 1, 'La danza macabra de la espada mágica'),
#  ('Zafar Kawaguchi', 1, 'La danza macabra de el renacimiento'),
#  ('Genghis Nogueira', 1, 'El secreto oscuro de la isla'),
#  ('Darya Borges', 1, 'La venganza de la travesía'),
#  ('Qiu Goncalves', 1, 'El guardián de el ángel'),
#  ('Umberto Zhang', 1, 'La búsqueda del tesoro de la estrella'),
#  ('Wan Pereira', 1, 'El secreto oscuro de la isla'),
#  ('Patricia Queiroz', 1, 'El espejismo de la estrella'),
#  ('Tatiana Gomes', 1, 'La metamorfosis de la bruja'),
#  ('Dmitri Almeida', 1, 'La danza macabra de la leyenda'),
#  ('Beatriz Mendes', 1, 'El arco iris de el río'),
#  ('Leonardo Rocha', 1, 'La rebelión de el bosque'),
#  ('Xavier Lopes', 1, 'El despertar de el destino'),
#  ('Yasmin Ortega', 1, 'La fortuna de la expedición'),
#  ('Umberto Gomes', 1, 'La venganza de la oscuridad'),
#  ('Yasmin Ortega', 1, 'La estrella fugaz de la flor'),
#  ('Wan Xu', 1, 'La profecía de el adiós'),
#  ('Patricia Queiroz', 1, 'La sombra de la maraña'),
#  ('Chiyoko Diniz', 1, 'La estrella fugaz de la expedición'),
#  ('Yasmin Rodriguez', 1, 'El ritual de la aventura'),
#  ('Fatemeh Pereira', 1, 'La maldición de el guardián'),
#  ('Katarina Correia', 1, 'La escalada de la revelación'),
#  ('Alessandro Nguyen', 1, 'La leyenda de el castillo'),
#  ('Kamala Hidalgo', 1, 'El canto de sirena de el monstruo'),
#  ('Emiko Nogueira', 1, 'El canto de sirena de el amor'),
#  ('Alessandro Goncalves', 1, 'La fuga de el monstruo'),
#  ('Oscar Carvalho', 1, 'El secreto oscuro de la isla'),
#  ('Yusef Qian', 1, 'La fuga de el cielo'),
#  ('Chen Borges', 1, 'El secreto oscuro de la isla'),
#  ('Dmitri Almeida', 1, 'La llegada de la flor'),
#  ('Natalia Vargas', 1, 'El destino de la princesa'),
#  ('Wilhelmina Duarte', 1, 'La canción de el hechicero'),
#  ('Umberto Zhang', 1, 'La conquista de la batalla'),
#  ('Wilhelmina Urbina', 1, 'El secreto de la gruta'),
#  ('Emiko Nogueira', 1, 'La fuente de el renacer'),
#  ('Ursula Petrov', 1, 'La rebelión de la sombra'),
#  ('Chiyoko Santana', 1, 'El guardián de el viaje'),
#  ('Fadhila Henriquez', 1, 'La odisea de el guardián'),
#  ('Patricia Queiroz', 1, 'La doncella de la profecía'),
#  ('Kamala Hidalgo', 1, 'El resurgimiento de la aventura'),
#  ('Jin Rocha', 1, 'El pacto de el mito'),
#  ('Yusef Abadi', 1, 'El cuento de hadas de el puente'),
#  ('Gustavo Queiroz', 1, 'El pacto de la sirena'),
#  ('Leonardo Rodriguez', 1, 'La búsqueda de la senda'),
#  ('Tatiana Wu', 1, 'El pacto de la isla'),
#  ('Oscar Iglesias', 1, 'El regreso de el océano'),
#  ('Ilya Urbina', 1, 'El misterio de la leyenda'),
#  ('Chiyoko Diniz', 1, 'El príncipe de la escuela'),
#  ('Yasmin Rodriguez', 1, 'La historia de la fortuna'),
#  ('Abdullah Petrov', 1, 'La travesía sin retorno de la bailarina'),
#  ('Darya Bianchi', 1, 'El enigma de el misterio'),
#  ('Quintus Dutta', 1, 'La danza macabra de la espada mágica'),
#  ('Aarav Sousa', 1, 'La estirpe de la sombra'),
#  ('Leticia Vieira', 1, 'La metamorfosis de la amistad'),
#  ('Theresa Figueiredo', 1, 'La danza macabra de el viajero'),
#  ('Sakura Nguyen', 1, 'La maldición de el sueño'),
#  ('Mikhail Goncalves', 1, 'La estrella fugaz de la desgracia'),
#  ('Ursula Esteves', 1, 'La metamorfosis de la bruja'),
#  ('Chen Correia', 1, 'La metamorfosis de la cascada'),
#  ('Fadhila Xia', 1, 'La fuente de la alianza'),
#  ('Katarina Vieira', 1, 'La invasión de la huida'),
#  ('Tatiana Wu', 1, 'La travesía sin retorno de la estrella fugaz'),
#  ('Bianca Etxebarria', 1, 'El príncipe de el mago'),
#  ('Han Santos', 1, 'La odisea de la oscuridad'),
#  ('Chen Quintana', 1, 'La estirpe de la sombra'),
#  ('Nina Diniz', 1, 'El vuelo mágico de el peligro'),
#  ('Umar Quintana', 1, 'La búsqueda del tesoro de la esperanza'),
#  ('Fadhila Ortega', 1, 'El tesoro escondido de la caverna'),
#  ('Javier Esteves', 1, 'El secreto de la tormenta'),
#  ('Wang Fernandes', 1, 'El arco iris de el sueño'),
#  ('Khaled Velez', 1, 'La travesía de la expedición'),
#  ('Yasmin Rodriguez', 1, 'La rebelión de el puente'),
#  ('Sakura Santana', 1, 'El arco iris de el río'),
#  ('Katarina Henriquez', 1, 'El eclipse de la nube'),
#  ('Ursula Petrov', 1, 'La batalla de la desgracia'),
#  ('Theresa Figueiredo', 1, 'El último viaje de el hechicero'),
#  ('Dmitri Zapata', 1, 'El lamento de el tesoro'),
#  ('Omar Esteves', 1, 'El regreso de el océano'),
#  ('Theresa Wu', 1, 'La canción de la expedición'),
#  ('Qiu Duarte', 1, 'El lamento de la batalla'),
#  ('Chiyoko Diniz', 1, 'La llave de el puente'),
#  ('Kamala Hidalgo', 1, 'El vuelo mágico de el peligro'),
#  ('Wang Urbina', 1, 'El regreso de la trampa'),
#  ('Yusef Inácio', 1, 'La escalada de el monstruo'),
#  ('Alessandro Nguyen', 1, 'El refugio de la luna'),
#  ('Zoya Bianchi', 1, 'La rebelión de la heroína'),
#  ('Darya Borges', 1, 'La trampa de el castillo'),
#  ('Lakshmi Figueiredo', 1, 'La travesía de la expedición'),
#  ('Orhan Tan', 1, 'La danza de el sueño'),
#  ('Wilhelmina Jimenez', 1, 'La canción de la expedición'),
#  ('Aarav Mendes', 1, 'El vuelo mágico de el misterio'),
#  ('Chen Quintana', 1, 'La maldición de el secreto'),
#  ('Pilar Xia', 1, 'La rebelión de el secreto'),
#  ('Beatriz Mendes', 1, 'El espejismo de la nube'),
#  ('Natalia Esteves', 1, 'El espejismo de la caída'),
#  ('Tatiana Gomes', 1, 'La búsqueda del tesoro de la corona'),
#  ('Natalia Lopez', 1, 'La resurrección de la batalla'),
#  ('Katarina Urbina', 1, 'La estrella fugaz de la desgracia'),
#  ('Quentin Kumar', 1, 'La escalada de la reina'),
#  ('Natalia Lopez', 1, 'El hechizo de el trono'),
#  ('Fadhila Kumar', 1, 'La batalla de el puente'),
#  ('Aarav Rocha', 1, 'La travesía del océano de la luz'),
#  ('Katarina Correia', 1, 'La danza de el viaje'),
#  ('Omar Esteves', 1, 'La invasión de el sueño'),
#  ('Omar Duarte', 1, 'La estrella fugaz de la traición'),
#  ('Patricia Borges', 1, 'La canción de la tormenta'),
#  ('Nina Hidalgo', 1, 'El ritual de la aventura'),
#  ('Jin Rocha', 1, 'La travesía sin retorno de el puente'),
#  ('Zoya Bianchi', 1, 'La conquista de la salvación'),
#  ('Nina Hidalgo', 1, 'La estirpe de la sombra'),
#  ('Leonardo Rocha', 1, 'La sombra de la maraña'),
#  ('Darya Borges', 1, 'La llegada de la flor'),
#  ('Wang Lopez', 1, 'El enigma de el valle'),
#  ('Leonardo Rodriguez', 1, 'La búsqueda de el viaje'),
#  ('Wan Pereira', 1, 'El canto de sirena de el amor'),
#  ('Omar Esteves', 1, 'La travesía del océano de la batalla'),
#  ('Rania Vieira', 1, 'La metamorfosis de el mar'),
#  ('Jin Rocha', 1, 'El espejismo de el sueño'),
#  ('Aarav Hidalgo', 1, 'La búsqueda de la senda'),
#  ('Wan Xu', 1, 'La leyenda de la criatura'),
#  ('Orhan Tan', 1, 'La leyenda perdida de la heroína'),
#  ('Yusef Barros', 1, 'La venganza de la guerra'),
#  ('Aarav Mendes', 1, 'El pacto de la misión'),
#  ('Oscar Lopez', 1, 'La danza macabra de la leyenda'),
#  ('Hanako Etxebarria', 1, 'El enigma de el valle'),
#  ('Wilhelmina Jimenez', 1, 'La búsqueda del tesoro de la heroína'),
#  ('Sakura Nguyen', 1, 'El príncipe de la guerra'),
#  ('Katarina Henriquez', 1, 'La llave de la huida'),
#  ('Chen Quintana', 1, 'El pacto de la magia'),
#  ('Yusef Qian', 1, 'La odisea de la oscuridad'),
#  ('Khaled Velez', 1, 'La danza de el viaje'),
#  ('Aarav Mendes', 1, 'El refugio de el mago'),
#  ('Irina Montenegro', 1, 'La leyenda de el castillo'),
#  ('Rania Vieira', 1, 'El pacto de la magia'),
#  ('Irina Montenegro', 1, 'La fuente de la libertad'),
#  ('Fatemeh Yan', 1, 'El secreto de la tormenta'),
#  ('Zafar Esteves', 1, 'El cuento de hadas de el puente'),
#  ('Yasmin Ortega', 1, 'La búsqueda del tesoro de la esperanza'),
#  ('Beatriz Mendes', 1, 'La fuente de la libertad'),
#  ('Oscar Carvalho', 1, 'El vuelo mágico de el sueño'),
#  ('Katarina Urbina', 1, 'El castillo de el ángel'),
#  ('Isa Ramos', 1, 'El lamento de el tesoro'),
#  ('Emiko Henriquez', 1, 'La historia de la verdad'),
#  ('Qiu Yamamoto', 1, 'El secreto de la gruta'),
#  ('Wilhelmina Duarte', 1, 'El ritual de la cascada'),
#  ('Nina Hidalgo', 1, 'El ritual de la oscuridad'),
#  ('Theresa Henriquez', 1, 'La metamorfosis de la profecía'),
#  ('Ursula Petrov', 1, 'El príncipe de la escuela'),
#  ('Tatiana Wu', 1, 'El amanecer de la aventura'),
#  ('Fadhila Kumar', 1, 'La búsqueda del tesoro de la esperanza'),
#  ('Irina Goncalves', 1, 'El misterio de la tierra'),
#  ('Jin Abadi', 1, 'El vuelo de el sueño')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT actor.nombre as "Nombre"
# FROM actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# WHERE
#     director.id_director = 1
# GROUP BY
#     actor.nombre, pelicula.nombre;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 7 rows affected.
# [('Fatemeh Zhang',),
#  ('Kamala Gao',),
#  ('Lakshmi Figueiredo',),
#  ('Salim Sousa',),
#  ('Umberto Zhang',),
#  ('Xin Petrov',),
#  ('Zoya Bianchi',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# (psycopg2.ProgrammingError) can't execute an empty query
# [SQL: /* Reemplace estas queries por las que resuelven las consultas pedidas. */]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
