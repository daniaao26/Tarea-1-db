# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Daniela Aguilar - 202111060-7
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: ipython in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: prettytable in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython-genutils in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: six in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (1.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: colorama in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: decorator in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: matplotlib-inline in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: wcwidth in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: pure-eval in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: psycopg2 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (2.9.4)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB
# Out:
# env: DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tareaDB',
   password="Quintero"
)
print(conn)
# Out:
# <connection object at 0x00000161FF2FABD0; dsn: 'user=postgres password=xxx dbname=tareaDB host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE Director(
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
#
# CREATE TABLE Actor(
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
#
# CREATE TABLE Pelicula(
#     id_pelicula INT GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula, id_director),
#     FOREIGN KEY (id_director) REFERENCES Director(id_director),
#     UNIQUE(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula(
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_director(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES Director(id_director)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_actor(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_actor) REFERENCES Actor(id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_pelicula(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula(id_pelicula)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 2017, 'director': 97, 'genero': 'Animación', 'cast': [143, 183], 'mejor pelicula': 'no'}, 2: {'año': 1970, 'director': 185, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 3: {'año': 2009, 'director': 80, 'genero': 'Acción', 'cast': [22, 194, 1], 'mejor pelicula': 'no'}, 4: {'año': 2021, 'director': 101, 'genero': 'Acción', 'cast': [14, 140, 156, 27], 'mejor pelicula': 'no'}, 5: {'año': 2000, 'director': 26, 'genero': 'Musical', 'cast': [36, 76], 'mejor pelicula': 'no'}, 6: {'año': 2007, 'director': 174, 'genero': 'Western', 'cast': [85, 133, 27], 'mejor pelicula': 'no'}, 7: {'año': 1976, 'director': 178, 'genero': 'Western', 'cast': [120, 9, 91], 'mejor pelicula': 'no'}, 8: {'año': 1995, 'director': 82, 'genero': 'Fantasía', 'cast': [41], 'mejor pelicula': 'no'}, 9: {'año': 2002, 'director': 114, 'genero': 'Fantasía', 'cast': [130], 'mejor pelicula': 'no'}, 10: {'año': 1972, 'director': 38, 'genero': 'Comedia', 'cast': [145, 158], 'mejor pelicula': 'no'}, 11: {'año': 1982, 'director': 194, 'genero': 'Animación', 'cast': [183, 8], 'mejor pelicula': 'no'}, 12: {'año': 1969, 'director': 39, 'genero': 'Acción', 'cast': [106, 113, 98], 'mejor pelicula': 'no'}, 13: {'año': 1980, 'director': 14, 'genero': 'Suspense', 'cast': [185, 199, 154, 24], 'mejor pelicula': 'no'}, 14: {'año': 1969, 'director': 13, 'genero': 'Western', 'cast': [195, 156], 'mejor pelicula': 'no'}, 15: {'año': 1994, 'director': 10, 'genero': 'Suspense', 'cast': [171], 'mejor pelicula': 'no'}, 16: {'año': 2002, 'director': 198, 'genero': 'Documental', 'cast': [125, 30, 34], 'mejor pelicula': 'no'}, 17: {'año': 1989, 'director': 109, 'genero': 'Suspense', 'cast': [75], 'mejor pelicula': 'no'}, 18: {'año': 1968, 'director': 180, 'genero': 'Comedia', 'cast': [90, 122, 169, 3], 'mejor pelicula': 'no'}, 19: {'año': 2020, 'director': 177, 'genero': 'Aventura', 'cast': [154, 146], 'mejor pelicula': 'no'}, 20: {'año': 2019, 'director': 136, 'genero': 'Misterio', 'cast': [13, 33, 194], 'mejor pelicula': 'no'}, 21: {'año': 1987, 'director': 83, 'genero': 'Musical', 'cast': [186, 59], 'mejor pelicula': 'no'}, 22: {'año': 1994, 'director': 86, 'genero': 'Fantasía', 'cast': [170, 119], 'mejor pelicula': 'no'}, 23: {'año': 1978, 'director': 192, 'genero': 'Acción', 'cast': [77, 133, 54], 'mejor pelicula': 'no'}, 24: {'año': 1987, 'director': 134, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 25: {'año': 1972, 'director': 124, 'genero': 'Terror', 'cast': [93, 166, 143], 'mejor pelicula': 'no'}, 26: {'año': 1969, 'director': 47, 'genero': 'Romance', 'cast': [46, 104], 'mejor pelicula': 'no'}, 27: {'año': 2000, 'director': 157, 'genero': 'Musical', 'cast': [100], 'mejor pelicula': 'no'}, 28: {'año': 1977, 'director': 161, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 29: {'año': 2008, 'director': 6, 'genero': 'Fantasía', 'cast': [47, 135, 86], 'mejor pelicula': 'no'}, 30: {'año': 1978, 'director': 107, 'genero': 'Romance', 'cast': [32], 'mejor pelicula': 'no'}, 31: {'año': 1995, 'director': 128, 'genero': 'Documental', 'cast': [93], 'mejor pelicula': 'no'}, 32: {'año': 2014, 'director': 182, 'genero': 'Suspense', 'cast': [156, 113], 'mejor pelicula': 'no'}, 33: {'año': 1976, 'director': 144, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 34: {'año': 2008, 'director': 62, 'genero': 'Misterio', 'cast': [59, 28, 132, 110], 'mejor pelicula': 'no'}, 35: {'año': 2009, 'director': 135, 'genero': 'Ciencia ficción', 'cast': [81], 'mejor pelicula': 'no'}, 36: {'año': 1967, 'director': 183, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 37: {'año': 1988, 'director': 91, 'genero': 'Drama', 'cast': [120, 82, 36, 117], 'mejor pelicula': 'no'}, 38: {'año': 1971, 'director': 159, 'genero': 'Romance', 'cast': [134, 195], 'mejor pelicula': 'no'}, 39: {'año': 1982, 'director': 122, 'genero': 'Western', 'cast': [73, 149], 'mejor pelicula': 'no'}, 40: {'año': 1987, 'director': 6, 'genero': 'Comedia', 'cast': [], 'mejor pelicula':  ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nombre as "Nombre"
# FROM
#     Pelicula
# WHERE
#     extract(Year from fecha_publicacion) >= 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 3 rows affected.
# [('La travesura de el guerrero',),
#  ('La doncella de la noche',),
#  ('La senda de la resistencia',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     nombre as "Nombre", fecha_publicacion as "Fecha de publicación"
# FROM
#     pelicula
# WHERE
#     genero = 'Drama' and extract(year from fecha_publicacion) = 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre as "Nombre"
# FROM
#     pelicula
# INNER JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN
#     actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# WHERE
#     genero = 'Comedia'
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 39 rows affected.
# [('Orhan Santos',),
#  ('Sakura Lopez',),
#  ('Leonardo Esteves',),
#  ('Patricia Diniz',),
#  ('Kamala Urbina',),
#  ('Genghis Gomes',),
#  ('Khaled Ueno',),
#  ('Darya Xu',),
#  ('Rania Lima',),
#  ('Nina Barros',),
#  ('Umar Estevez',),
#  ('Irina Kawaguchi',),
#  ('Gustavo Almeida',),
#  ('Yuri Alvarez',),
#  ('Jin Nogueira',),
#  ('Hanako Mendes',),
#  ('Han Janssen',),
#  ('Nina Duarte',),
#  ('Dmitri Qian',),
#  ('Jasmin Kawaguchi',),
#  ('Dmitri Diniz',),
#  ('Irina Queiroz',),
#  ('Oscar Iglesias',),
#  ('Samir Jimenez',),
#  ('Chiyoko Nunes',),
#  ('Leonardo Quintana',),
#  ('Hiroko Barros',),
#  ('Elif Alvarez',),
#  ('Beatriz Alvarez',),
#  ('Fadhila Correia',),
#  ('Pilar Uchoa',),
#  ('Leonardo Esteves',),
#  ('Jasmin Kawaguchi',),
#  ('Yuri Alvarez',),
#  ('Vivek Esteves',),
#  ('Salim Goncalves',),
#  ('Chiyoko Jimenez',),
#  ('Sakura Queiroz',),
#  ('Isa Borges',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.genero as "Género",COUNT(pelicula.genero) AS "Cantidad de premios"
# FROM
#     pelicula INNER JOIN premio_mejor_pelicula ON pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# GROUP BY
#     pelicula.genero
# ORDER BY
#     COUNT(pelicula.genero) DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 13 rows affected.
# [('Misterio', 4),
#  ('Western', 4),
#  ('Animación', 4),
#  ('Musical', 3),
#  ('Comedia', 2),
#  ('Romance', 2),
#  ('Acción', 2),
#  ('Suspense', 2),
#  ('Documental', 2),
#  ('Fantasía', 1),
#  ('Terror', 1),
#  ('Drama', 1),
#  ('Aventura', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre", COUNT(premio_mejor_actor.id_actor) as "Cantidad de Premios Mejor Actor"
# FROM
#     pelicula
# INNER JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN
#     premio_mejor_actor ON actor_participa_en_pelicula.id_actor = premio_mejor_actor.id_actor
# GROUP BY
#     pelicula.nombre
# HAVING
#     COUNT(premio_mejor_actor.id_actor) >= 2
# ORDER BY
#     COUNT(premio_mejor_actor.id_actor) DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 9 rows affected.
# [('La fuga de el guardián', 3),
#  ('La escalada de el horizonte', 3),
#  ('La danza de la montaña', 2),
#  ('El grito de la montaña', 2),
#  ('El regreso de la traición', 2),
#  ('La fortuna de el amor', 2),
#  ('El refugio de la escuela', 2),
#  ('El renacimiento de el descubrimiento', 2),
#  ('El renacimiento de la fortuna', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** Se obtienen el nombre de la pelicula, edad del actor más joven y la edad del actor más viejo de la intersección entre las tablas pelicula, actor_participa_en_pelicula y actor, inmedietamente ordenamos la tabla resultante en función de la diferencia de edad entre el actor más viejo y más joven y limitamos el número de filas a 1.

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre",MIN(actor.edad) as "Edad del actor más joven",MAX(actor.edad) as "Edad del actor más viejo"
# FROM pelicula
# INNER JOIN actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# GROUP BY pelicula.nombre
# ORDER BY MAX(actor.edad) - MIN(actor.edad) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 1 rows affected.
# [('El bosque encantado de el sacrificio', 15, 68)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT premio_mejor_pelicula.anio as "Año"
# FROM (
#     SELECT *
#     FROM pelicula
#     ORDER BY pelicula.duracion desc
#     limit 1
# ) as pelicula
# INNER JOIN premio_mejor_pelicula on pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre as "Nombre del actor",
#     COUNT(director) as "Cantidad de directores",
#     pelicula.nombre as "Nombre de una pelicula"
# FROM
#     actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# GROUP BY
#     actor.nombre, pelicula.nombre
# HAVING
#     COUNT(director) >= 2
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT actor.nombre as "Nombre"
# FROM actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# WHERE
#     director.id_director = 1
# GROUP BY
#     actor.nombre
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre AS "Nombre del actor",
#     pelicula.nombre AS "Nombre de la Pelicula",
#     director.nombre AS "Nombre del director",
#     COUNT(pelicula.id_pelicula) AS "Número de películas del director",
#     COUNT(premio_mejor_director.id_premio) AS "Número de premios del director"
# FROM actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# LEFT JOIN
#     premio_mejor_director ON director.id_director = premio_mejor_director.id_director
# WHERE NOT EXISTS(
#     SELECT 1
#     FROM premio_mejor_actor
#     WHERE actor.id_actor = premio_mejor_actor.id_actor
# )
# GROUP BY
#     actor.nombre,pelicula.nombre, director.nombre;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 417 rows affected.
# [('Nina Rodriguez', 'El lamento de el adiós', 'Bianca Borges', 1, 0),
#  ('Fadhila Correia', 'La misión de el bosque', 'Aarav Rocha', 1, 0),
#  ('Oscar Iglesias', 'El cuento de hadas de la batalla', 'Quentin Kumar', 1, 0),
#  ('Chiyoko Jimenez', 'La venganza de la despedida', 'Rosa Hidalgo', 1, 0),
#  ('Rashid Petrov', 'El arco iris de la senda', 'Khaled Cruz', 1, 0),
#  ('Parvati Fernandes', 'El cuento de hadas de la caverna', 'Isa Yamamoto', 1, 1),
#  ('Xavier Hidalgo', 'El secreto de la sombra', 'Mina Vieira', 1, 1),
#  ('Hiroko Barros', 'La misión de el ángel', 'Elif Ortega', 1, 0),
#  ('Yuri Quintana', 'La travesía de la guerra', 'Umberto Ueno', 1, 0),
#  ('Chen Uchoa', 'La profecía de el faro', 'Elena Yilmaz', 1, 0),
#  ('Kamala Urbina', 'La travesura de la nube', 'Lakshmi Santana', 1, 0),
#  ('Darya Xu', 'El secreto de la compañía', 'Ursula Hernandez', 1, 1),
#  ('Orhan Santos', 'La trampa de el árbol', 'Alessandro Nogueira', 1, 1),
#  ('Mikhail Santana', 'La leyenda perdida de el desafío', 'Chen Yan', 1, 0),
#  ('Hiroko Queiroz', 'La tormenta de la soledad', 'Rania Santana', 1, 0),
#  ('Rania Lima', 'El lamento de la clave', 'Yusef Etxebarria', 1, 1),
#  ('Han Pacheco', 'El regreso de el sacrificio', 'Rashid Martinez', 1, 0),
#  ('Darya Wu', 'El descubrimiento de la estrella fugaz', 'Alessandro Nogueira', 1, 1),
#  ('Wang Carvalho', 'La búsqueda de la caza', 'Patricia Santana', 1, 0),
#  ('Xavier Hidalgo', 'La resurrección de el pacto', 'Patricia Santana', 1, 0),
#  ('Darya Xu', 'La fortuna de la noche', 'Salim Olivares', 1, 0),
#  ('Salim Teixeira', 'La conquista de la leyenda', 'Umberto Ueno', 1, 0),
#  ('Hiroko Vargas', 'El espejismo de la revelación', 'Quintus Xavier', 1, 0),
#  ('Samir Ferreira', 'El secreto de la magia', 'Rosa Hidalgo', 1, 0),
#  ('Yasmin Henriquez', 'El eclipse de la sombra', 'Yasmin Yan', 1, 0),
#  ('Nina Lima', 'La fuente de el pacto', 'Rashid Lopez', 1, 0),
#  ('Chen Wu', 'El cuento de hadas de la luna', 'Ursula Rocha', 1, 1),
#  ('Wang Jimenez', 'La batalla de el unicornio', 'Chen Inácio', 1, 1),
#  ('Javier Bianchi', 'La estrella fugaz de la montaña', 'Isa Duarte', 1, 0),
#  ('Nina Rodriguez', 'El eclipse de la flor', 'Vivek Nogueira', 1, 0),
#  ('Mina Quintana', 'El secreto oscuro de la esperanza', 'Alessandro Zapata', 1, 0),
#  ('Jasmin Kawaguchi', 'El arco iris de la senda', 'Khaled Cruz', 1, 0),
#  ('Ursula Kumar', 'El renacimiento de la neblina', 'Bianca Borges', 1, 0),
#  ('Beatriz Alvarez', 'La misión de el ángel', 'Elif Ortega', 1, 0),
#  ('Samir Ferreira', 'La fuente de el viajero', 'Samir Uchoa', 1, 0),
#  ('Isa Xu', 'La tormenta de la soledad', 'Rania Santana', 1, 0),
#  ('Sakura Ferreira', 'El canto de sirena de la prisión', 'Leticia Vieira', 1, 0),
#  ('Chen Uchoa', 'El regreso de la luna', 'Rashid Olivares', 1, 1),
#  ('Ximena Etxebarria', 'La leyenda de la leyenda', 'Xavier Xu', 1, 0),
#  ('Salim Goncalves', 'La venganza de el perdón', 'Quintus Xavier', 1, 0),
#  ('Yuri Kawaguchi', 'El enigma de la sirena', 'Nina Correia', 1, 1),
#  ('Beatriz Ramos', 'La misión de el bosque', 'Aarav Rocha', 1, 0),
#  ('Darya Xu', 'La llave de la magia', 'Zoya Kawaguchi', 1, 0),
#  ('Umberto Teles', 'La llave de la magia', 'Zoya Kawaguchi', 1, 0),
#  ('Kamala Kawaguchi', 'El canto de sirena de el viaje', 'Zoya Kawaguchi', 1, 0),
#  ('Vivek Esteves', 'La doncella de la despedida', 'Hiroko Nogueira', 1, 1),
#  ('Dmitri Diniz', 'La fuente de el destino', 'Valeria Zapata', 1, 1),
#  ('Mina Tan', 'La cripta de la magia', 'Leonardo Zambrano', 1, 0),
#  ('Han Janssen', 'La batalla de el mito', 'Quintus Correia', 1, 0),
#  ('Han Ferreira', 'El hechizo de la espada mágica', 'Elif Ortega', 1, 0),
#  ('Orhan Inácio', 'El enigma de la sirena', 'Nina Correia', 1, 1),
#  ('Wan Ivanov', 'La llave de la tormenta', 'Gustavo Estevez', 1, 1),
#  ('Jasmin Kawaguchi', 'La maldición del vampiro de la profecía', 'Leticia Rocha', 1, 0),
#  ('Wang Jimenez', 'El eclipse de la flor', 'Vivek Nogueira', 1, 0),
#  ('Sakura Dutta', 'La conquista de la guerra', 'Qiu Carvalho', 1, 1),
#  ('Genghis Gomes', 'La sombra de la aventura', 'Chen Ueno', 1, 0),
#  ('Wan Ivanov', 'El viajero de la traición', 'Yasmin Yan', 1, 0),
#  ('Hiroko Barros', 'El refugio de el lobo', 'Javier Lopes', 1, 0),
#  ('Parvati Teixeira', 'El tesoro escondido de la aventura', 'Nadia Xavier', 1, 1),
#  ('Orhan Inácio', 'El descubrimiento de la prisión', 'Fadhila Gomes', 1, 0),
#  ('Fadhila Correia', 'El regreso de la luna', 'Rashid Olivares', 1, 1),
#  ('Samir Jimenez', 'El resurgimiento de la fuga', 'Alessandro Nogueira', 1, 1),
#  ('Zafar Montenegro', 'El despertar de el cielo', 'Genghis Alvarez', 1, 0),
#  ('Ursula Kumar', 'La trampa de la batalla', 'Alessandro Urbina', 1, 0),
#  ('Wilhelmina Hidalgo', 'La fortuna de el sueño', 'Rashid Olivares', 1, 1),
#  ('Giovanni Dutta', 'La trampa de la cripta', 'Tatiana Tan', 1, 1),
#  ('Sakura Lopez', 'La cripta de el árbol', 'Wilhelmina Joaquim', 1, 1),
#  ('Darya Wu', 'La estirpe de el hechizo', 'Khaled Cruz', 1, 0),
#  ('Vivek Esteves', 'El refugio de el destino', 'Natalia Gao', 1, 0),
#  ('Chiyoko Jimenez', 'El tesoro escondido de la aventura', 'Nadia Xavier', 1, 1),
#  ('Isa Borges', 'La travesía de la guerra', 'Umberto Ueno', 1, 0),
#  ('Umar Nunes', 'La fuente de el pacto', 'Rashid Lopez', 1, 0),
#  ('Wang Abadi', 'La fuente de la sombra', 'Lakshmi Montenegro', 1, 1),
#  ('Zara Hidalgo', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Wang Jimenez', 'El refugio de el destino', 'Natalia Gao', 1, 0),
#  ('Patricia Martinez', 'La venganza de el perdón', 'Quintus Xavier', 1, 0),
#  ('Wan Ivanov', 'El viajero de la huida', 'Leonardo Zambrano', 1, 0),
#  ('Pilar Kawaguchi', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Rania Nunes', 'El vuelo de la espada', 'Alessandro Urbina', 1, 0),
#  ('Rania Nunes', 'La misión de el bosque', 'Aarav Rocha', 1, 0),
#  ('Mikhail Santana', 'El renacimiento de el descubrimiento', 'Alessandro Urbina', 1, 0),
#  ('Zara Hidalgo', 'El grito de la montaña', 'Zoya Nogueira', 1, 0),
#  ('Isa Xu', 'El tesoro escondido de la paz', 'Ximena Kumar', 1, 0),
#  ('Giovanni Xia', 'La venganza de el río', 'Yuri Ortega', 1, 0),
#  ('Khaled Janssen', 'La búsqueda del tesoro de la flor', 'Alessandro Santos', 1, 0),
#  ('Irina Kawaguchi', 'El refugio de la fuga', 'Lakshmi Abadi', 1, 0),
#  ('Ursula Rodriguez', 'El secreto oscuro de el héroe', 'Mikhail Urbina', 2, 2),
#  ('Quintus Goncalves', 'El prisionero de la soledad', 'Yasmin Lima', 1, 0),
#  ('Dmitri Diniz', 'El resurgimiento de la selva', 'Genghis Xia', 1, 0),
#  ('Chiyoko Nunes', 'El cuento de hadas de la batalla', 'Quentin Kumar', 1, 0),
#  ('Rosa Watanabe', 'El secreto de la selva', 'Ximena Kumar', 1, 0),
#  ('Wang Carvalho', 'El príncipe de el dragón', 'Rashid Olivares', 1, 1),
#  ('Jasmin Kawaguchi', 'El enigma de la misión', 'Dmitri Henriquez', 1, 0),
#  ('Dmitri Qian', 'La danza macabra de la gárgola', 'Rosa Mendes', 1, 0),
#  ('Mina Tan', 'El regreso de la nube', 'Natalia Inácio', 1, 1),
#  ('Nadia Goncalves', 'El hechizo de la espada mágica', 'Elif Ortega', 1, 0),
#  ('Xin Almeida', 'El espejismo de el volcán', 'Nina Velez', 1, 0),
#  ('Javier Qian', 'La historia de el caos', 'Mina Almeida', 1, 0),
#  ('Lakshmi Nguyen', 'La conquista de la guerra', 'Qiu Carvalho', 1, 1),
#  ('Rashid Yan', 'El refugio de el sacrificio', 'Quintus Abadi', 1, 0),
#  ('Wilhelmina Hidalgo', 'El misterio de el dragón', 'Genghis Xia', 1, 0),
#  ('Mikhail Estevez', 'La leyenda perdida de el desafío', 'Chen Yan', 1, 0),
#  ('Abdullah Santos', 'El arco iris de la luna', 'Bianca Borges', 1, 0),
#  ('Hiroko Barros', 'El secreto oscuro de el héroe', 'Mikhail Urbina', 2, 2),
#  ('Han Janssen', 'El misterio de el mar', 'Yasmin Dutta', 1, 0),
#  ('Sakura Ferreira', 'El regreso de la luna', 'Rashid Olivares', 1, 1),
#  ('Rosa Petrov', 'El hechizo de el río', 'Isa Etxebarria', 1, 1),
#  ('Javier Bianchi', 'La fuga de el ángel', 'Chen Inácio', 1, 1),
#  ('Khaled Yilmaz', 'La fuente de el destino', 'Valeria Zapata', 1, 1),
#  ('Mikhail Carvalho', 'La leyenda perdida de la misión', 'Kamala Hernandez', 1, 0),
#  ('Khaled Yilmaz', 'La fortuna de el tesoro', 'Lakshmi Montenegro', 1, 1),
#  ('Lakshmi Nguyen', 'La fuga de el ángel', 'Chen Inácio', 1, 1),
#  ('Mikhail Santana', 'La senda de la resistencia', 'Nadia Figueiredo', 1, 1),
#  ('Theresa Ivanov', 'La odisea de la muralla', 'Irina Joaquim', 1, 0),
#  ('Jasmin Kawaguchi', 'La trampa de la cripta', 'Tatiana Tan', 1, 1),
#  ('Mina Janssen', 'El canto de sirena de el sapo', 'Quintus Correia', 1, 0),
#  ('Mikhail Carvalho', 'La fuente de el viajero', 'Samir Uchoa', 1, 0),
#  ('Katarina Teles', 'La fuente de el destino', 'Valeria Zapata', 1, 1),
#  ('Abdullah Lopez', 'La fuente de el sol', 'Mina Oliveira', 1, 0),
#  ('Hiroko Henriquez', 'El renacimiento de la neblina', 'Bianca Borges', 1, 0),
#  ('Xin Nogueira', 'El arco iris de el viaje', 'Leticia Rocha', 1, 0),
#  ('Tatjana Santana', 'El arco iris de la montaña', 'Fadhila Gomes', 1, 0),
#  ('Gustavo Xu', 'La profecía de el faro', 'Elena Yilmaz', 1, 0),
#  ('Khaled Ueno', 'El bosque encantado de el sacrificio', 'Chen Correia', 1, 0),
#  ('Umberto Teles', 'El viaje de el laberinto', 'Kamala Uchoa', 1, 0),
#  ('Leonardo Quintana', 'El refugio de la escuela', 'Natalia Estevez', 1, 0),
#  ('Yuri Kawaguchi', 'La sombra de el atardecer', 'Javier Lopes', 1, 0),
#  ('Rosa Yan', 'La odisea de la revelación', 'Zara Vargas', 1, 0),
#  ('Mina Estevez', 'El cuento de hadas de la luna', 'Ursula Rocha', 1, 1),
#  ('Yuri Quintana', 'El caballero de el cielo', 'Natalia Santos', 1, 1),
#  ('Giovanni Santana', 'La travesura de la princesa', 'Samir Estevez', 1, 0),
#  ('Omar Pereira', 'El regreso de la criatura', 'Isa Ferreira', 1, 0),
#  ('Kamala Kawaguchi', 'El viajero de la traición', 'Yasmin Yan', 1, 0),
#  ('Aarav Lima', 'La tormenta de la soledad', 'Rania Santana', 1, 0),
#  ('Wilhelmina Abadi', 'La odisea de la revelación', 'Zara Vargas', 1, 0),
#  ('Mikhail Santana', 'El refugio de la escuela', 'Natalia Estevez', 1, 0),
#  ('Isa Correia', 'La batalla de la bruja', 'Dmitri Fernandes', 1, 0),
#  ('Wilhelmina Goncalves', 'El vuelo mágico de el viaje', 'Darius Bianchi', 1, 0),
#  ('Rania Nunes', 'El guardián de la luz', 'Chen Watanabe', 1, 0),
#  ('Fadhila Correia', 'La leyenda de la leyenda', 'Xavier Xu', 1, 0),
#  ('Omar Pereira', 'La fortuna de la noche', 'Salim Olivares', 1, 0),
#  ('Han Janssen', 'El pacto de la alianza', 'Quintus Ortega', 1, 0),
#  ('Fadhila Pacheco', 'La búsqueda de la caza', 'Patricia Santana', 1, 0),
#  ('Leticia Jimenez', 'La profecía de la cascada', 'Ursula Hernandez', 1, 1),
#  ('Ximena Etxebarria', 'La resurrección de el grito', 'Natalia Tan', 1, 0),
#  ('Nina Rodriguez', 'La trampa de el árbol', 'Alessandro Nogueira', 1, 1),
#  ('Xin Almeida', 'Las aventuras de la revelación', 'Zara Goncalves', 1, 0),
#  ('Ursula Zambrano', 'La canción de el amor', 'Mikhail Urbina', 2, 2),
#  ('Sakura Ferreira', 'La cripta de la magia', 'Leonardo Zambrano', 1, 0),
#  ('Natalia Ivanov', 'El eclipse de la sombra', 'Yasmin Yan', 1, 0),
#  ('Theresa Ivanov', 'El secreto de la selva', 'Ximena Kumar', 1, 0),
#  ('Nina Duarte', 'El destino de el guerrero', 'Wan Bianchi', 1, 0),
#  ('Tatjana Santana', 'El espejismo de la revelación', 'Quintus Xavier', 1, 0),
#  ('Sakura Alvarez', 'La tormenta de el mago', 'Akira Joaquim', 1, 0),
#  ('Beatriz Ramos', 'El destino de el guardián', 'Wilhelmina Joaquim', 1, 1),
#  ('Wilhelmina Hidalgo', 'El refugio de la resistencia', 'Quintus Abadi', 1, 0),
#  ('Emiko Pereira', 'El grito de la montaña', 'Zoya Nogueira', 1, 0),
#  ('Sakura Dutta', 'El despertar de el cielo', 'Genghis Alvarez', 1, 0),
#  ('Javier Bianchi', 'La senda de la resistencia', 'Nadia Figueiredo', 1, 1),
#  ('Salim Goncalves', 'El viajero de el caos', 'Rania Santana', 1, 0),
#  ('Chiyoko Jimenez', 'El bosque encantado de el puente', 'Natalia Estevez', 1, 0),
#  ('Elif Alvarez', 'La redención de la maraña', 'Yuri Velez', 1, 1),
#  ('Sakura Alvarez', 'La historia de la pesadilla', 'Valeria Zapata', 1, 1),
#  ('Ximena Martinez', 'El misterio de el dragón', 'Salim Olivares', 1, 0),
#  ('Rashid Yan', 'El espejismo de la gárgola', 'Darya Hernandez', 1, 0),
#  ('Vivek Nogueira', 'El hechizo de la espada mágica', 'Elif Ortega', 1, 0),
#  ('Nina Rodriguez', 'El secreto oscuro de la esperanza', 'Alessandro Zapata', 1, 0),
#  ('Yuri Alvarez', 'El bosque encantado de el sacrificio', 'Chen Correia', 1, 0),
#  ('Ursula Nogueira', 'La redención de la maraña', 'Yuri Velez', 1, 1),
#  ('Javier Qian', 'El pacto de la alianza', 'Quintus Ortega', 1, 0),
#  ('Elif Alvarez', 'La leyenda de la sombra', 'Genghis Xia', 1, 0),
#  ('Dmitri Qian', 'La doncella de la despedida', 'Hiroko Nogueira', 1, 1),
#  ('Hanako Zambrano', 'La tormenta de el ángel', 'Javier Lopes', 1, 0),
#  ('Fadhila Zapata', 'El regreso de la luna', 'Rashid Olivares', 1, 1),
#  ('Mikhail Santana', 'El descubrimiento de el legado', 'Lakshmi Abadi', 1, 0),
#  ('Vivek Inácio', 'La odisea de la profecía', 'Xin Rocha', 1, 0),
#  ('Orhan Santos', 'La venganza de el río', 'Yuri Ortega', 1, 0),
#  ('Khaled Yilmaz', 'La batalla de el faro', 'Zara Goncalves', 1, 0),
#  ('Beatriz Alvarez', 'La fuente de el viajero', 'Samir Uchoa', 1, 0),
#  ('Irina Queiroz', 'El bosque encantado de el sacrificio', 'Chen Correia', 1, 0),
#  ('Patricia Diniz', 'La canción de el amor', 'Mikhail Urbina', 2, 2),
#  ('Wang Diniz', 'El lamento de la clave', 'Yusef Etxebarria', 1, 1),
#  ('Mikhail Carvalho', 'La batalla de la bruja', 'Dmitri Fernandes', 1, 0),
#  ('Leonardo Tan', 'La leyenda de la sombra', 'Genghis Xia', 1, 0),
#  ('Wilhelmina Abadi', 'El refugio de la fuga', 'Lakshmi Abadi', 1, 0),
#  ('Irina Queiroz', 'El príncipe de la espada mágica', 'Patricia Santana', 1, 0),
#  ('Yusef Abadi', 'La fuente de la sombra', 'Lakshmi Montenegro', 1, 1),
#  ('Rosa Watanabe', 'El misterio de el dragón', 'Genghis Xia', 1, 0),
#  ('Wang Diniz', 'El renacimiento de la amistad', 'Salim Watanabe', 1, 0),
#  ('Sakura Ferreira', 'La misión de el muro', 'Beatriz Nogueira', 1, 0),
#  ('Gustavo Xu', 'La leyenda de el laberinto', 'Valeria Zapata', 1, 1),
#  ('Sakura Lopez', 'La redención de la nube', 'Nadia Montenegro', 1, 0),
#  ('Mikhail Santana', 'La profecía de la cascada', 'Ursula Hernandez', 1, 1),
#  ('Darya Xu', 'La búsqueda de la profecía', 'Tatjana Pacheco', 1, 0),
#  ('Leticia Jimenez', 'El prisionero de la muralla', 'Vivek Nogueira', 1, 0),
#  ('Isa Correia', 'El lamento de la gárgola', 'Chen Yan', 1, 0),
#  ('Kamala Kawaguchi', 'El refugio de la esperanza', 'Wilhelmina Joaquim', 1, 1),
#  ('Han Pacheco', 'El viajero de la huida', 'Leonardo Zambrano', 1, 0),
#  ('Mikhail Estevez', 'La fortuna de el sueño', 'Rashid Olivares', 1, 1),
#  ('Oscar Vieira', 'El hechizo de la espada mágica', 'Elif Ortega', 1, 0),
#  ('Elif Alvarez', 'El canto de sirena de la corona', 'Quentin Pereira', 1, 0),
#  ('Dmitri Diniz', 'El misterio de la muralla', 'Ursula Rocha', 1, 1),
#  ('Chen Duarte', 'La trampa de la prisión', 'Han Santos', 1, 0),
#  ('Leticia Jimenez', 'El ritual de la ciudad', 'Irina Joaquim', 1, 0),
#  ('Hiroko Henriquez', 'El refugio de la escuela', 'Natalia Estevez', 1, 0),
#  ('Genghis Gomes', 'El refugio de la resistencia', 'Quintus Abadi', 1, 0),
#  ('Natalia Ferreira', 'El espejismo de el volcán', 'Nina Velez', 1, 0),
#  ('Khaled Yilmaz', 'El viaje de el laberinto', 'Kamala Uchoa', 1, 0),
#  ('Han Ferreira', 'La travesía de la batalla', 'Wang Hernandez', 1, 1),
#  ('Darya Ferreira', 'La fuga de el ángel', 'Chen Inácio', 1, 1),
#  ('Leonardo Tan', 'La maldición del vampiro de la clave', 'Mehmet Lopes', 1, 0),
#  ('Han Janssen', 'La leyenda perdida de la promesa', 'Nadia Figueiredo', 1, 1),
#  ('Nina Duarte', 'La maldición de la salvación', 'Hanako Urbina', 1, 0),
#  ('Elif Alvarez', 'El misterio de la montaña', 'Samir Esteves', 1, 0),
#  ('Umberto Teles', 'La redención de la maraña', 'Yuri Velez', 1, 1),
#  ('Salim Goncalves', 'El príncipe de la neblina', 'Quentin Goncalves', 1, 1),
#  ('Umberto Etxebarria', 'La invasión de la revelación', 'Nina Velez', 1, 0),
#  ('Umar Nunes', 'La venganza de el río', 'Yuri Ortega', 1, 0),
#  ('Orhan Santos', 'La danza macabra de la cripta', 'Chen Watanabe', 1, 0),
#  ('Isa Borges', 'El tesoro de la alianza', 'Dmitri Henriquez', 1, 0),
#  ('Gustavo Almeida', 'La cripta de el mar', 'Elena Henriquez', 1, 1),
#  ('Xin Almeida', 'La conquista de la guerra', 'Qiu Carvalho', 1, 1),
#  ('Tatjana Barros', 'El canto de sirena de el sapo', 'Quintus Correia', 1, 0),
#  ('Rosa Petrov', 'La metamorfosis de la academia', 'Rosa Mendes', 1, 0),
#  ('Nina Dutta', 'El arco iris de el viaje', 'Leticia Rocha', 1, 0),
#  ('Han Janssen', 'El tesoro de la tierra', 'Nina Correia', 1, 1),
#  ('Samir Jimenez', 'El prisionero de la montaña', 'Tatiana Dutta', 1, 0),
#  ('Yasmin Henriquez', 'El hechizo de el río', 'Isa Etxebarria', 1, 1),
#  ('Omar Pereira', 'La leyenda perdida de la huida', 'Rosa Hidalgo', 1, 0),
#  ('Leonardo Abadi', 'El hechizo de el río', 'Isa Etxebarria', 1, 1),
#  ('Elif Olivares', 'Las aventuras de el unicornio', 'Jin Sousa', 1, 0),
#  ('Jasmin Kawaguchi', 'La fuente de la verdad', 'Xavier Xu', 1, 0),
#  ('Hiroko Barros', 'La fortuna de el sueño', 'Rashid Olivares', 1, 1),
#  ('Chidike Tan', 'La odisea de la revelación', 'Zara Vargas', 1, 0),
#  ('Zoya Figueiredo', 'El tesoro escondido de la aventura', 'Nadia Xavier', 1, 1),
#  ('Lakshmi Nguyen', 'La sombra de la despedida', 'Xavier Abadi', 1, 0),
#  ('Giovanni Xia', 'La resurrección de el grito', 'Natalia Tan', 1, 0),
#  ('Quintus Goncalves', 'La metamorfosis de la academia', 'Rosa Mendes', 1, 0),
#  ('Patricia Martinez', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Rosa Petrov', 'El amanecer de la profecía', 'Xavier Abadi', 1, 0),
#  ('Darya Wu', 'Las aventuras de la pasión', 'Isa Xu', 1, 0),
#  ('Hiroko Queiroz', 'La leyenda de el laberinto', 'Valeria Zapata', 1, 1),
#  ('Omar Zapata', 'El descubrimiento de el fuego', 'Dmitri Henriquez', 1, 0),
#  ('Theresa Ivanov', 'La estirpe de el hechizo', 'Khaled Cruz', 1, 0),
#  ('Isa Borges', 'La fuente de el destino', 'Valeria Zapata', 1, 1),
#  ('Akira Quintana', 'El grito de la montaña', 'Zoya Nogueira', 1, 0),
#  ('Ursula Rodriguez', 'El vuelo de la amistad', 'Javier Lopes', 1, 0),
#  ('Katarina Teles', 'El resurgimiento de la magia', 'Theresa Janssen', 1, 0),
#  ('Jasmin Kawaguchi', 'La venganza de la despedida', 'Rosa Hidalgo', 1, 0),
#  ('Ursula Zambrano', 'La historia de el explorador', 'Lakshmi Santana', 1, 0),
#  ('Orhan Santos', 'El grito de la despedida', 'Leonardo Zambrano', 1, 0),
#  ('Wang Jimenez', 'La batalla de el mito', 'Quintus Correia', 1, 0),
#  ('Mikhail Estevez', 'El último viaje de el valle', 'Rania Inácio', 1, 0),
#  ('Isa Correia', 'El prisionero de la soledad', 'Yasmin Lima', 1, 0),
#  ('Hiroko Henriquez', 'La leyenda perdida de el viajero', 'Jasmin Inácio', 1, 0),
#  ('Fadhila Correia', 'El bosque encantado de el sacrificio', 'Chen Correia', 1, 0),
#  ('Wang Iglesias', 'La danza de la montaña', 'Chen Olivares', 1, 0),
#  ('Ursula Kumar', 'La fuga de el ángel', 'Chen Inácio', 1, 1),
#  ('Patricia Diniz', 'La fortuna de el sol', 'Wilhelmina Kawaguchi', 1, 0),
#  ('Sakura Lopez', 'El cuento de hadas de la batalla', 'Quentin Kumar', 1, 0),
#  ('Katarina Teles', 'El misterio de el dragón', 'Salim Olivares', 1, 0),
#  ('Xin Nogueira', 'La canción de el amor', 'Mikhail Urbina', 2, 2),
#  ('Darya Ferreira', 'El descubrimiento de la fortuna', 'Isa Esteves', 1, 0),
#  ('Darya Wu', 'La conquista de la guerra', 'Qiu Carvalho', 1, 1),
#  ('Isa Xu', 'La búsqueda del tesoro de la bruma', 'Lakshmi Montenegro', 1, 1),
#  ('Sakura Alvarez', 'El tesoro escondido de la traición', 'Salim Nogueira', 1, 0),
#  ('Han Ferreira', 'El descubrimiento de el fuego', 'Dmitri Henriquez', 1, 0),
#  ('Oscar Iglesias', 'La historia de el laberinto', 'Quentin Zapata', 1, 0),
#  ('Hiroko Barros', 'Las aventuras de el unicornio', 'Jin Sousa', 1, 0),
#  ('Leonardo Tan', 'La misión de el muro', 'Beatriz Nogueira', 1, 0),
#  ('Omar Zapata', 'La historia de el caos', 'Mina Almeida', 1, 0),
#  ('Giovanni Xia', 'El canto de sirena de la corona', 'Quentin Pereira', 1, 0),
#  ('Abdullah Lopez', 'El último viaje de el dragón', 'Qiu Carvalho', 1, 1),
#  ('Omar Zapata', 'El guardián de la profecía', 'Salim Pereira', 1, 0),
#  ('Katarina Teles', 'El eclipse de la pasión', 'Ilya Inácio', 1, 1),
#  ('Dmitri Diniz', 'La invasión de la revelación', 'Nina Velez', 1, 0),
#  ('Yuri Kawaguchi', 'La misión de el bosque', 'Aarav Rocha', 1, 0),
#  ('Irina Kawaguchi', 'La redención de la nube', 'Nadia Montenegro', 1, 0),
#  ('Isa Velez', 'El prisionero de el castillo', 'Mikhail Urbina', 2, 2),
#  ('Yuri Kawaguchi', 'El refugio de el destino', 'Natalia Gao', 1, 0),
#  ('Giovanni Santana', 'El caballero de el cielo', 'Natalia Santos', 1, 1),
#  ('Isa Xu', 'El caballero de el ángel', 'Salim Olivares', 1, 0),
#  ('Leonardo Tan', 'El enigma de el peligro', 'Hanako Urbina', 1, 0),
#  ('Quintus Lima', 'El último viaje de el dragón', 'Qiu Carvalho', 1, 1),
#  ('Zara Hidalgo', 'El caballero de el ángel', 'Salim Olivares', 1, 0),
#  ('Patricia Diniz', 'El cuento de hadas de la batalla', 'Quentin Kumar', 1, 0),
#  ('Tatjana Santana', 'El tesoro escondido de la traición', 'Salim Nogueira', 1, 0),
#  ('Ursula Rodriguez', 'La misión de la tormenta', 'Natalia Santos', 1, 1),
#  ('Vivek Nogueira', 'El refugio de el héroe', 'Valeria Ivanov', 1, 0),
#  ('Rania Lima', 'El tesoro de la alianza', 'Dmitri Henriquez', 1, 0),
#  ('Mina Janssen', 'El renacimiento de la fortuna', 'Chen Lima', 1, 0),
#  ('Giovanni Xia', 'El viaje de la caverna', 'Alessandro Ivanov', 1, 0),
#  ('Hiroko Barros', 'El prisionero de la heroína', 'Nadia Figueiredo', 1, 1),
#  ('Dmitri Diniz', 'La danza macabra de la gárgola', 'Rosa Mendes', 1, 0),
#  ('Nina Tan', 'La profecía de el faro', 'Elena Yilmaz', 1, 0),
#  ('Nina Barros', 'El misterio de la montaña', 'Samir Esteves', 1, 0),
#  ('Oscar Iglesias', 'El despertar de el cielo', 'Genghis Alvarez', 1, 0),
#  ('Rashid Yan', 'El refugio de la fuga', 'Lakshmi Abadi', 1, 0),
#  ('Khaled Ueno', 'El pacto de la redención', 'Jasmin Lima', 1, 0),
#  ('Hiroko Queiroz', 'La trampa de la cripta', 'Tatiana Tan', 1, 1),
#  ('Yasmin Henriquez', 'La danza de la selva', 'Jin Sousa', 1, 0),
#  ('Rosa Watanabe', 'El amanecer de la nube', 'Chen Lima', 1, 0),
#  ('Wilhelmina Abadi', 'La leyenda de el laberinto', 'Valeria Zapata', 1, 1),
#  ('Leticia Martinez', 'El prisionero de la soledad', 'Yasmin Lima', 1, 0),
#  ('Bianca Xia', 'El lamento de la clave', 'Yusef Etxebarria', 1, 1),
#  ('Wang Abadi', 'El enigma de la misión', 'Dmitri Henriquez', 1, 0),
#  ('Gustavo Almeida', 'La danza macabra de la desgracia', 'Nina Velez', 1, 0),
#  ('Xavier Hidalgo', 'El secreto de el sacrificio', 'Darya Correia', 1, 0),
#  ('Tatjana Lima', 'La odisea de la muralla', 'Irina Joaquim', 1, 0),
#  ('Elif Olivares', 'La búsqueda de la caza', 'Patricia Santana', 1, 0),
#  ('Genghis Gomes', 'El espejismo de la revelación', 'Quintus Xavier', 1, 0),
#  ('Leonardo Quintana', 'La leyenda de el lobo', 'Ursula Teixeira', 1, 0),
#  ('Xin Nogueira', 'El regreso de la criatura', 'Isa Ferreira', 1, 0),
#  ('Isa Correia', 'La búsqueda del tesoro de la bruma', 'Lakshmi Montenegro', 1, 1),
#  ('Hiroko Barros', 'La resurrección de el grito', 'Natalia Tan', 1, 0),
#  ('Nina Lima', 'La doncella de el susurro', 'Mikhail Urbina', 2, 2),
#  ('Beatriz Alvarez', 'La invasión de la revelación', 'Nina Velez', 1, 0),
#  ('Tatjana Barros', 'La estirpe de la prisión', 'Nadia Xavier', 1, 1),
#  ('Wilhelmina Hidalgo', 'La sombra de el atardecer', 'Javier Lopes', 1, 0),
#  ('Samir Jimenez', 'El espejismo de la caza', 'Mehmet Lopes', 1, 0),
#  ('Xavier Hidalgo', 'La resurrección de el grito', 'Natalia Tan', 1, 0),
#  ('Elif Alvarez', 'La historia de la perdición', 'Isa Yamamoto', 1, 1),
#  ('Qiu Abadi', 'La maldición del vampiro de la travesía', 'Genghis Xia', 1, 0),
#  ('Fadhila Pacheco', 'El vuelo mágico de el laberinto', 'Quentin Goncalves', 1, 1),
#  ('Irina Kawaguchi', 'La misión de el ángel', 'Elif Ortega', 1, 0),
#  ('Wang Carvalho', 'El descubrimiento de el legado', 'Lakshmi Abadi', 1, 0),
#  ('Rosa Watanabe', 'El vuelo mágico de el laberinto', 'Quentin Goncalves', 1, 1),
#  ('Leonardo Quintana', 'La leyenda perdida de la promesa', 'Nadia Figueiredo', 1, 1),
#  ('Fadhila Zapata', 'El secreto de el sacrificio', 'Darya Correia', 1, 0),
#  ('Wang Iglesias', 'El vuelo mágico de el viaje', 'Darius Bianchi', 1, 0),
#  ('Hanako Zambrano', 'El ritual de la ciudad', 'Irina Joaquim', 1, 0),
#  ('Leonardo Esteves', 'La búsqueda de la profecía', 'Tatjana Pacheco', 1, 0),
#  ('Emiko Joaquim', 'El caballero de la expedición', 'Leonardo Xia', 1, 0),
#  ('Katarina Teles', 'La búsqueda de el puente', 'Rosa Mendes', 1, 0),
#  ('Emiko Joaquim', 'La tormenta de el ángel', 'Javier Lopes', 1, 0),
#  ('Pilar Uchoa', 'La llegada de la gruta', 'Theresa Nguyen', 1, 0),
#  ('Yuri Quintana', 'El renacimiento de la amistad', 'Salim Watanabe', 1, 0),
#  ('Darya Ferreira', 'El renacimiento de la neblina', 'Bianca Borges', 1, 0),
#  ('Genghis Gomes', 'La leyenda de el lobo', 'Ursula Teixeira', 1, 0),
#  ('Tatjana Santana', 'El príncipe de la neblina', 'Quentin Goncalves', 1, 1),
#  ('Beatriz Ramos', 'El eclipse de la flor', 'Vivek Nogueira', 1, 0),
#  ('Dmitri Diniz', 'El grito de la montaña', 'Zoya Nogueira', 1, 0),
#  ('Chiyoko Nunes', 'La canción de el amor', 'Mikhail Urbina', 2, 2),
#  ('Kamala Urbina', 'El regreso de la criatura', 'Isa Ferreira', 1, 0),
#  ('Omar Pereira', 'El destino de la cripta', 'Darya Wu', 1, 1),
#  ('Leonardo Tan', 'El eclipse de la pasión', 'Ilya Inácio', 1, 1),
#  ('Aarav Lima', 'La búsqueda del tesoro de la flor', 'Alessandro Santos', 1, 0),
#  ('Javier Bianchi', 'La profecía de la cascada', 'Ursula Hernandez', 1, 1),
#  ('Abdullah Ortega', 'La danza macabra de la venganza', 'Natalia Estevez', 1, 0),
#  ('Dmitri Qian', 'El arco iris de el viaje', 'Leticia Rocha', 1, 0),
#  ('Leonardo Esteves', 'La leyenda perdida de el viajero', 'Jasmin Inácio', 1, 0),
#  ('Leonardo Esteves', 'El viajero de el caos', 'Rania Santana', 1, 0),
#  ('Zafar Montenegro', 'La llave de la magia', 'Zoya Kawaguchi', 1, 0),
#  ('Darya Ferreira', 'El guardián de la profecía', 'Salim Pereira', 1, 0),
#  ('Akira Jimenez', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Irina Kawaguchi', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Chiyoko Jimenez', 'La fuente de el sol', 'Mina Oliveira', 1, 0),
#  ('Lakshmi Nguyen', 'El secreto de la selva', 'Ximena Kumar', 1, 0),
#  ('Zafar Nogueira', 'El hechizo de la espada mágica', 'Elif Ortega', 1, 0),
#  ('Abdullah Lopez', 'La sombra de la batalla', 'Jin Xu', 1, 1),
#  ('Wilhelmina Goncalves', 'El pacto de la alianza', 'Quintus Ortega', 1, 0),
#  ('Samir Jimenez', 'El espejismo de la revelación', 'Quintus Xavier', 1, 0),
#  ('Khaled Ueno', 'La sombra de la despedida', 'Xavier Abadi', 1, 0),
#  ('Giovanni Carvalho', 'El canto de sirena de la gárgola', 'Mehmet Lopes', 1, 0),
#  ('Isa Velez', 'La leyenda de la clave', 'Kamala Hernandez', 1, 0),
#  ('Vivek Esteves', 'La danza macabra de la gárgola', 'Rosa Mendes', 1, 0),
#  ('Yuri Kawaguchi', 'El enigma de la misión', 'Dmitri Henriquez', 1, 0),
#  ('Chiyoko Nguyen', 'El secreto de la magia', 'Rosa Hidalgo', 1, 0),
#  ('Nina Rodriguez', 'El refugio de la esperanza', 'Wilhelmina Joaquim', 1, 1),
#  ('Hiroko Henriquez', 'La conquista de la guerra', 'Qiu Carvalho', 1, 1),
#  ('Ursula Zambrano', 'El refugio de la fuga', 'Lakshmi Abadi', 1, 0),
#  ('Ximena Martinez', 'El caballero de el ángel', 'Salim Olivares', 1, 0),
#  ('Chiyoko Jimenez', 'El príncipe de la espada mágica', 'Patricia Santana', 1, 0),
#  ('Aarav Lima', 'El refugio de el sacrificio', 'Quintus Abadi', 1, 0),
#  ('Elena Rodriguez', 'La fuga de el guardián', 'Gustavo Estevez', 1, 1),
#  ('Nina Dutta', 'La travesía de la batalla', 'Wang Hernandez', 1, 1),
#  ('Theresa Henriquez', 'La venganza de el perdón', 'Quintus Xavier', 1, 0),
#  ('Abdullah Lopez', 'La cripta de el mar', 'Elena Henriquez', 1, 1),
#  ('Xavier Vargas', 'El descubrimiento de el fuego', 'Dmitri Henriquez', 1, 0),
#  ('Hiroko Barros', 'El resurgimiento de la fuga', 'Alessandro Nogueira', 1, 1),
#  ('Han Estevez', 'El príncipe de el dragón', 'Rashid Olivares', 1, 1),
#  ('Leticia Jimenez', 'El regreso de la nube', 'Natalia Inácio', 1, 1),
#  ('Leonardo Lopes', 'La búsqueda de la caza', 'Patricia Santana', 1, 0),
#  ('Leticia Martinez', 'El viajero de la traición', 'Yasmin Yan', 1, 0),
#  ('Chiyoko Jimenez', 'El renacimiento de la sirena', 'Natalia Tan', 1, 0),
#  ('Ximena Etxebarria', 'La fuente de el destino', 'Valeria Zapata', 1, 1),
#  ('Javier Qian', 'La sombra de la aventura', 'Chen Ueno', 1, 0),
#  ('Leonardo Esteves', 'El refugio de el destino', 'Natalia Gao', 1, 0),
#  ('Elif Olivares', 'La llegada de la fuga', 'Samir Uchoa', 1, 0),
#  ('Umar Nunes', 'El refugio de el héroe', 'Valeria Ivanov', 1, 0),
#  ('Rosa Petrov', 'El eclipse de la sombra', 'Yasmin Yan', 1, 0),
#  ('Theresa Ivanov', 'El canto de sirena de la corona', 'Quentin Pereira', 1, 0),
#  ('Javier Bianchi', 'La redención de el río', 'Rania Inácio', 1, 0),
#  ('Xavier Vargas', 'La llave de la tormenta', 'Gustavo Estevez', 1, 1),
#  ('Yasmin Henriquez', 'La batalla de el mito', 'Quintus Correia', 1, 0),
#  ('Darya Wu', 'El canto de sirena de la corona', 'Quentin Pereira', 1, 0),
#  ('Han Pacheco', 'El destino de el guardián', 'Wilhelmina Joaquim', 1, 1),
#  ('Umar Nunes', 'El canto de sirena de la prisión', 'Leticia Vieira', 1, 0),
#  ('Xavier Hidalgo', 'El ritual de la libertad', 'Mikhail Urbina', 2, 2),
#  ('Darya Xu', 'El tesoro escondido de la aventura', 'Nadia Xavier', 1, 1),
#  ('Giovanni Carvalho', 'El amanecer de el ángel', 'Quintus Abadi', 1, 0),
#  ('Orhan Inácio', 'El secreto oscuro de la esperanza', 'Alessandro Zapata', 1, 0),
#  ('Bianca Xia', 'El vuelo de la amistad', 'Javier Lopes', 1, 0),
#  ('Oscar Vieira', 'La redención de la maraña', 'Yuri Velez', 1, 1),
#  ('Samir Carvalho', 'El lamento de el adiós', 'Bianca Borges', 1, 0),
#  ('Wang Diniz', 'El vuelo de la espada', 'Alessandro Urbina', 1, 0),
#  ('Yuri Alvarez', 'La leyenda de el lobo', 'Ursula Teixeira', 1, 0),
#  ('Natalia Ivanov', 'La historia de el laberinto', 'Quentin Zapata', 1, 0),
#  ('Natalia Ivanov', 'El secreto de la prisión', 'Umberto Sousa', 1, 0),
#  ('Ilya Ferreira', 'La danza macabra de la venganza', 'Natalia Estevez', 1, 0),
#  ('Wang Jimenez', 'La leyenda perdida de la misión', 'Kamala Hernandez', 1, 0),
#  ('Chen Wu', 'El secreto de la magia', 'Rosa Hidalgo', 1, 0),
#  ('Lakshmi Nguyen', 'El regreso de el tesoro', 'Khaled Cruz', 1, 0),
#  ('Mikhail Estevez', 'La leyenda perdida de el camino', 'Isa Etxebarria', 1, 1),
#  ('Salim Goncalves', 'La danza de la montaña', 'Chen Olivares', 1, 0),
#  ('Wang Iglesias', 'El lamento de la clave', 'Yusef Etxebarria', 1, 1),
#  ('Nina Duarte', 'La travesura de la princesa', 'Samir Estevez', 1, 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
