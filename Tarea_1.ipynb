# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Daniela Aguilar - 202111060-7
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:moracrema@localhost:5432/BDD

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='BDD',
   password="moracrema"
)

print(conn)

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE Director(
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
#
# CREATE TABLE Actor(
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
#
# CREATE TABLE Pelicula(
#     id_pelicula INT GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula, id_director),
#     FOREIGN KEY (id_director) REFERENCES Director(id_director),
#     UNIQUE(id_pelicula)
# );

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula(
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula (id_pelicula)
# );

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_director(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES Director(id_director)
# )

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_actor(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_actor) REFERENCES Actor(id_actor)
# )

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_pelicula(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula(id_pelicula)
# )

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT * FROM Pelicula
# Out:
#  * postgresql://postgres:***@localhost:5432/BDD
# 300 rows affected.
# [(1, 158, 'La búsqueda de el abismo', 'Aventura', 99, datetime.date(1977, 1, 12)),
#  (2, 89, 'La redención de el mar', 'Romance', 99, datetime.date(2002, 12, 17)),
#  (3, 196, 'La resurrección de el río', 'Romance', 138, datetime.date(1993, 7, 27)),
#  (4, 93, 'La canción de la profecía', 'Musical', 101, datetime.date(2021, 3, 8)),
#  (5, 55, 'El laberinto de la estrella fugaz', 'Animación', 85, datetime.date(2022, 8, 4)),
#  (6, 78, 'La escalada de la leyenda', 'Fantasía', 95, datetime.date(2021, 1, 19)),
#  (7, 97, 'El tesoro escondido de la bestia', 'Musical', 93, datetime.date(1976, 5, 9)),
#  (8, 77, 'La canción de la esperanza', 'Acción', 147, datetime.date(2018, 10, 27)),
#  (9, 54, 'La conquista de la corona', 'Animación', 82, datetime.date(1971, 7, 23)),
#  (10, 181, 'El resurgimiento de el misterio', 'Documental', 115, datetime.date(1962, 5, 3)),
#  (11, 111, 'El destino de el viaje', 'Misterio', 141, datetime.date(2006, 11, 19)),
#  (12, 158, 'El eclipse de la senda', 'Documental', 140, datetime.date(1986, 9, 30)),
#  (13, 140, 'La travesía de la venganza', 'Western', 98, datetime.date(2020, 10, 2)),
#  (14, 80, 'El cuento de hadas de la oscuridad', 'Western', 94, datetime.date(1971, 3, 20)),
#  (15, 70, 'La rebelión de el destino', 'Fantasía', 116, datetime.date(1964, 1, 19)),
#  (16, 100, 'La leyenda perdida de la venganza', 'Terror', 140, datetime.date(1975, 4, 12)),
#  (17, 2, 'La llegada de la desgracia', 'Terror', 104, datetime.date(2005, 4, 5)),
#  (18, 186, 'El vuelo mágico de el árbol', 'Western', 118, datetime.date(2021, 11, 28)),
#  (19, 15, 'La metamorfosis de el amor', 'Ciencia ficción', 118, datetime.date(1972, 10, 13)),
#  (20, 138, 'La maldición de el sapo', 'Western', 135, datetime.date(1995, 1, 26)),
#  (21, 21, 'El amanecer de la cripta', 'Comedia', 100, datetime.date(1970, 3, 6)),
#  (22, 129, 'La travesía sin retorno de la gárgola', 'Acción', 134, datetime.date(1997, 5, 11)),
#  (23, 125, 'La trampa de la desgracia', 'Suspense', 114, datetime.date(1984, 1, 15)),
#  (24, 191, 'El camino hacia el horizonte', 'Ciencia ficción', 78, datetime.date(1998, 4, 1)),
#  (25, 190, 'La metamorfosis de el amor', 'Ciencia ficción', 82, datetime.date(1990, 5, 7)),
#  (26, 142, 'El hechizo de el rincón', 'Acción', 83, datetime.date(1978, 12, 3)),
#  (27, 123, 'El viaje de el sol', 'Acción', 74, datetime.date(2013, 9, 22)),
#  (28, 66, 'El arco iris de el susurro', 'Western', 78, datetime.date(2000, 5, 18)),
#  (29, 129, 'La conquista de el árbol', 'Documental', 71, datetime.date(2007, 7, 1)),
#  (30, 123, 'La metamorfosis de la guerra', 'Suspense', 117, datetime.date(2011, 12, 27)),
#  (31, 182, 'El secreto oscuro de la compañía', 'Animación', 108, datetime.date(1970, 5, 17)),
#  (32, 187, 'El espejismo de el viaje', 'Documental', 83, datetime.date(2022, 3, 10)),
#  (33, 149, 'El arco iris de el mito', 'Suspense', 70, datetime.date(1987, 7, 27)),
#  (34, 155, 'El castillo de el horizonte', 'Musical', 89, datetime.date(1984, 1, 29)),
#  (35, 192, 'El caballero de el abismo', 'Acción', 111, datetime.date(1972, 9, 9)),
#  (36, 97, 'La tormenta de la corrupción', 'Acción', 112, datetime.date(2019, 8, 18)),
#  (37, 53, 'El príncipe de el caos', 'Misterio', 70, datetime.date(1976, 12, 14)),
#  (38, 143, 'La fuga de la bestia', 'Terror', 88, datetime.date(2007, 8, 30)),
#  (39, 70, 'La metamorfosis de la profecía', 'Terror', 105, datetime.date(2009, 3, 11)),
#  (40, 115, 'El descubrimiento de la misión', 'Suspense', 70, datetime.date(2022, 3, 12)),
#  (41, 25, 'La travesía del océano de el guardián', 'Romance', 87, datetime.date(1998, 4, 21)),
#  (42, 129, 'La maldición del vampiro de la sirena', 'Acción', 109, datetime.date(2015, 7, 18)),
#  (43, 83, 'El amanecer de el ángel', 'Drama', 77, datetime.date(1990, 5, 8)),
#  (44, 105, 'El prisionero de el secreto', 'Western', 141, datetime.date(1960, 5, 24)),
#  (45, 2, 'La tormenta de la esperanza', 'Misterio', 116, datetime.date(1996, 6, 30)),
#  (46, 55, 'La canción de el monstruo', 'Romance', 147, datetime.date(1975, 2, 7)),
#  (47, 73, 'La sombra de la reina', 'Ciencia ficción', 143, datetime.date(1990, 8, 7)),
#  (48, 157, 'La leyenda perdida de la aventura', 'Animación', 74, datetime.date(1992, 7, 11)),
#  (49, 127, 'El despertar de el río', 'Misterio', 74, datetime.date(1968, 9, 6)),
#  (50, 68, 'El misterio de la luna', 'Drama', 101, datetime.date(1971, 4, 11)),
#  (51, 72, 'El vuelo de el hechicero', 'Animación', 129, datetime.date(1970, 6, 19)),
#  (52, 195, 'La rebelión de la luna', 'Drama', 133, datetime.date(1976, 8, 21)),
#  (53, 70, 'El destino de la soledad', 'Aventura', 114, datetime.date(1960, 10, 5)),
#  (54, 151, 'El renacimiento de la espada', 'Misterio', 120, datetime.date(1998, 8, 1)),
#  (55, 17, 'El refugio de el trono', 'Drama', 143, datetime.date(1982, 3, 27)),
#  (56, 116, 'El camino hacia el monstruo', 'Romance', 79, datetime.date(2003, 7, 20)),
#  (57, 188, 'El caballero de el ángel', 'Western', 121, datetime.date(1974, 10, 24)),
#  (58, 23, 'El destino de la magia', 'Misterio', 105, datetime.date(1970, 10, 6)),
#  (59, 49, 'La metamorfosis de la luna', 'Fantasía', 146, datetime.date(2005, 10, 29)),
#  (60, 127, 'La rebelión de el abismo', 'Musical', 75, datetime.date(2017, 9, 28)),
#  (61, 72, 'La invasión de el camino', 'Musical', 110, datetime.date(2011, 12, 3)),
#  (62, 40, 'El despertar de la bienvenida', 'Comedia', 83, datetime.date(1981, 4, 29)),
#  (63, 45, 'La odisea de el trono', 'Romance', 98, datetime.date(1981, 2, 11)),
#  (64, 12, 'La fuga de el vuelo', 'Suspense', 131, datetime.date(1988, 12, 1)),
#  (65, 144, 'La historia de la tierra', 'Western', 142, datetime.date(2006, 7, 1)),
#  (66, 19, 'La maldición del vampiro de la alianza', 'Drama', 126, datetime.date(1994, 11, 19)),
#  (67, 78, 'El prisionero de la amistad', 'Western', 113, datetime.date(1968, 4, 2)),
#  (68, 167, 'La conquista de la expedición', 'Terror', 95, datetime.date(1960, 11, 12)),
#  (69, 128, 'El despertar de la estrella', 'Suspense', 114, datetime.date(2019, 5, 28)),
#  (70, 148, 'La travesura de el renacimiento', 'Fantasía', 118, datetime.date(2007, 3, 3)),
#  (71, 151, 'La travesura de el león', 'Animación', 136, datetime.date(1980, 5, 22)),
#  (72, 69, 'El último viaje de el peligro', 'Musical', 85, datetime.date(1963, 4, 24)),
#  (73, 197, 'La venganza de el sueño', 'Animación', 139, datetime.date(1980, 1, 13)),
#  (74, 121, 'Las aventuras de el mito', 'Suspense', 78, datetime.date(2005, 5, 13)),
#  (75, 195, 'La leyenda perdida de la pesadilla', 'Suspense', 102, datetime.date(1971, 9, 2)),
#  (76, 187, 'El camino hacia la espada', 'Acción', 78, datetime.date(1978, 3, 27)),
#  (77, 44, 'La senda de el misterio', 'Misterio', 84, datetime.date(1968, 12, 3)),
#  (78, 25, 'La metamorfosis de el susurro', 'Comedia', 116, datetime.date(1973, 3, 17)),
#  (79, 18, 'La estirpe de la despedida', 'Animación', 78, datetime.date(1979, 9, 17)),
#  (80, 174, 'El grito de la batalla', 'Aventura', 96, datetime.date(1995, 8, 7)),
#  (81, 127, 'La historia de el renacer', 'Western', 131, datetime.date(1963, 12, 25)),
#  (82, 174, 'La sombra de la criatura', 'Documental', 128, datetime.date(1972, 3, 16)),
#  (83, 159, 'La cripta de la cripta', 'Musical', 144, datetime.date(1987, 3, 28)),
#  (84, 39, 'La maldición de la estrella', 'Terror', 74, datetime.date(1977, 3, 10)),
#  (85, 16, 'El destino de el mito', 'Ciencia ficción', 146, datetime.date(1983, 12, 23)),
#  (86, 185, 'El bosque encantado de el sueño', 'Terror', 138, datetime.date(2009, 10, 11)),
#  (87, 48, 'El viajero de la esperanza', 'Comedia', 90, datetime.date(1965, 1, 23)),
#  (88, 182, 'La travesía sin retorno de el fuego', 'Drama', 112, datetime.date(2010, 11, 15)),
#  (89, 6, 'La llave de el unicornio', 'Romance', 138, datetime.date(1970, 6, 16)),
#  (90, 79, 'La cripta de la caza', 'Acción', 81, datetime.date(1970, 4, 9)),
#  (91, 93, 'La batalla de la montaña', 'Drama', 143, datetime.date(1987, 8, 16)),
#  (92, 62, 'El despertar de la batalla', 'Comedia', 139, datetime.date(1986, 11, 7)),
#  (93, 54, 'El tesoro escondido de la escuela', 'Fantasía', 142, datetime.date(1960, 2, 6)),
#  (94, 134, 'La danza macabra de el laberinto', 'Comedia', 80, datetime.date(1983, 5, 30)),
#  (95, 85, 'El secreto oscuro de la senda', 'Acción', 150, datetime.date(2011, 10, 29)),
#  (96, 183, 'Las aventuras de el hechizo', 'Ciencia ficción', 107, datetime.date(1962, 2, 19)),
#  (97, 144, 'El prisionero de el guardián', 'Terror', 110, datetime.date(2021, 9, 24)),
#  (98, 148, 'El arco iris de el encuentro', 'Acción', 132, datetime.date(1996, 2, 9)),
#  (99, 107, 'El arco iris de la estrella', 'Drama', 137, datetime.date(2014, 9, 7)),
#  (100, 66, 'El espejismo de la travesía', 'Drama', 113, datetime.date(2016, 8, 6)),
#  (101, 151, 'La búsqueda del tesoro de la bienvenida', 'Ciencia ficción', 132, datetime.date(1974, 2, 7)),
#  (102, 193, 'La misión de la pesadilla', 'Suspense', 106, datetime.date(1973, 6, 13)),
#  (103, 34, 'La estrella fugaz de la paz', 'Ciencia ficción', 82, datetime.date(2020, 12, 9)),
#  (104, 53, 'El renacimiento de el vuelo', 'Documental', 114, datetime.date(1971, 11, 11)),
#  (105, 124, 'La estirpe de el sueño', 'Musical', 89, datetime.date(1975, 9, 29)),
#  (106, 116, 'La metamorfosis de el vuelo', 'Drama', 89, datetime.date(2016, 6, 17)),
#  (107, 189, 'El regreso de el legado', 'Aventura', 112, datetime.date(1967, 9, 1)),
#  (108, 142, 'La conquista de el hechizo', 'Western', 130, datetime.date(1966, 5, 15)),
#  (109, 155, 'La maldición del vampiro de el viajero', 'Terror', 117, datetime.date(2003, 10, 21)),
#  (110, 189, 'La historia de la traición', 'Aventura', 126, datetime.date(1979, 8, 16)),
#  (111, 68, 'La leyenda de el legado', 'Suspense', 122, datetime.date(2006, 8, 4)),
#  (112, 130, 'El viaje de el león', 'Documental', 89, datetime.date(2012, 5, 5)),
#  (113, 77, 'El refugio de la oscuridad', 'Comedia', 141, datetime.date(2008, 6, 11)),
#  (114, 156, 'La conquista de la ola', 'Animación', 112, datetime.date(2018, 12, 31)),
#  (115, 58, 'El resurgimiento de el mago', 'Aventura', 119, datetime.date(1960, 12, 18)),
#  (116, 103, 'La sombra de la batalla', 'Romance', 107, datetime.date(1969, 3, 12)),
#  (117, 158, 'El viaje de la sombra', 'Comedia', 115, datetime.date(1965, 2, 8)),
#  (118, 1, 'El castillo de el bosque', 'Ciencia ficción', 128, datetime.date(1963, 5, 10)),
#  (119, 197, 'La odisea de el puente', 'Animación', 122, datetime.date(1985, 10, 2)),
#  (120, 24, 'El viajero de la pesadilla', 'Misterio', 123, datetime.date(2022, 12, 3)),
#  (121, 168, 'La senda de la cripta', 'Terror', 81, datetime.date(1992, 10, 31)),
#  (122, 157, 'La odisea de la fortuna', 'Romance', 82, datetime.date(1995, 7, 1)),
#  (123, 40, 'El viaje de el sacrificio', 'Documental', 74, datetime.date(1999, 7, 18)),
#  (124, 177, 'El último viaje de el puente', 'Misterio', 127, datetime.date(1986, 8, 23)),
#  (125, 99, 'El secreto de la redención', 'Western', 95, datetime.date(1977, 4, 3)),
#  (126, 54, 'La danza macabra de la cripta', 'Musical', 120, datetime.date(1987, 10, 26)),
#  (127, 112, 'El grito de la bruja', 'Comedia', 129, datetime.date(1963, 8, 3)),
#  (128, 78, 'El pacto de la cárcel', 'Comedia', 97, datetime.date(1994, 7, 12)),
#  (129, 173, 'El último viaje de la esperanza', 'Western', 72, datetime.date(1964, 6, 28)),
#  (130, 147, 'El viajero de la tormenta', 'Suspense', 77, datetime.date(1962, 8, 18)),
#  (131, 92, 'La fuente de la sombra', 'Misterio', 83, datetime.date(1979, 12, 23)),
#  (132, 200, 'El laberinto de la venganza', 'Romance', 82, datetime.date(1969, 11, 24)),
#  (133, 20, 'El secreto oscuro de la princesa', 'Musical', 115, datetime.date(1991, 9, 12)),
#  (134, 165, 'El tesoro escondido de la sirena', 'Documental', 109, datetime.date(2021, 2, 5)),
#  (135, 151, 'El caballero de el explorador', 'Aventura', 82, datetime.date(1965, 5, 16)),
#  (136, 42, 'El viaje de el cielo', 'Musical', 92, datetime.date(2002, 10, 26)),
#  (137, 118, 'La trampa de la pasión', 'Acción', 110, datetime.date(1984, 2, 21)),
#  (138, 126, 'La fortuna de la profecía', 'Drama', 70, datetime.date(1988, 2, 11)),
#  (139, 179, 'El prisionero de la bruja', 'Comedia', 118, datetime.date(2013, 12, 24)),
#  (140, 164, 'El refugio de la estrella', 'Documental', 115, datetime.date(2016, 10, 18)),
#  (141, 173, 'La búsqueda de la prisión', 'Western', 134, datetime.date(1975, 1, 23)),
#  (142, 128, 'La doncella de la montaña', 'Suspense', 74, datetime.date(1985, 4, 14)),
#  (143, 89, 'La invasión de el pacto', 'Aventura', 124, datetime.date(1973, 10, 21)),
#  (144, 163, 'La fuga de el río', 'Comedia', 124, datetime.date(1992, 1, 27)),
#  (145, 27, 'La odisea de el laberinto', 'Animación', 79, datetime.date(1992, 9, 9)),
#  (146, 179, 'La leyenda de el grito', 'Documental', 109, datetime.date(1967, 8, 31)),
#  (147, 18, 'La travesía del océano de la paz', 'Musical', 94, datetime.date(1966, 2, 23)),
#  (148, 163, 'El viajero de el rey', 'Acción', 130, datetime.date(1978, 12, 21)),
#  (149, 35, 'La redención de la libertad', 'Terror', 90, datetime.date(1960, 7, 26)),
#  (150, 55, 'El eclipse de el horizonte', 'Ciencia ficción', 75, datetime.date(1964, 3, 29)),
#  (151, 23, 'La cripta de la desgracia', 'Ciencia ficción', 136, datetime.date(2007, 10, 24)),
#  (152, 197, 'La travesura de la ciudad', 'Suspense', 103, datetime.date(2010, 10, 15)),
#  (153, 93, 'El guardián de la sirena', 'Drama', 143, datetime.date(1971, 5, 8)),
#  (154, 18, 'La danza macabra de el sacrificio', 'Romance', 105, datetime.date(2018, 12, 18)),
#  (155, 69, 'El grito de el laberinto', 'Ciencia ficción', 116, datetime.date(2006, 11, 8)),
#  (156, 125, 'El cuento de hadas de la academia', 'Acción', 80, datetime.date(1982, 2, 22)),
#  (157, 150, 'El tesoro de la pesadilla', 'Romance', 101, datetime.date(1983, 6, 16)),
#  (158, 110, 'El secreto de la trampa', 'Musical', 126, datetime.date(2023, 8, 22)),
#  (159, 179, 'La metamorfosis de el adiós', 'Acción', 138, datetime.date(2007, 2, 11)),
#  (160, 9, 'El ritual de el renacimiento', 'Comedia', 113, datetime.date(1977, 6, 6)),
#  (161, 61, 'La sombra de el peligro', 'Musical', 136, datetime.date(2012, 11, 27)),
#  (162, 11, 'El destino de la guerra', 'Suspense', 135, datetime.date(1996, 6, 25)),
#  (163, 64, 'El enigma de el susurro', 'Aventura', 149, datetime.date(1985, 6, 17)),
#  (164, 39, 'La estirpe de la bailarina', 'Comedia', 147, datetime.date(1969, 12, 30)),
#  (165, 56, 'El despertar de la cárcel', 'Drama', 87, datetime.date(1962, 5, 9)),
#  (166, 114, 'El grito de la selva', 'Comedia', 94, datetime.date(1999, 2, 13)),
#  (167, 106, 'El guardián de el desafío', 'Documental', 90, datetime.date(2010, 12, 3)),
#  (168, 113, 'El eclipse de el castillo', 'Comedia', 72, datetime.date(1968, 10, 20)),
#  (169, 42, 'La estrella fugaz de la redención', 'Romance', 70, datetime.date(1967, 8, 9)),
#  (170, 23, 'El secreto oscuro de la senda', 'Comedia', 100, datetime.date(1998, 8, 19)),
#  (171, 45, 'El espejismo de la maraña', 'Acción', 136, datetime.date(1976, 4, 11)),
#  (172, 23, 'El eclipse de el monstruo', 'Drama', 101, datetime.date(1981, 4, 8)),
#  (173, 187, 'El arco iris de el puente', 'Misterio', 80, datetime.date(1992, 3, 25)),
#  (174, 175, 'El despertar de la oscuridad', 'Terror', 137, datetime.date(1977, 11, 25)),
#  (175, 66, 'La profecía de el río', 'Drama', 137, datetime.date(2020, 7, 21)),
#  (176, 57, 'La búsqueda de la montaña', 'Romance', 116, datetime.date(2014, 4, 15)),
#  (177, 135, 'El príncipe de la caverna', 'Acción', 83, datetime.date(1970, 9, 15)),
#  (178, 14, 'La búsqueda de la paz', 'Fantasía', 74, datetime.date(1960, 12, 22)),
#  (179, 4, 'El pacto de el sacrificio', 'Aventura', 114, datetime.date(2022, 4, 4)),
#  (180, 134, 'La travesía del océano de la trampa', 'Aventura', 110, datetime.date(1969, 3, 11)),
#  (181, 20, 'El misterio de la mariposa', 'Misterio', 141, datetime.date(1977, 9, 18)),
#  (182, 60, 'La leyenda de la bruja', 'Fantasía', 89, datetime.date(1971, 12, 14)),
#  (183, 36, 'El regreso de la isla', 'Acción', 138, datetime.date(1969, 1, 2)),
#  (184, 70, 'La fuente de el rey', 'Acción', 78, datetime.date(1995, 12, 11)),
#  (185, 130, 'La sombra de la princesa', 'Aventura', 142, datetime.date(2003, 2, 3)),
#  (186, 41, 'La tormenta de el río', 'Animación', 72, datetime.date(2003, 6, 21)),
#  (187, 142, 'El castillo de el lobo', 'Romance', 86, datetime.date(2012, 4, 25)),
#  (188, 40, 'El prisionero de la gárgola', 'Terror', 114, datetime.date(2003, 9, 4)),
#  (189, 22, 'La búsqueda del tesoro de la magia', 'Musical', 87, datetime.date(1968, 1, 27)),
#  (190, 11, 'El despertar de la misión', 'Suspense', 79, datetime.date(2020, 12, 28)),
#  (191, 196, 'El bosque encantado de el viajero', 'Suspense', 123, datetime.date(1964, 11, 18)),
#  (192, 21, 'Las aventuras de la isla', 'Terror', 115, datetime.date(1979, 9, 2)),
#  (193, 58, 'La misión de la compañía', 'Musical', 100, datetime.date(2021, 2, 11)),
#  (194, 14, 'La invasión de la oscuridad', 'Western', 108, datetime.date(1978, 8, 5)),
#  (195, 14, 'El amanecer de la cascada', 'Musical', 103, datetime.date(1986, 1, 10)),
#  (196, 163, 'El despertar de el perdón', 'Documental', 71, datetime.date(1991, 2, 15)),
#  (197, 32, 'La rebelión de el cielo', 'Comedia', 96, datetime.date(1980, 10, 22)),
#  (198, 44, 'El enigma de la misión', 'Romance', 140, datetime.date(1964, 7, 2)),
#  (199, 59, 'La profecía de el descubrimiento', 'Comedia', 108, datetime.date(2011, 8, 11)),
#  (200, 27, 'La búsqueda del tesoro de la estrella', 'Terror', 117, datetime.date(1987, 3, 26)),
#  (201, 149, 'La invasión de la amistad', 'Fantasía', 118, datetime.date(2013, 7, 8)),
#  (202, 165, 'La sombra de el laberinto', 'Aventura', 119, datetime.date(1963, 12, 27)),
#  (203, 170, 'El amanecer de la verdad', 'Musical', 129, datetime.date(2008, 2, 26)),
#  (204, 153, 'La profecía de la pesadilla', 'Western', 137, datetime.date(1999, 10, 12)),
#  (205, 48, 'El ritual de la despedida', 'Acción', 121, datetime.date(1970, 11, 17)),
#  (206, 126, 'El grito de el hechicero', 'Ciencia ficción', 94, datetime.date(1983, 1, 28)),
#  (207, 108, 'La fuente de el renacimiento', 'Animación', 102, datetime.date(1984, 10, 23)),
#  (208, 157, 'La fortuna de la salvación', 'Ciencia ficción', 118, datetime.date(1970, 12, 17)),
#  (209, 133, 'El viaje de el león', 'Animación', 101, datetime.date(2009, 7, 2)),
#  (210, 178, 'El destino de la amistad', 'Terror', 88, datetime.date(1978, 1, 17)),
#  (211, 117, 'El despertar de la luz', 'Documental', 140, datetime.date(1965, 12, 21)),
#  (212, 157, 'La canción de la bienvenida', 'Suspense', 102, datetime.date(1961, 6, 13)),
#  (213, 200, 'La resurrección de el laberinto', 'Misterio', 135, datetime.date(2013, 11, 8)),
#  (214, 24, 'La leyenda perdida de la profecía', 'Documental', 89, datetime.date(2017, 5, 25)),
#  (215, 54, 'La doncella de la redención', 'Romance', 85, datetime.date(2015, 2, 1)),
#  (216, 200, 'El enigma de la guerra', 'Romance', 137, datetime.date(2022, 12, 29)),
#  (217, 29, 'El eclipse de el trono', 'Comedia', 121, datetime.date(1994, 9, 6)),
#  (218, 27, 'El vuelo de el puente', 'Misterio', 127, datetime.date(1999, 10, 7)),
#  (219, 150, 'El descubrimiento de la cripta', 'Musical', 89, datetime.date(1961, 6, 2)),
#  (220, 30, 'La danza de la tormenta', 'Comedia', 149, datetime.date(2009, 10, 30)),
#  (221, 6, 'El príncipe de el volcán', 'Drama', 79, datetime.date(2005, 6, 15)),
#  (222, 58, 'La búsqueda del tesoro de el sapo', 'Animación', 108, datetime.date(2018, 8, 11)),
#  (223, 40, 'El refugio de la verdad', 'Suspense', 81, datetime.date(1965, 9, 6)),
#  (224, 81, 'El lamento de el héroe', 'Misterio', 82, datetime.date(1986, 8, 21)),
#  (225, 12, 'El tesoro escondido de la huida', 'Misterio', 100, datetime.date(1963, 8, 20)),
#  (226, 88, 'El camino hacia la profecía', 'Musical', 139, datetime.date(1977, 3, 26)),
#  (227, 33, 'La leyenda de la cripta', 'Western', 127, datetime.date(1973, 9, 8)),
#  (228, 1, 'La tormenta de la oscuridad', 'Acción', 136, datetime.date(2015, 9, 10)),
#  (229, 61, 'La fortuna de la ciudad', 'Western', 84, datetime.date(1992, 8, 16)),
#  (230, 126, 'La maldición de el explorador', 'Documental', 91, datetime.date(1979, 4, 8)),
#  (231, 162, 'El pacto de el río', 'Drama', 142, datetime.date(1964, 1, 12)),
#  (232, 59, 'La travesía sin retorno de la reina', 'Documental', 79, datetime.date(2023, 4, 17)),
#  (233, 41, 'La trampa de la bestia', 'Acción', 99, datetime.date(1963, 4, 3)),
#  (234, 101, 'El ritual de la neblina', 'Western', 77, datetime.date(1971, 8, 24)),
#  (235, 145, 'La travesura de el lamento', 'Drama', 128, datetime.date(1966, 10, 27)),
#  (236, 8, 'El arco iris de la venganza', 'Suspense', 103, datetime.date(1967, 1, 8)),
#  (237, 92, 'El amanecer de la ciudad', 'Acción', 90, datetime.date(1994, 2, 15)),
#  (238, 179, 'El renacimiento de la escuela', 'Musical', 95, datetime.date(1993, 12, 31)),
#  (239, 60, 'La misión de la prisión', 'Ciencia ficción', 111, datetime.date(1996, 9, 1)),
#  (240, 81, 'El lamento de la tierra', 'Documental', 74, datetime.date(1964, 7, 23)),
#  (241, 156, 'El secreto de el hechicero', 'Western', 126, datetime.date(1989, 2, 10)),
#  (242, 103, 'El lamento de el horizonte', 'Fantasía', 138, datetime.date(2020, 12, 10)),
#  (243, 21, 'El príncipe de la salvación', 'Romance', 132, datetime.date(2004, 9, 24)),
#  (244, 108, 'La llegada de el rincón', 'Misterio', 75, datetime.date(2022, 3, 10)),
#  (245, 119, 'La búsqueda del tesoro de la promesa', 'Ciencia ficción', 98, datetime.date(2005, 10, 1)),
#  (246, 127, 'La danza macabra de la traición', 'Drama', 81, datetime.date(2007, 1, 12)),
#  (247, 123, 'El destino de la verdad', 'Animación', 118, datetime.date(1994, 11, 20)),
#  (248, 76, 'El canto de sirena de el rey', 'Documental', 105, datetime.date(2011, 10, 20)),
#  (249, 37, 'El vuelo mágico de el puente', 'Acción', 144, datetime.date(1974, 11, 2)),
#  (250, 116, 'La llave de la academia', 'Acción', 77, datetime.date(1979, 6, 28)),
#  (251, 189, 'El enigma de la revelación', 'Documental', 136, datetime.date(1976, 6, 12)),
#  (252, 58, 'La senda de el susurro', 'Drama', 78, datetime.date(2001, 1, 20)),
#  (253, 139, 'El guardián de el ángel', 'Fantasía', 125, datetime.date(1964, 9, 3)),
#  (254, 26, 'La leyenda perdida de la sirena', 'Fantasía', 134, datetime.date(1971, 6, 26)),
#  (255, 152, 'El eclipse de la ciudad', 'Romance', 94, datetime.date(1981, 1, 11)),
#  (256, 180, 'La travesura de la travesía', 'Terror', 150, datetime.date(1998, 6, 9)),
#  (257, 160, 'El lamento de el trono', 'Romance', 142, datetime.date(1967, 12, 2)),
#  (258, 81, 'El prisionero de el enigma', 'Aventura', 119, datetime.date(2016, 3, 13)),
#  (259, 96, 'La travesura de el peligro', 'Documental', 121, datetime.date(1968, 9, 22)),
#  (260, 107, 'La fortuna de la escuela', 'Ciencia ficción', 72, datetime.date(2010, 2, 7)),
#  (261, 134, 'Las aventuras de el bosque', 'Western', 101, datetime.date(1991, 1, 15)),
#  (262, 19, 'La leyenda de la pesadilla', 'Aventura', 148, datetime.date(2005, 8, 20)),
#  (263, 108, 'El vuelo mágico de el mito', 'Aventura', 140, datetime.date(1988, 12, 18)),
#  (264, 81, 'El cuento de hadas de la puerta', 'Western', 86, datetime.date(1973, 9, 8)),
#  (265, 42, 'El grito de el volcán', 'Fantasía', 125, datetime.date(1989, 10, 11)),
#  (266, 49, 'La tormenta de la traición', 'Misterio', 136, datetime.date(1978, 9, 30)),
#  (267, 78, 'La travesía de la despedida', 'Aventura', 109, datetime.date(1980, 12, 25)),
#  (268, 129, 'La travesía del océano de la montaña', 'Drama', 75, datetime.date(2008, 5, 7)),
#  (269, 190, 'El refugio de la corrupción', 'Romance', 104, datetime.date(1964, 1, 31)),
#  (270, 176, 'La llave de el valle', 'Drama', 116, datetime.date(2007, 8, 26)),
#  (271, 49, 'La redención de la profecía', 'Suspense', 112, datetime.date(1991, 4, 14)),
#  (272, 104, 'El hechizo de la misión', 'Romance', 139, datetime.date(1985, 8, 14)),
#  (273, 6, 'El tesoro de la traición', 'Drama', 89, datetime.date(1976, 12, 7)),
#  (274, 181, 'El prisionero de el sacrificio', 'Animación', 84, datetime.date(2007, 4, 20)),
#  (275, 41, 'La travesía sin retorno de el secreto', 'Fantasía', 75, datetime.date(2014, 12, 1)),
#  (276, 125, 'El descubrimiento de la espada mágica', 'Comedia', 73, datetime.date(1989, 3, 10)),
#  (277, 95, 'El lamento de la verdad', 'Romance', 111, datetime.date(1964, 10, 28)),
#  (278, 113, 'La senda de la pesadilla', 'Ciencia ficción', 79, datetime.date(1964, 12, 30)),
#  (279, 140, 'El cuento de hadas de el guardián', 'Misterio', 121, datetime.date(1970, 10, 24)),
#  (280, 29, 'El misterio de la aventura', 'Aventura', 146, datetime.date(1961, 5, 5)),
#  (281, 45, 'El viaje de el unicornio', 'Suspense', 72, datetime.date(1988, 12, 29)),
#  (282, 123, 'La fuga de la clave', 'Fantasía', 79, datetime.date(1984, 3, 21)),
#  (283, 113, 'La cripta de el atardecer', 'Animación', 107, datetime.date(2023, 12, 2)),
#  (284, 168, 'Las aventuras de la travesía', 'Romance', 146, datetime.date(1970, 11, 4)),
#  (285, 177, 'El príncipe de la montaña', 'Fantasía', 149, datetime.date(2010, 3, 16)),
#  (286, 79, 'El destino de la esperanza', 'Aventura', 150, datetime.date(1974, 5, 26)),
#  (287, 46, 'El eclipse de la bruma', 'Misterio', 74, datetime.date(2016, 9, 28)),
#  (288, 165, 'La misión de la estrella', 'Ciencia ficción', 112, datetime.date(1994, 3, 31)),
#  (289, 156, 'Las aventuras de el camino', 'Western', 127, datetime.date(1974, 5, 2)),
#  (290, 189, 'El vuelo de la prisión', 'Misterio', 74, datetime.date(2008, 5, 30)),
#  (291, 4, 'La leyenda de la desgracia', 'Terror', 100, datetime.date(1987, 5, 5)),
#  (292, 95, 'La resurrección de la bruja', 'Misterio', 124, datetime.date(2011, 6, 5)),
#  (293, 111, 'El viajero de la reina', 'Comedia', 148, datetime.date(1981, 4, 15)),
#  (294, 126, 'El arco iris de la maraña', 'Ciencia ficción', 129, datetime.date(1980, 5, 22)),
#  (295, 61, 'El canto de sirena de la huida', 'Fantasía', 76, datetime.date(1981, 3, 23)),
#  (296, 47, 'La maldición de la mariposa', 'Terror', 85, datetime.date(1984, 1, 10)),
#  (297, 92, 'El misterio de el susurro', 'Comedia', 88, datetime.date(1975, 9, 3)),
#  (298, 156, 'La misión de el mago', 'Aventura', 99, datetime.date(1979, 8, 5)),
#  (299, 159, 'La escalada de la guerra', 'Animación', 114, datetime.date(2001, 7, 28)),
#  (300, 31, 'El regreso de la bienvenida', 'Suspense', 98, datetime.date(1983, 7, 12))]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
