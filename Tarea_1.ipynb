# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Daniela Aguilar - 202111060-7
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlparse in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: prettytable in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: six in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: ipython in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: stack-data in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: matplotlib-inline in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: exceptiongroup in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (1.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: decorator in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: colorama in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: wcwidth in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: psycopg2 in c:\users\ferna\appdata\local\programs\python\python310\lib\site-packages (2.9.4)
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB
# Out:
# env: DATABASE_URL=postgresql://postgres:Quintero@localhost:5432/tareaDB

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tareaDB',
   password="Quintero"
)
print(conn)
# Out:
# <connection object at 0x0000017630346BD0; dsn: 'user=postgres password=xxx dbname=tareaDB host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE Director(
#     id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
#
# CREATE TABLE Actor(
#     id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
#
# CREATE TABLE Pelicula(
#     id_pelicula INT GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula, id_director),
#     FOREIGN KEY (id_director) REFERENCES Director(id_director),
#     UNIQUE(id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula(
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_director(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES Director(id_director)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_actor(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_actor) REFERENCES Actor(id_actor)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_pelicula(
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     anio INT NOT NULL,
#     FOREIGN KEY (id_pelicula) REFERENCES Pelicula(id_pelicula)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1971, 'director': 10, 'genero': 'Suspense', 'cast': [53], 'mejor pelicula': 'no'}, 2: {'año': 1976, 'director': 62, 'genero': 'Ciencia ficción', 'cast': [158, 55], 'mejor pelicula': 'no'}, 3: {'año': 1965, 'director': 148, 'genero': 'Acción', 'cast': [9], 'mejor pelicula': 'no'}, 4: {'año': 2022, 'director': 54, 'genero': 'Misterio', 'cast': [115], 'mejor pelicula': 'no'}, 5: {'año': 1984, 'director': 153, 'genero': 'Aventura', 'cast': [169], 'mejor pelicula': 'no'}, 6: {'año': 1982, 'director': 103, 'genero': 'Western', 'cast': [101], 'mejor pelicula': 'no'}, 7: {'año': 2014, 'director': 49, 'genero': 'Acción', 'cast': [27, 192], 'mejor pelicula': 'no'}, 8: {'año': 2004, 'director': 193, 'genero': 'Ciencia ficción', 'cast': [69], 'mejor pelicula': 'no'}, 9: {'año': 1975, 'director': 194, 'genero': 'Ciencia ficción', 'cast': [122, 83, 34], 'mejor pelicula': 'no'}, 10: {'año': 2002, 'director': 111, 'genero': 'Misterio', 'cast': [199], 'mejor pelicula': 'no'}, 11: {'año': 1960, 'director': 95, 'genero': 'Romance', 'cast': [2], 'mejor pelicula': 'no'}, 12: {'año': 2003, 'director': 18, 'genero': 'Misterio', 'cast': [195], 'mejor pelicula': 'no'}, 13: {'año': 1962, 'director': 20, 'genero': 'Drama', 'cast': [109, 86], 'mejor pelicula': 'no'}, 14: {'año': 1992, 'director': 64, 'genero': 'Acción', 'cast': [143, 158], 'mejor pelicula': 'no'}, 15: {'año': 1988, 'director': 49, 'genero': 'Documental', 'cast': [189], 'mejor pelicula': 'no'}, 16: {'año': 1977, 'director': 160, 'genero': 'Drama', 'cast': [33, 165, 132], 'mejor pelicula': 'no'}, 17: {'año': 1967, 'director': 8, 'genero': 'Documental', 'cast': [36, 147], 'mejor pelicula': 'no'}, 18: {'año': 2008, 'director': 198, 'genero': 'Animación', 'cast': [181, 169], 'mejor pelicula': 'no'}, 19: {'año': 1983, 'director': 150, 'genero': 'Animación', 'cast': [14, 98, 64], 'mejor pelicula': 'no'}, 20: {'año': 1963, 'director': 187, 'genero': 'Western', 'cast': [179], 'mejor pelicula': 'no'}, 21: {'año': 1999, 'director': 131, 'genero': 'Drama', 'cast': [111, 197], 'mejor pelicula': 'no'}, 22: {'año': 1978, 'director': 116, 'genero': 'Musical', 'cast': [190, 49], 'mejor pelicula': 'no'}, 23: {'año': 2005, 'director': 73, 'genero': 'Misterio', 'cast': [146, 3, 145], 'mejor pelicula': 'no'}, 24: {'año': 1974, 'director': 117, 'genero': 'Drama', 'cast': [48, 45, 128], 'mejor pelicula': 'no'}, 25: {'año': 2004, 'director': 28, 'genero': 'Terror', 'cast': [180, 27], 'mejor pelicula': 'no'}, 26: {'año': 1975, 'director': 1, 'genero': 'Ciencia ficción', 'cast': [195, 117], 'mejor pelicula': 'no'}, 27: {'año': 1991, 'director': 94, 'genero': 'Ciencia ficción', 'cast': [24, 39], 'mejor pelicula': 'no'}, 28: {'año': 1966, 'director': 23, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 29: {'año': 1996, 'director': 185, 'genero': 'Musical', 'cast': [55, 126], 'mejor pelicula': 'no'}, 30: {'año': 2017, 'director': 138, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 31: {'año': 1990, 'director': 79, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 32: {'año': 1967, 'director': 10, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 33: {'año': 1964, 'director': 39, 'genero': 'Fantasía', 'cast': [194], 'mejor pelicula': 'no'}, 34: {'año': 1995, 'director': 191, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 35: {'año': 1960, 'director': 98, 'genero': 'Comedia', 'cast': [116], 'mejor pelicula': 'no'}, 36: {'año': 2013, 'director': 66, 'genero': 'Documental', 'cast': [193, 150, 92], 'mejor pelicula': 'no'}, 37: {'año': 2023, 'director': 52, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 38: {'año': 1970, 'director': 23, 'genero': 'Terror', 'cast': [198, 4, 189], 'mejor pelicula': 'no'}, 39: {'año': 2011, 'director': 93, 'genero': 'Acción', 'cast': [170], 'mejor pelicula': 'no'}, 40: {'año': 1982, 'director': 90, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 41: {'año': 2016, 'director': 188, 'genero': 'Western', 'ca ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nombre as "Nombre"
# FROM
#     Pelicula
# WHERE
#     extract(Year from fecha_publicacion) >= 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 4 rows affected.
# [('La historia de la perdición',),
#  ('La odisea de el secreto',),
#  ('El canto de sirena de la caza',),
#  ('La travesía sin retorno de el destino',)]

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     nombre as "Nombre", fecha_publicacion as "Fecha de publicación"
# FROM
#     pelicula
# WHERE
#     genero = 'Drama' and extract(year from fecha_publicacion) = 2023;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# SELECT
#     actor.nombre as "Nombre"
# FROM
#     pelicula
# INNER JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN
#     actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# WHERE
#     genero = 'Comedia'
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 27 rows affected.
# [('Elena Hidalgo',),
#  ('Akira Xu',),
#  ('Jin Bianchi',),
#  ('Tatiana Wu',),
#  ('Tatiana Quintana',),
#  ('Giovanni Duarte',),
#  ('Chiyoko Mendes',),
#  ('Isa Vieira',),
#  ('Jasmin Alvarez',),
#  ('Tatiana Quintana',),
#  ('Tatjana Qian',),
#  ('Elena Fernandes',),
#  ('Quentin Joaquim',),
#  ('Orhan Nguyen',),
#  ('Alessandro Carvalho',),
#  ('Kamala Nguyen',),
#  ('Gustavo Janssen',),
#  ('Wang Teixeira',),
#  ('Tatiana Qian',),
#  ('Umar Jimenez',),
#  ('Quentin Queiroz',),
#  ('Emiko Queiroz',),
#  ('Abdullah Inácio',),
#  ('Aarav Estevez',),
#  ('Salim Teixeira',),
#  ('Wang Zhang',),
#  ('Patricia Abadi',)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.genero as "Género",COUNT(pelicula.genero) AS "Cantidad de premios"
# FROM
#     pelicula INNER JOIN premio_mejor_pelicula ON pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# GROUP BY
#     pelicula.genero
# ORDER BY
#     COUNT(pelicula.genero) DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 13 rows affected.
# [('Western', 5),
#  ('Romance', 4),
#  ('Animación', 4),
#  ('Terror', 3),
#  ('Misterio', 3),
#  ('Aventura', 3),
#  ('Ciencia ficción', 3),
#  ('Musical', 3),
#  ('Acción', 2),
#  ('Drama', 2),
#  ('Documental', 1),
#  ('Suspense', 1),
#  ('Comedia', 1)]

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre",COUNT(pelicula.nombre) as "Cantidad de actores"
# FROM
#     pelicula
# INNER JOIN
#     actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# GROUP BY
#     pelicula.nombre
# HAVING
#     COUNT(pelicula.nombre)>=2
# ORDER BY
#     COUNT(pelicula.nombre) DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 146 rows affected.
# [('La trampa de la guerra', 6),
#  ('La senda de el rey', 6),
#  ('El lamento de el puente', 6),
#  ('La travesura de la flor', 5),
#  ('El eclipse de el puente', 5),
#  ('El guardián de la escuela', 5),
#  ('La metamorfosis de el amanecer', 5),
#  ('La tormenta de el bosque', 5),
#  ('El resurgimiento de la bestia', 4),
#  ('El cuento de hadas de el misterio', 4),
#  ('La fuga de la aventura', 4),
#  ('La maldición de la criatura', 4),
#  ('El camino hacia la aldea', 4),
#  ('El canto de sirena de el muro', 4),
#  ('La invasión de el viaje', 4),
#  ('La conquista de el peligro', 4),
#  ('La maldición del vampiro de la corrupción', 4),
#  ('La canción de la gárgola', 4),
#  ('El cuento de hadas de el abismo', 4),
#  ('El prisionero de el guerrero', 4),
#  ('La leyenda de la aventura', 4),
#  ('La profecía de el sacrificio', 4),
#  ('La estrella fugaz de el camino', 4),
#  ('El refugio de el viajero', 4),
#  ('La invasión de la cascada', 4),
#  ('La resurrección de la prisión', 4),
#  ('El príncipe de la criatura', 3),
#  ('El viaje de la compañía', 3),
#  ('La venganza de la ola', 3),
#  ('El prisionero de el hechicero', 3),
#  ('La senda de la magia', 3),
#  ('La búsqueda del tesoro de la bruja', 3),
#  ('La leyenda perdida de la muralla', 3),
#  ('La fuga de la esperanza', 3),
#  ('La canción de la bestia', 3),
#  ('La doncella de el sueño', 3),
#  ('La danza de la bruja', 3),
#  ('La estrella fugaz de la profecía', 3),
#  ('El canto de sirena de el amor', 3),
#  ('El refugio de la promesa', 3),
#  ('El guardián de el peligro', 3),
#  ('El secreto oscuro de la alianza', 3),
#  ('La fortuna de la oscuridad', 3),
#  ('La venganza de el amor', 3),
#  ('La leyenda perdida de el sacrificio', 3),
#  ('El eclipse de el árbol', 3),
#  ('La búsqueda del tesoro de el mago', 3),
#  ('La estirpe de el misterio', 3),
#  ('La maldición de la batalla', 3),
#  ('El destino de la pesadilla', 3),
#  ('La travesura de el muro', 3),
#  ('La fortuna de el puente', 3),
#  ('La trampa de el amanecer', 3),
#  ('La estrella fugaz de la senda', 3),
#  ('La sombra de el horizonte', 3),
#  ('El último viaje de la tormenta', 3),
#  ('El lamento de el renacimiento', 3),
#  ('La travesía de la noche', 3),
#  ('La travesía sin retorno de el destino', 3),
#  ('La metamorfosis de la bruja', 3),
#  ('La venganza de el atardecer', 3),
#  ('El canto de sirena de la traición', 3),
#  ('La metamorfosis de el encuentro', 3),
#  ('La redención de el laberinto', 3),
#  ('La metamorfosis de el guerrero', 3),
#  ('El ritual de la aventura', 3),
#  ('La sombra de el vuelo', 3),
#  ('El resurgimiento de la espada mágica', 3),
#  ('La travesía de el árbol', 3),
#  ('El caballero de la magia', 3),
#  ('El resurgimiento de la tormenta', 3),
#  ('El tesoro escondido de el valle', 3),
#  ('La historia de la maraña', 3),
#  ('El secreto de la aventura', 3),
#  ('La leyenda de la bruma', 3),
#  ('El destino de la batalla', 2),
#  ('La maldición del vampiro de la espada mágica', 2),
#  ('La fuente de la oscuridad', 2),
#  ('La misión de la guerra', 2),
#  ('El viajero de el hechizo', 2),
#  ('La travesía del océano de el susurro', 2),
#  ('La trampa de la aldea', 2),
#  ('La leyenda de la luz', 2),
#  ('La danza de la isla', 2),
#  ('La travesura de el trono', 2),
#  ('La profecía de el jardín', 2),
#  ('El arco iris de el faro', 2),
#  ('El canto de sirena de la caza', 2),
#  ('El secreto oscuro de el dragón', 2),
#  ('El canto de sirena de la redención', 2),
#  ('El canto de sirena de la heroína', 2),
#  ('Las aventuras de la pesadilla', 2),
#  ('El bosque encantado de la princesa', 2),
#  ('La maldición del vampiro de la cascada', 2),
#  ('La odisea de el mar', 2),
#  ('El grito de el guardián', 2),
#  ('El ritual de la espada', 2),
#  ('El arco iris de la aventura', 2),
#  ('La estrella fugaz de la prisión', 2),
#  ('El cuento de hadas de la resistencia', 2),
#  ('La senda de el tesoro', 2),
#  ('La búsqueda del tesoro de la batalla', 2),
#  ('La travesía sin retorno de el ángel', 2),
#  ('La búsqueda de la guerra', 2),
#  ('El renacimiento de el rincón', 2),
#  ('El tesoro escondido de el león', 2),
#  ('El amanecer de la oscuridad', 2),
#  ('La travesura de el tesoro', 2),
#  ('El vuelo de la traición', 2),
#  ('El tesoro escondido de el bosque', 2),
#  ('El amanecer de el héroe', 2),
#  ('La doncella de la revelación', 2),
#  ('La danza de el desafío', 2),
#  ('La llave de el descubrimiento', 2),
#  ('La llave de la bienvenida', 2),
#  ('El guardián de la bruja', 2),
#  ('El laberinto de la sirena', 2),
#  ('El refugio de el faro', 2),
#  ('La escalada de el faro', 2),
#  ('La rebelión de la cueva', 2),
#  ('La llegada de la senda', 2),
#  ('El prisionero de la travesía', 2),
#  ('La metamorfosis de el rincón', 2),
#  ('La odisea de la compañía', 2),
#  ('La canción de el sol', 2),
#  ('El último viaje de la batalla', 2),
#  ('El secreto de el guardián', 2),
#  ('La leyenda de el sol', 2),
#  ('Las aventuras de la flor', 2),
#  ('La fuente de la guerra', 2),
#  ('El castillo de la alianza', 2),
#  ('El ritual de el dragón', 2),
#  ('La rebelión de el tesoro', 2),
#  ('El ritual de la fortuna', 2),
#  ('La fuente de el valle', 2),
#  ('La resurrección de el laberinto', 2),
#  ('La tormenta de la alianza', 2),
#  ('El último viaje de el héroe', 2),
#  ('La odisea de la redención', 2),
#  ('El último viaje de la magia', 2),
#  ('El cuento de hadas de el viajero', 2),
#  ('El tesoro de la magia', 2),
#  ('El camino hacia el sol', 2),
#  ('El regreso de la luz', 2),
#  ('La escalada de la compañía', 2),
#  ('La odisea de el susurro', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** Se obtienen el nombre de la pelicula, edad del actor más joven y la edad del actor más viejo de la intersección entre las tablas pelicula, actor_participa_en_pelicula y actor, inmedietamente ordenamos la tabla resultante en función de la diferencia de edad entre el actor más viejo y más joven y limitamos el número de filas a 1.

# %%
# %%sql
# SELECT
#     pelicula.nombre as "Nombre",MIN(actor.edad) as "Edad del actor más joven",MAX(actor.edad) as "Edad del actor más viejo"
# FROM pelicula
# INNER JOIN actor_participa_en_pelicula ON pelicula.id_pelicula = actor_participa_en_pelicula.id_pelicula
# INNER JOIN actor ON actor_participa_en_pelicula.id_actor = actor.id_actor
# GROUP BY pelicula.nombre
# ORDER BY MAX(actor.edad) - MIN(actor.edad) DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 1 rows affected.
# [('El canto de sirena de el muro', 16, 69)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT premio_mejor_pelicula.anio as "Año", premio_mejor_pelicula.id_pelicula as "id_pelicula"
# FROM (
#     SELECT *
#     FROM pelicula
#     ORDER BY pelicula.duracion desc
#     limit 1
# ) as pelicula
# inner JOIN premio_mejor_pelicula on pelicula.id_pelicula = premio_mejor_pelicula.id_pelicula
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 1 rows affected.
# [(None, None)]

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     auxiliar.nombreActor as "Nombre del actor",
#     auxiliar.nDirectores as "Cantidad de directores",
#     pelicula.nombre as "Nombre de una pelicula"
# FROM
#     (select actor.nombre as nombreActor, actor.id_actor as idActor, COUNT(director.id_director) as nDirectores
#     FROM actor
#     INNER JOIN actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
#     INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
#     INNER JOIN director ON pelicula.id_director = director.id_director
#     GROUP BY actor.id_actor
#     HAVING COUNT(director.id_director) >= 2
#     ) as auxiliar
# INNER JOIN actor_participa_en_pelicula ON auxiliar.idActor = actor_participa_en_pelicula.id_actor
# INNER JOIN pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# GROUP BY auxiliar.nombreActor,pelicula.nombre,auxiliar.nDirectores
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 460 rows affected.
# [('Giovanni Alvarez', 4, 'El último viaje de la tormenta'),
#  ('Emiko Queiroz', 6, 'El ritual de la espada'),
#  ('Kamala Estevez', 4, 'El canto de sirena de el muro'),
#  ('Tatjana Santana', 5, 'La estrella fugaz de el camino'),
#  ('Rashid Montenegro', 3, 'La sombra de el horizonte'),
#  ('Valeria Henriquez', 3, 'La búsqueda del tesoro de la bruja'),
#  ('Akira Inácio', 3, 'La metamorfosis de el guerrero'),
#  ('Fabiana Urbina', 4, 'La danza de el desafío'),
#  ('Jasmin Duarte', 4, 'El lamento de el misterio'),
#  ('Bianca Olivares', 4, 'El renacimiento de la aventura'),
#  ('Chiyoko Mendes', 2, 'La estrella fugaz de la revelación'),
#  ('Emiko Wu', 3, 'La maldición del vampiro de la cascada'),
#  ('Fabiana Urbina', 4, 'El enigma de el encuentro'),
#  ('Tatjana Santana', 5, 'La estirpe de la pesadilla'),
#  ('Natalia Martinez', 2, 'La doncella de el sueño'),
#  ('Isa Pacheco', 3, 'La odisea de la redención'),
#  ('Bianca Olivares', 4, 'La fortuna de el puente'),
#  ('Quintus Lopes', 3, 'La invasión de el viaje'),
#  ('Han Iglesias', 5, 'El cuento de hadas de el misterio'),
#  ('Tatiana Qian', 4, 'La venganza de el amor'),
#  ('Lakshmi Abadi', 5, 'La fuente de la guerra'),
#  ('Akira Olivares', 4, 'El cuento de hadas de el abismo'),
#  ('Parvati Inácio', 3, 'El vuelo mágico de el lamento'),
#  ('Genghis Diniz', 4, 'La senda de el rey'),
#  ('Ilya Zhang', 3, 'El camino hacia la aldea'),
#  ('Pilar Ivanov', 3, 'El amanecer de la oscuridad'),
#  ('Akira Martinez', 3, 'El guardián de la escuela'),
#  ('Giovanni Duarte', 3, 'El cuento de hadas de el misterio'),
#  ('Valeria Wu', 2, 'La travesura de el tesoro'),
#  ('Elena Hidalgo', 5, 'El ritual de el dragón'),
#  ('Gustavo Yilmaz', 2, 'La leyenda de la bruma'),
#  ('Gustavo Urbina', 2, 'El lamento de el puente'),
#  ('Wang Zhang', 2, 'La trampa de el amanecer'),
#  ('Natalia Duarte', 3, 'La conquista de el lamento'),
#  ('Wan Carvalho', 4, 'El guardián de la escuela'),
#  ('Mehmet Goncalves', 4, 'El grito de el destino'),
#  ('Leticia Urbina', 2, 'El canto de sirena de el amor'),
#  ('Ilya Yan', 2, 'La venganza de la ola'),
#  ('Abdullah Jimenez', 4, 'La trampa de la guerra'),
#  ('Theresa Pereira', 3, 'El guardián de el peligro'),
#  ('Chiyoko Queiroz', 5, 'La travesía de la prisión'),
#  ('Chiyoko Queiroz', 5, 'La leyenda perdida de el sacrificio'),
#  ('Yuri Uchoa', 4, 'La canción de la bestia'),
#  ('Elena Fernandes', 2, 'El refugio de la promesa'),
#  ('Han Barros', 7, 'La resurrección de el cielo'),
#  ('Irina Santos', 4, 'La búsqueda del tesoro de el mago'),
#  ('Wang Martinez', 5, 'La resurrección de el laberinto'),
#  ('Quintus Lopes', 3, 'La metamorfosis de el amanecer'),
#  ('Elena Hidalgo', 5, 'El resurgimiento de la bestia'),
#  ('Valeria Sousa', 2, 'El tesoro escondido de el bosque'),
#  ('Yuri Uchoa', 4, 'El grito de el guardián'),
#  ('Han Barros', 7, 'La danza de el desafío'),
#  ('Quintus Diniz', 4, 'La odisea de la redención'),
#  ('Akira Xu', 6, 'La llegada de la venganza'),
#  ('Mehmet Goncalves', 4, 'La doncella de el sueño'),
#  ('Patricia Figueiredo', 2, 'El destino de la pesadilla'),
#  ('Omar Ivanov', 4, 'La profecía de el jardín'),
#  ('Leticia Urbina', 2, 'La estirpe de el misterio'),
#  ('Tatiana Diniz', 4, 'El príncipe de el renacer'),
#  ('Darya Jimenez', 5, 'La danza de la bruja'),
#  ('Tatiana Quintana', 4, 'El regreso de la luz'),
#  ('Theresa Pereira', 3, 'El cuento de hadas de la resistencia'),
#  ('Emiko Queiroz', 6, 'La odisea de la compañía'),
#  ('Akira Martinez', 3, 'El bosque encantado de la princesa'),
#  ('Darya Alvarez', 2, 'El lamento de el renacimiento'),
#  ('Yasmin Olivares', 3, 'La maldición de la criatura'),
#  ('Akira Inácio', 3, 'La senda de el tesoro'),
#  ('Elif Ramos', 2, 'El eclipse de el sacrificio'),
#  ('Valeria Wu', 2, 'La fuga de la aventura'),
#  ('Orhan Urbina', 2, 'La escalada de el faro'),
#  ('Ilya Zhang', 3, 'El prisionero de el hechicero'),
#  ('Orhan Uchoa', 2, 'La resurrección de la prisión'),
#  ('Oscar Joaquim', 4, 'La cripta de la montaña'),
#  ('Natalia Duarte', 3, 'El arco iris de el puente'),
#  ('Akira Xu', 6, 'El viajero de el hechizo'),
#  ('Lakshmi Abadi', 5, 'La profecía de el sacrificio'),
#  ('Valeria Sousa', 2, 'La odisea de el mar'),
#  ('Quintus Diniz', 4, 'El tesoro de el misterio'),
#  ('Valeria Lopes', 4, 'El secreto oscuro de el dragón'),
#  ('Valeria Lopes', 4, 'La maldición de la criatura'),
#  ('Alessandro Diniz', 2, 'El bosque encantado de el descubrimiento'),
#  ('Alessandro Lopez', 2, 'La travesía sin retorno de la tormenta'),
#  ('Rashid Montenegro', 3, 'La travesía de la noche'),
#  ('Abdullah Inácio', 3, 'El arco iris de el ángel'),
#  ('Omar Teixeira', 3, 'La invasión de el viaje'),
#  ('Nina Petrov', 5, 'La travesía de la esperanza'),
#  ('Elena Hidalgo', 5, 'El vuelo de la traición'),
#  ('Chiyoko Queiroz', 5, 'El resurgimiento de la ciudad'),
#  ('Mehmet Nguyen', 3, 'La trampa de la aldea'),
#  ('Mikhail Montenegro', 2, 'El príncipe de la criatura'),
#  ('Tatiana Wu', 3, 'La trampa de la guerra'),
#  ('Wan Carvalho', 4, 'La canción de la gárgola'),
#  ('Jasmin Henriquez', 2, 'La travesía del océano de el susurro'),
#  ('Quentin Queiroz', 2, 'El caballero de la magia'),
#  ('Jin Gao', 3, 'El vuelo de la puerta'),
#  ('Qiu Xia', 2, 'La canción de el sol'),
#  ('Genghis Diniz', 4, 'El refugio de la caza'),
#  ('Aarav Estevez', 5, 'La travesura de el trono'),
#  ('Wang Yan', 5, 'El arco iris de el faro'),
#  ('Patricia Figueiredo', 2, 'El canto de sirena de la traición'),
#  ('Yuri Uchoa', 4, 'La fuga de la aventura'),
#  ('Pilar Rodriguez', 2, 'La trampa de la guerra'),
#  ('Han Iglesias', 5, 'El refugio de el faro'),
#  ('Umar Jimenez', 5, 'La venganza de el atardecer'),
#  ('Jasmin Alvarez', 4, 'El guardián de la bailarina'),
#  ('Pilar Ivanov', 3, 'La leyenda perdida de el sacrificio'),
#  ('Leticia Ramos', 2, 'La tormenta de el bosque'),
#  ('Alessandro Carvalho', 2, 'La trampa de la guerra'),
#  ('Ilya Zhang', 3, 'La fortuna de la ley'),
#  ('Wang Martinez', 5, 'La leyenda de la aventura'),
#  ('Emiko Queiroz', 6, 'El camino hacia la isla'),
#  ('Tatiana Quintana', 4, 'El refugio de la promesa'),
#  ('Aarav Urbina', 3, 'El canto de sirena de la heroína'),
#  ('Omar Ivanov', 4, 'La maldición de la batalla'),
#  ('Han Barros', 7, 'La maldición de la batalla'),
#  ('Beatriz Zambrano', 3, 'El último viaje de la batalla'),
#  ('Lakshmi Santana', 3, 'La llave de la bienvenida'),
#  ('Umar Jimenez', 5, 'El príncipe de la puerta'),
#  ('Kamala Nunes', 3, 'El secreto de el renacer'),
#  ('Aarav Estevez', 5, 'El último viaje de la tormenta'),
#  ('Nina Petrov', 5, 'El camino hacia la aldea'),
#  ('Genghis Diniz', 4, 'La travesura de el tesoro'),
#  ('Oscar Martinez', 3, 'El último viaje de el héroe'),
#  ('Quentin Carvalho', 4, 'El ritual de la espada'),
#  ('Bianca Henriquez', 4, 'El guardián de la fortuna'),
#  ('Umberto Nogueira', 3, 'La rebelión de el tesoro'),
#  ('Bianca Olivares', 4, 'El enigma de el guerrero'),
#  ('Umar Jimenez', 5, 'La travesura de el rey'),
#  ('Tatjana Santana', 5, 'El guardián de la bruja'),
#  ('Giovanni Hernandez', 2, 'El ritual de la aventura'),
#  ('Emiko Wu', 3, 'La llave de el descubrimiento'),
#  ('Emiko Uchoa', 3, 'La canción de la gárgola'),
#  ('Orhan Nguyen', 5, 'El camino hacia el sol'),
#  ('Jasmin Alvarez', 4, 'El ritual de el dragón'),
#  ('Yusef Bianchi', 3, 'El cuento de hadas de el misterio'),
#  ('Gustavo Pereira', 4, 'La travesía de la noche'),
#  ('Gustavo Janssen', 5, 'La venganza de el atardecer'),
#  ('Genghis Velez', 6, 'La historia de la maraña'),
#  ('Rania Gao', 2, 'La fuente de la oscuridad'),
#  ('Tatiana Diniz', 4, 'La travesura de el muro'),
#  ('Bianca Olivares', 4, 'La metamorfosis de el amanecer'),
#  ('Wang Yan', 5, 'El camino hacia la aldea'),
#  ('Elena Hidalgo', 5, 'La travesura de la flor'),
#  ('Rashid Mendes', 4, 'La canción de la bestia'),
#  ('Patricia Inácio', 2, 'El canto de sirena de la redención'),
#  ('Omar Ivanov', 4, 'La profecía de el sacrificio'),
#  ('Genghis Velez', 6, 'La leyenda perdida de la muralla'),
#  ('Akira Urbina', 3, 'La invasión de el viaje'),
#  ('Gustavo Urbina', 2, 'La venganza de la sonrisa'),
#  ('Quintus Diniz', 4, 'La travesía del océano de el hechizo'),
#  ('Salim Hidalgo', 5, 'La metamorfosis de el rincón'),
#  ('Emiko Yamamoto', 5, 'La fortuna de la guerra'),
#  ('Valeria Henriquez', 3, 'El castillo de la alianza'),
#  ('Wang Yan', 5, 'La búsqueda del tesoro de el mago'),
#  ('Mehmet Nguyen', 3, 'El despertar de el amor'),
#  ('Oscar Martinez', 3, 'La llegada de la pasión'),
#  ('Patricia Abadi', 4, 'El tesoro escondido de el valle'),
#  ('Elif Queiroz', 2, 'La trampa de la aldea'),
#  ('Kamala Nguyen', 3, 'El resurgimiento de la bestia'),
#  ('Bianca Henriquez', 4, 'La rebelión de la bienvenida'),
#  ('Patricia Bianchi', 3, 'El bosque encantado de la montaña'),
#  ('Mehmet Nguyen', 3, 'La fortuna de el puente'),
#  ('Wang Yan', 5, 'El ritual de la fortuna'),
#  ('Salim Teixeira', 2, 'La batalla de la promesa'),
#  ('Rania Gao', 2, 'La travesura de el muro'),
#  ('Lakshmi Abadi', 5, 'La cripta de la tormenta'),
#  ('Fabiana Estevez', 2, 'El guardián de el peligro'),
#  ('Akira Olivares', 4, 'La leyenda perdida de la muralla'),
#  ('Akira Martinez', 3, 'El canto de sirena de la heroína'),
#  ('Zafar Rodriguez', 3, 'La metamorfosis de el rincón'),
#  ('Emiko Yamamoto', 5, 'La maldición de la guerra'),
#  ('Oscar Joaquim', 4, 'El prisionero de el hechicero'),
#  ('Mikhail Borges', 3, 'El cuento de hadas de el misterio'),
#  ('Abdullah Inácio', 3, 'La fortuna de la oscuridad'),
#  ('Akira Inácio', 3, 'El guardián de la escuela'),
#  ('Natalia Duarte', 3, 'La búsqueda del tesoro de la batalla'),
#  ('Salim Hidalgo', 5, 'La travesura de el trono'),
#  ('Jasmin Henriquez', 2, 'El arco iris de la aventura'),
#  ('Yusef Bianchi', 3, 'El eclipse de el árbol'),
#  ('Nina Petrov', 5, 'La venganza de el amor'),
#  ('Kamala Nunes', 3, 'El espejismo de la escuela'),
#  ('Darya Jimenez', 5, 'El último viaje de el héroe'),
#  ('Darius Yilmaz', 4, 'El espejismo de la criatura'),
#  ('Abdullah Inácio', 3, 'La leyenda de la luz'),
#  ('Patricia Abadi', 4, 'El pacto de el guardián'),
#  ('Mina Mendes', 2, 'El guardián de la escuela'),
#  ('Qiu Correia', 3, 'La invasión de el viaje'),
#  ('Oscar Martinez', 3, 'La danza de la isla'),
#  ('Isa Pacheco', 3, 'El cuento de hadas de el abismo'),
#  ('Leticia Ramos', 2, 'La senda de el rey'),
#  ('Wang Yan', 5, 'La travesura de la heroína'),
#  ('Yasmin Olivares', 3, 'La leyenda de la bruma'),
#  ('Tatiana Diniz', 4, 'La estrella fugaz de la prisión'),
#  ('Gustavo Janssen', 5, 'El tesoro escondido de el valle'),
#  ('Quintus Dutta', 2, 'La conquista de el peligro'),
#  ('Han Barros', 7, 'La estrella fugaz de la senda'),
#  ('Mina Mendes', 2, 'La leyenda de la aventura'),
#  ('Yusef Bianchi', 3, 'La búsqueda del tesoro de la bruja'),
#  ('Isa Pacheco', 3, 'El viaje de el hechicero'),
#  ('Aarav Urbina', 3, 'La estrella fugaz de la profecía'),
#  ('Mikhail Borges', 3, 'El secreto oscuro de la perdición'),
#  ('Kamala Estevez', 4, 'El resurgimiento de la tormenta'),
#  ('Emiko Yamamoto', 5, 'El secreto oscuro de el laberinto'),
#  ('Yasmin Olivares', 3, 'La misión de la guerra'),
#  ('Rashid Montenegro', 3, 'La leyenda perdida de la muralla'),
#  ('Tatjana Abadi', 2, 'El vuelo de la traición'),
#  ('Gustavo Janssen', 5, 'El canto de sirena de la caza'),
#  ('Omar Lima', 6, 'La estrella fugaz de la profecía'),
#  ('Tatiana Qian', 4, 'La estirpe de el misterio'),
#  ('Kamala Estevez', 4, 'La travesía de el árbol'),
#  ('Xavier Etxebarria', 2, 'La maldición del vampiro de la corrupción'),
#  ('Giovanni Alvarez', 4, 'La resurrección de la prisión'),
#  ('Patricia Abadi', 4, 'La metamorfosis de el amanecer'),
#  ('Pilar Yan', 2, 'La sombra de el vuelo'),
#  ('Tatjana Qian', 2, 'La búsqueda del tesoro de la batalla'),
#  ('Omar Teixeira', 3, 'La danza de la bruja'),
#  ('Akira Olivares', 4, 'La travesía sin retorno de el ángel'),
#  ('Wan Carvalho', 4, 'El canto de sirena de la caza'),
#  ('Rashid Olivares', 2, 'El laberinto de la sirena'),
#  ('Jin Gao', 3, 'La travesía de el árbol'),
#  ('Giovanni Hernandez', 2, 'El refugio de el viajero'),
#  ('Xin Xia', 3, 'La travesía del océano de el susurro'),
#  ('Hiroko Ramos', 2, 'El resurgimiento de la bestia'),
#  ('Rashid Olivares', 2, 'La metamorfosis de la bruja'),
#  ('Abdullah Jimenez', 4, 'La búsqueda del tesoro de la bruja'),
#  ('Chen Hernandez', 2, 'El vuelo de la tierra'),
#  ('Rania Diniz', 2, 'El pacto de el sapo'),
#  ('Emiko Uchoa', 3, 'La estrella fugaz de el camino'),
#  ('Darya Diniz', 3, 'El castillo de la trampa'),
#  ('Isa Vieira', 3, 'La rebelión de la escuela'),
#  ('Mina Wu', 2, 'El resurgimiento de la espada mágica'),
#  ('Darya Diniz', 3, 'El resurgimiento de la sombra'),
#  ('Chen Hernandez', 2, 'La maldición del vampiro de la corrupción'),
#  ('Tatjana Santana', 5, 'El secreto de la aventura'),
#  ('Jasmin Duarte', 4, 'El ritual de la aventura'),
#  ('Gustavo Janssen', 5, 'La canción de la gárgola'),
#  ('Xin Xia', 3, 'La búsqueda del tesoro de el mago'),
#  ('Tatiana Quintana', 4, 'El viaje de la compañía'),
#  ('Natalia Martinez', 2, 'El prisionero de el guerrero'),
#  ('Chiyoko Queiroz', 5, 'La fuga de la esperanza'),
#  ('Quentin Carvalho', 4, 'La resurrección de la estrella'),
#  ('Fabiana Urbina', 4, 'La historia de la maraña'),
#  ('Genghis Velez', 6, 'La conquista de el peligro'),
#  ('Lakshmi Santana', 3, 'La estrella fugaz de la profecía'),
#  ('Yasmin Figueiredo', 3, 'El príncipe de la bestia'),
#  ('Emiko Queiroz', 6, 'El tesoro escondido de el león'),
#  ('Quentin Carvalho', 4, 'El secreto de el mar'),
#  ('Umar Jimenez', 5, 'El guardián de la escuela'),
#  ('Irina Santos', 4, 'El secreto oscuro de la alianza'),
#  ('Darya Jimenez', 5, 'La senda de el rey'),
#  ('Mehmet Goncalves', 4, 'La tormenta de el bosque'),
#  ('Xavier Etxebarria', 2, 'El hechizo de la esperanza'),
#  ('Fabiana Urbina', 4, 'La senda de el rey'),
#  ('Samir Ferreira', 4, 'La odisea de el mar'),
#  ('Theresa Pereira', 3, 'La rebelión de el tesoro'),
#  ('Ilya Yan', 2, 'La travesura de la flor'),
#  ('Quentin Queiroz', 2, 'Las aventuras de la aventura'),
#  ('Valeria Henriquez', 3, 'La llegada de la senda'),
#  ('Valeria Lopes', 4, 'La escalada de la compañía'),
#  ('Jin Gao', 3, 'La escalada de la compañía'),
#  ('Oscar Joaquim', 4, 'La llegada de la senda'),
#  ('Nina Petrov', 5, 'La fortuna de la oscuridad'),
#  ('Zafar Rodriguez', 3, 'La senda de la magia'),
#  ('Chiyoko Queiroz', 5, 'El cuento de hadas de la resistencia'),
#  ('Zafar Rodriguez', 3, 'Las aventuras de la flor'),
#  ('Hiroko Henriquez', 3, 'La travesía de la bailarina'),
#  ('Fabiana Estevez', 2, 'El destino de la pesadilla'),
#  ('Patricia Inácio', 2, 'La fuga de la esperanza'),
#  ('Genghis Velez', 6, 'El tesoro de la magia'),
#  ('Patricia Bianchi', 3, 'El canto de sirena de el amor'),
#  ('Emiko Yamamoto', 5, 'La fuente de la guerra'),
#  ('Akira Xu', 6, 'La metamorfosis de la bruja'),
#  ('Alessandro Carvalho', 2, 'El laberinto de la sirena'),
#  ('Jin Mendes', 2, 'Las aventuras de la pesadilla'),
#  ('Darya Jimenez', 5, 'El lamento de el renacimiento'),
#  ('Omar Teixeira', 3, 'La fortuna de la oscuridad'),
#  ('Leonardo Iglesias', 4, 'La leyenda de la aventura'),
#  ('Jin Mendes', 2, 'El último viaje de la tormenta'),
#  ('Genghis Velez', 6, 'La redención de la bestia'),
#  ('Samir Ferreira', 4, 'El destino de el sapo'),
#  ('Genghis Inácio', 3, 'La odisea de el susurro'),
#  ('Pilar Zhang', 3, 'El resurgimiento de la tormenta'),
#  ('Jin Teixeira', 2, 'La travesía sin retorno de el destino'),
#  ('Beatriz Zambrano', 3, 'La rebelión de la cueva'),
#  ('Sakura Nguyen', 2, 'El camino hacia el sol'),
#  ('Elif Ramos', 2, 'La sombra de el vuelo'),
#  ('Parvati Inácio', 3, 'El renacimiento de el rincón'),
#  ('Leonardo Iglesias', 4, 'La canción de la gárgola'),
#  ('Darius Yilmaz', 4, 'El lamento de el puente'),
#  ('Xin Barros', 2, 'La metamorfosis de el guerrero'),
#  ('Mina Wu', 2, 'El camino hacia la aldea'),
#  ('Valeria Lopes', 4, 'El arco iris de la aventura'),
#  ('Wang Zhang', 2, 'La doncella de la revelación'),
#  ('Alessandro Lopez', 2, 'La metamorfosis de el encuentro'),
#  ('Darius Yilmaz', 4, 'La leyenda perdida de el amor'),
#  ('Han Abadi', 3, 'La leyenda de la luz'),
#  ('Hiroko Ramos', 2, 'La travesura de la flor'),
#  ('Aarav Estevez', 5, 'La tormenta de la alianza'),
#  ('Tatjana Zapata', 3, 'La invasión de la cascada'),
#  ('Sakura Pacheco', 2, 'La odisea de el susurro'),
#  ('Tatjana Qian', 2, 'El viaje de la compañía'),
#  ('Lakshmi Abadi', 5, 'El tesoro escondido de el león'),
#  ('Yasmin Figueiredo', 3, 'El resurgimiento de la espada mágica'),
#  ('Tatiana Qian', 4, 'La trampa de el amanecer'),
#  ('Emiko Queiroz', 6, 'El prisionero de el hechicero'),
#  ('Darya Jimenez', 5, 'La invasión de la senda'),
#  ('Gustavo Janssen', 5, 'La trampa de la guerra'),
#  ('Alessandro Diniz', 2, 'La maldición del vampiro de la espada mágica'),
#  ('Hiroko Henriquez', 3, 'El secreto oscuro de el dragón'),
#  ('Tatjana Zapata', 3, 'El resurgimiento de la bestia'),
#  ('Rashid Mendes', 4, 'La senda de el rey'),
#  ('Tatiana Diniz', 4, 'El canto de sirena de el muro'),
#  ('Akira Santos', 2, 'La leyenda de el sol'),
#  ('Han Abadi', 3, 'El secreto oscuro de la alianza'),
#  ('Bianca Henriquez', 4, 'La profecía de el jardín'),
#  ('Akira Xu', 6, 'La danza de la bruja'),
#  ('Jasmin Duarte', 4, 'El eclipse de el puente'),
#  ('Irina Inácio', 2, 'La búsqueda del tesoro de la muralla'),
#  ('Orhan Nguyen', 5, 'La llave de la bienvenida'),
#  ('Darya Pereira', 3, 'El regreso de la luz'),
#  ('Gustavo Yilmaz', 2, 'La travesura de el muro'),
#  ('Abdullah Jimenez', 4, 'El grito de el guardián'),
#  ('Qiu Xia', 2, 'El último viaje de la batalla'),
#  ('Beatriz Zambrano', 3, 'La travesía sin retorno de el destino'),
#  ('Quintus Lopes', 3, 'El secreto oscuro de la alianza'),
#  ('Ximena Xu', 2, 'El secreto de la aventura'),
#  ('Leonardo Iglesias', 4, 'El amanecer de la oscuridad'),
#  ('Jin Bianchi', 4, 'El destino de la batalla'),
#  ('Khaled Yilmaz', 2, 'La conquista de el peligro'),
#  ('Chiyoko Mendes', 2, 'La resurrección de la prisión'),
#  ('Omar Lima', 6, 'La maldición de la criatura'),
#  ('Xin Barros', 2, 'La metamorfosis de el amanecer'),
#  ('Han Iglesias', 5, 'La rebelión de la cueva'),
#  ('Emiko Wu', 3, 'La fuga de el árbol'),
#  ('Parvati Inácio', 3, 'El eclipse de el puente'),
#  ('Quintus Diniz', 4, 'La canción de la bestia'),
#  ('Jin Bianchi', 4, 'El secreto oscuro de la estrella'),
#  ('Tatiana Wu', 3, 'El ritual de la aventura'),
#  ('Orhan Nguyen', 5, 'El tesoro escondido de el bosque'),
#  ('Wang Martinez', 5, 'El lamento de el puente'),
#  ('Tatjana Abadi', 2, 'El secreto de la aventura'),
#  ('Omar Lima', 6, 'La escalada de el faro'),
#  ('Giovanni Alvarez', 4, 'La venganza de la ola'),
#  ('Han Barros', 7, 'La llave de el descubrimiento'),
#  ('Samir Ferreira', 4, 'La redención de el laberinto'),
#  ('Omar Lima', 6, 'La maldición del vampiro de la corrupción'),
#  ('Ximena Xu', 2, 'El guardián de el peligro'),
#  ('Rania Diniz', 2, 'El eclipse de el puente'),
#  ('Genghis Velez', 6, 'La odisea de la compañía'),
#  ('Mehmet Goncalves', 4, 'La travesura de la flor'),
#  ('Emiko Yamamoto', 5, 'El grito de la esperanza'),
#  ('Giovanni Duarte', 3, 'El caballero de la magia'),
#  ('Sakura Pacheco', 2, 'El cuento de hadas de el renacer'),
#  ('Orhan Nguyen', 5, 'El cuento de hadas de el abismo'),
#  ('Abdullah Jimenez', 4, 'La invasión de la cascada'),
#  ('Genghis Inácio', 3, 'La fuga de la esperanza'),
#  ('Akira Xu', 6, 'La travesía sin retorno de el ángel'),
#  ('Elena Fernandes', 2, 'El eclipse de el árbol'),
#  ('Tatiana Wu', 3, 'El príncipe de la criatura'),
#  ('Qiu Correia', 3, 'El tesoro escondido de la desgracia'),
#  ('Jasmin Lopez', 2, 'La fuente de el valle'),
#  ('Darya Pereira', 3, 'La maldición del vampiro de la cascada'),
#  ('Omar Ivanov', 4, 'La trampa de el sol'),
#  ('Kamala Nunes', 3, 'El cuento de hadas de el viajero'),
#  ('Pilar Zhang', 3, 'La maldición de el sueño'),
#  ('Leonardo Iglesias', 4, 'La leyenda de la bruma'),
#  ('Lakshmi Santana', 3, 'El canto de sirena de el muro'),
#  ('Omar Lima', 6, 'El destino de la pesadilla'),
#  ('Oscar Joaquim', 4, 'La sombra de el horizonte'),
#  ('Gustavo Pereira', 4, 'El arco iris de el faro'),
#  ('Darya Alvarez', 2, 'El último viaje de la magia'),
#  ('Irina Santos', 4, 'La leyenda de la aventura'),
#  ('Darius Mendes', 2, 'El prisionero de el guerrero'),
#  ('Ximena Olivares', 3, 'La travesura de la flor'),
#  ('Giovanni Alvarez', 4, 'La canción de el sol'),
#  ('Emiko Queiroz', 6, 'La resurrección de la prisión'),
#  ('Genghis Inácio', 3, 'El refugio de el faro'),
#  ('Jasmin Duarte', 4, 'El príncipe de la criatura'),
#  ('Jin Bianchi', 4, 'El tesoro de la magia'),
#  ('Han Iglesias', 5, 'La doncella de el sueño'),
#  ('Pilar Yan', 2, 'La metamorfosis de el amanecer'),
#  ('Akira Urbina', 3, 'La maldición de la criatura'),
#  ('Tatiana Quintana', 4, 'El prisionero de el guerrero'),
#  ('Salim Hidalgo', 5, 'La profecía de el sacrificio'),
#  ('Aarav Estevez', 5, 'La búsqueda de la guerra'),
#  ('Han Barros', 7, 'El secreto de el guardián'),
#  ('Nina Petrov', 5, 'El vuelo mágico de la estrella'),
#  ('Omar Lima', 6, 'El lamento de el puente'),
#  ('Vivek Yan', 2, 'El secreto de el guardián'),
#  ('Rashid Mendes', 4, 'El secreto oscuro de el viaje'),
#  ('Gustavo Pereira', 4, 'La fuente de el valle'),
#  ('Patricia Abadi', 4, 'El amanecer de el jardín'),
#  ('Wang Martinez', 5, 'La metamorfosis de la bruja'),
#  ('Mikhail Montenegro', 2, 'La trampa de el puente'),
#  ('Akira Santos', 2, 'El ritual de la fortuna'),
#  ('Samir Ferreira', 4, 'El destino de el caos'),
#  ('Lakshmi Abadi', 5, 'La venganza de la ola'),
#  ('Quintus Dutta', 2, 'La llegada de la estrella'),
#  ('Han Abadi', 3, 'La maldición de la batalla'),
#  ('Sakura Nguyen', 2, 'La profecía de el sacrificio'),
#  ('Isa Vieira', 3, 'La travesía de la noche'),
#  ('Ximena Olivares', 3, 'La redención de el laberinto'),
#  ('Salim Hidalgo', 5, 'El guardián de la bruma'),
#  ('Qiu Correia', 3, 'El despertar de el abismo'),
#  ('Elena Hidalgo', 5, 'El cuento de hadas de el viajero'),
#  ('Tatiana Qian', 4, 'La travesía sin retorno de el destino'),
#  ('Orhan Urbina', 2, 'La venganza de el misterio'),
#  ('Akira Xu', 6, 'La fuente de la oscuridad'),
#  ('Akira Urbina', 3, 'La sombra de el horizonte'),
#  ('Darya Pereira', 3, 'La estrella fugaz de la senda'),
#  ('Jasmin Lopez', 2, 'La estrella fugaz de el camino'),
#  ('Tatjana Santana', 5, 'La senda de el tesoro'),
#  ('Aarav Urbina', 3, 'La estrella fugaz de el camino'),
#  ('Jin Bianchi', 4, 'El caballero de la magia'),
#  ('Genghis Diniz', 4, 'El vuelo de la travesía'),
#  ('Jin Teixeira', 2, 'La leyenda de el sol'),
#  ('Vivek Yan', 2, 'La misión de la guerra'),
#  ('Umberto Nogueira', 3, 'La redención de el laberinto'),
#  ('Pilar Zhang', 3, 'El refugio de el viajero'),
#  ('Wang Martinez', 5, 'El bosque encantado de la princesa'),
#  ('Darius Mendes', 2, 'La venganza de el amor'),
#  ('Irina Santos', 4, 'La tormenta de el mar'),
#  ('Darya Diniz', 3, 'La doncella de la revelación'),
#  ('Hiroko Henriquez', 3, 'El regreso de la caza'),
#  ('Kamala Estevez', 4, 'La historia de la maraña'),
#  ('Darius Yilmaz', 4, 'La estrella fugaz de la senda'),
#  ('Xin Xia', 3, 'El misterio de la profecía'),
#  ('Salim Teixeira', 2, 'El viajero de el hechizo'),
#  ('Jasmin Alvarez', 4, 'El prisionero de la travesía'),
#  ('Bianca Henriquez', 4, 'La danza de la isla'),
#  ('Umberto Nogueira', 3, 'La tormenta de la alianza'),
#  ('Han Iglesias', 5, 'El prisionero de la travesía'),
#  ('Jasmin Alvarez', 4, 'La fuga de la aventura'),
#  ('Umar Jimenez', 5, 'La escalada de la oscuridad'),
#  ('Khaled Yilmaz', 2, 'La senda de el rey'),
#  ('Yasmin Figueiredo', 3, 'El viajero de la selva'),
#  ('Kamala Nguyen', 3, 'El tesoro escondido de el valle'),
#  ('Emiko Uchoa', 3, 'El misterio de el caos'),
#  ('Akira Olivares', 4, 'El guardián de la bruja'),
#  ('Yuri Uchoa', 4, 'La metamorfosis de el guerrero'),
#  ('Pilar Ivanov', 3, 'La invasión de la cascada'),
#  ('Rashid Mendes', 4, 'La metamorfosis de el encuentro'),
#  ('Kamala Nguyen', 3, 'La maldición del vampiro de la corrupción'),
#  ('Orhan Uchoa', 2, 'El resurgimiento de la tormenta'),
#  ('Wan Carvalho', 4, 'La tormenta de el bosque'),
#  ('Isa Vieira', 3, 'El refugio de la promesa'),
#  ('Patricia Bianchi', 3, 'La tormenta de el bosque'),
#  ('Han Barros', 7, 'La llave de el unicornio'),
#  ('Giovanni Duarte', 3, 'El refugio de el viajero'),
#  ('Irina Inácio', 2, 'La venganza de el atardecer'),
#  ('Orhan Nguyen', 5, 'El viaje de la compañía'),
#  ('Quentin Carvalho', 4, 'La estrella fugaz de la prisión'),
#  ('Pilar Rodriguez', 2, 'El eclipse de el puente'),
#  ('Ximena Olivares', 3, 'La metamorfosis de el encuentro'),
#  ('Tatjana Zapata', 3, 'El destino de la batalla'),
#  ('Elif Queiroz', 2, 'La invasión de la cascada'),
#  ('Gustavo Pereira', 4, 'El amanecer de el héroe'),
#  ('Aarav Estevez', 5, 'La llave de la sirena'),
#  ('Mikhail Borges', 3, 'La trampa de la guerra'),
#  ('Salim Hidalgo', 5, 'El amanecer de el héroe')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT actor.nombre as "Nombre"
# FROM actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# WHERE
#     director.id_director = 1
# GROUP BY
#     actor.nombre
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 6 rows affected.
# [('Alessandro Lopez',),
#  ('Hiroko Henriquez',),
#  ('Jasmin Henriquez',),
#  ('Mikhail Borges',),
#  ('Valeria Lopes',),
#  ('Xin Xia',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre AS "Nombre del actor",
#     pelicula.nombre AS "Nombre de la Pelicula",
#     director.nombre AS "Nombre del director",
#     COUNT(pelicula.id_pelicula) AS "Número de películas del director",
#     COUNT(premio_mejor_director.id_premio) AS "Número de premios del director"
# FROM actor
# INNER JOIN
#     actor_participa_en_pelicula ON actor.id_actor = actor_participa_en_pelicula.id_actor
# INNER JOIN
#     pelicula ON actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula
# INNER JOIN
#     director ON pelicula.id_director = director.id_director
# LEFT JOIN
#     premio_mejor_director ON director.id_director = premio_mejor_director.id_director
# WHERE NOT EXISTS(
#     SELECT 1
#     FROM premio_mejor_actor
#     WHERE actor.id_actor = premio_mejor_actor.id_actor
# )
# GROUP BY
#     actor.nombre,pelicula.nombre, director.nombre;
# Out:
#  * postgresql://postgres:***@localhost:5432/tareaDB
# 407 rows affected.
# [('Hiroko Henriquez', 'La travesía de la bailarina', 'Katarina Ramos', 1, 0),
#  ('Darya Diniz', 'La doncella de la revelación', 'Sakura Gao', 1, 0),
#  ('Bianca Olivares', 'La fortuna de el puente', 'Oscar Oliveira', 1, 0),
#  ('Leticia Ramos', 'La senda de el rey', 'Zafar Carvalho', 1, 0),
#  ('Tatjana Zapata', 'La invasión de la cascada', 'Yusef Yilmaz', 3, 3),
#  ('Leonardo Iglesias', 'El amanecer de la oscuridad', 'Alessandro Janssen', 1, 0),
#  ('Akira Olivares', 'La travesía sin retorno de el ángel', 'Aarav Quintana', 1, 0),
#  ('Gustavo Janssen', 'La canción de la gárgola', 'Bianca Diniz', 2, 2),
#  ('Abdullah Jimenez', 'El grito de el guardián', 'Hiroko Ramos', 1, 0),
#  ('Chen Hernandez', 'La maldición del vampiro de la corrupción', 'Jasmin Teixeira', 1, 0),
#  ('Khaled Yilmaz', 'La senda de el rey', 'Zafar Carvalho', 1, 0),
#  ('Rashid Montenegro', 'La leyenda perdida de la muralla', 'Zoya Hernandez', 1, 1),
#  ('Aarav Estevez', 'La travesura de el trono', 'Jasmin Teixeira', 1, 0),
#  ('Han Abadi', 'La maldición de la batalla', 'Orhan Velez', 1, 0),
#  ('Omar Ivanov', 'La maldición de la batalla', 'Orhan Velez', 1, 0),
#  ('Mehmet Goncalves', 'La doncella de el sueño', 'Leticia Correia', 1, 0),
#  ('Elif Queiroz', 'La trampa de la aldea', 'Wang Hidalgo', 1, 0),
#  ('Chiyoko Mendes', 'La estrella fugaz de la revelación', 'Sakura Ferreira', 1, 0),
#  ('Chiyoko Mendes', 'La resurrección de la prisión', 'Rosa Vargas', 1, 1),
#  ('Wang Teixeira', 'La trampa de el amanecer', 'Orhan Velez', 1, 0),
#  ('Qiu Xia', 'El último viaje de la batalla', 'Qiu Gao', 1, 0),
#  ('Hiroko Ramos', 'La travesura de la flor', 'Irina Xavier', 1, 1),
#  ('Mikhail Borges', 'La trampa de la guerra', 'Wang Diniz', 1, 0),
#  ('Fabiana Urbina', 'La danza de el desafío', 'Quentin Esteves', 1, 1),
#  ('Bianca Olivares', 'El renacimiento de la aventura', 'Ilya Yan', 1, 0),
#  ('Quentin Carvalho', 'El secreto de el mar', 'Xin Ferreira', 1, 0),
#  ('Qiu Xia', 'La canción de el sol', 'Alessandro Urbina', 1, 0),
#  ('Elena Fernandes', 'El eclipse de el árbol', 'Genghis Xavier', 1, 0),
#  ('Yasmin Figueiredo', 'El príncipe de la bestia', 'Tatjana Santana', 1, 0),
#  ('Jasmin Duarte', 'El ritual de la aventura', 'Abdullah Ivanov', 1, 0),
#  ('Ilya Zhang', 'El prisionero de el hechicero', 'Abdullah Uchoa', 1, 0),
#  ('Tatjana Santana', 'La estirpe de la pesadilla', 'Yusef Yilmaz', 3, 3),
#  ('Darius Yilmaz', 'La estrella fugaz de la senda', 'Salim Montenegro', 1, 0),
#  ('Natalia Duarte', 'La conquista de el lamento', 'Bianca Vieira', 1, 0),
#  ('Tatjana Qian', 'El viaje de la compañía', 'Emiko Yan', 1, 1),
#  ('Sakura Nguyen', 'La profecía de el sacrificio', 'Chiyoko Lopes', 1, 1),
#  ('Gustavo Janssen', 'El canto de sirena de la caza', 'Salim Montenegro', 1, 0),
#  ('Lakshmi Mendes', 'El eclipse de el árbol', 'Genghis Xavier', 1, 0),
#  ('Gustavo Janssen', 'El tesoro escondido de el valle', 'Yasmin Joaquim', 1, 1),
#  ('Orhan Urbina', 'La venganza de el misterio', 'Khaled Hidalgo', 1, 0),
#  ('Beatriz Zambrano', 'El último viaje de la batalla', 'Qiu Gao', 1, 0),
#  ('Emiko Queiroz', 'La odisea de la compañía', 'Natalia Dutta', 1, 0),
#  ('Kamala Estevez', 'La travesía de el árbol', 'Elena Kawaguchi', 1, 0),
#  ('Irina Santos', 'El secreto oscuro de la alianza', 'Qiu Urbina', 2, 2),
#  ('Giovanni Alvarez', 'La resurrección de la prisión', 'Rosa Vargas', 1, 1),
#  ('Aarav Estevez', 'La tormenta de la alianza', 'Isa Watanabe', 1, 0),
#  ('Elena Hidalgo', 'El ritual de el dragón', 'Hiroko Queiroz', 1, 0),
#  ('Hiroko Pacheco', 'La leyenda perdida de el sacrificio', 'Isa Vieira', 1, 0),
#  ('Jasmin Duarte', 'El príncipe de la criatura', 'Oscar Zapata', 1, 0),
#  ('Darya Pereira', 'El regreso de la luz', 'Rania Esteves', 1, 0),
#  ('Mina Zapata', 'El canto de sirena de la redención', 'Kamala Vargas', 1, 1),
#  ('Hiroko Henriquez', 'El secreto oscuro de el dragón', 'Wan Urbina', 1, 0),
#  ('Abdullah Jimenez', 'La trampa de la guerra', 'Wang Diniz', 1, 0),
#  ('Pilar Zhang', 'El refugio de el viajero', 'Alessandro Teixeira', 1, 0),
#  ('Patricia Bianchi', 'El canto de sirena de el amor', 'Jin Olivares', 1, 0),
#  ('Valeria Henriquez', 'La búsqueda del tesoro de la bruja', 'Mina Gao', 1, 0),
#  ('Akira Inácio', 'El guardián de la escuela', 'Qiu Oliveira', 1, 0),
#  ('Emiko Queiroz', 'El camino hacia la isla', 'Tatiana Quintana', 1, 0),
#  ('Leonardo Iglesias', 'La leyenda de la aventura', 'Xavier Goncalves', 1, 1),
#  ('Leticia Ramos', 'La tormenta de el bosque', 'Wang Rocha', 1, 1),
#  ('Gustavo Yilmaz', 'La leyenda de la bruma', 'Natalia Dutta', 1, 0),
#  ('Giovanni Xia', 'La resurrección de el laberinto', 'Hiroko Queiroz', 1, 0),
#  ('Samir Ferreira', 'La redención de el laberinto', 'Quentin Ramos', 1, 0),
#  ('Fabiana Urbina', 'La historia de la maraña', 'Quentin Ramos', 1, 0),
#  ('Valeria Lopes', 'El arco iris de la aventura', 'Katarina Carvalho', 1, 0),
#  ('Alessandro Diniz', 'La maldición del vampiro de la espada mágica', 'Fadhila Kawaguchi', 1, 0),
#  ('Jin Gao', 'La escalada de la compañía', 'Yasmin Zapata', 1, 0),
#  ('Tatiana Wu', 'El ritual de la aventura', 'Abdullah Ivanov', 1, 0),
#  ('Pilar Yan', 'La sombra de el vuelo', 'Aarav Quintana', 1, 0),
#  ('Quintus Diniz', 'La canción de la bestia', 'Mehmet Nguyen', 1, 0),
#  ('Vivek Yan', 'La misión de la guerra', 'Orhan Hernandez', 1, 0),
#  ('Kamala Estevez', 'La historia de la maraña', 'Quentin Ramos', 1, 0),
#  ('Quintus Lopes', 'La invasión de el viaje', 'Parvati Zambrano', 1, 0),
#  ('Chen Hernandez', 'El vuelo de la tierra', 'Orhan Almeida', 1, 0),
#  ('Mehmet Goncalves', 'El grito de el destino', 'Mina Oliveira', 1, 0),
#  ('Quentin Joaquim', 'La redención de la resistencia', 'Wang Martinez', 1, 0),
#  ('Omar Ivanov', 'La profecía de el sacrificio', 'Chiyoko Lopes', 1, 1),
#  ('Han Barros', 'La resurrección de el cielo', 'Leonardo Oliveira', 1, 0),
#  ('Pilar Zhang', 'El resurgimiento de la tormenta', 'Akira Borges', 1, 0),
#  ('Han Barros', 'La estrella fugaz de la senda', 'Salim Montenegro', 1, 0),
#  ('Aarav Urbina', 'La estrella fugaz de la profecía', 'Wang Queiroz', 1, 0),
#  ('Emiko Wu', 'La maldición del vampiro de la cascada', 'Sakura Gao', 1, 0),
#  ('Mehmet Goncalves', 'La tormenta de el bosque', 'Wang Rocha', 1, 1),
#  ('Emiko Uchoa', 'La canción de la gárgola', 'Bianca Diniz', 2, 2),
#  ('Fatemeh Zhang', 'La leyenda perdida de el castillo', 'Tatjana Jimenez', 1, 0),
#  ('Hiroko Henriquez', 'El regreso de la caza', 'Theresa Watanabe', 1, 0),
#  ('Umberto Nogueira', 'La redención de el laberinto', 'Quentin Ramos', 1, 0),
#  ('Emiko Queiroz', 'El ritual de la espada', 'Qiu Henriquez', 1, 1),
#  ('Abdullah Jimenez', 'La invasión de la cascada', 'Yusef Yilmaz', 3, 3),
#  ('Giovanni Duarte', 'El cuento de hadas de el misterio', 'Chiyoko Inácio', 1, 0),
#  ('Omar Ivanov', 'La trampa de el sol', 'Qiu Gao', 1, 0),
#  ('Irina Inácio', 'La búsqueda del tesoro de la muralla', 'Rashid Kumar', 1, 0),
#  ('Mikhail Borges', 'El cuento de hadas de el misterio', 'Chiyoko Inácio', 1, 0),
#  ('Ximena Xu', 'El secreto de la aventura', 'Parvati Vargas', 1, 0),
#  ('Wang Zhang', 'La doncella de la revelación', 'Sakura Gao', 1, 0),
#  ('Parvati Inácio', 'El renacimiento de el rincón', 'Wan Kumar', 1, 0),
#  ('Mina Wu', 'El camino hacia la aldea', 'Rania Martinez', 1, 0),
#  ('Akira Inácio', 'La metamorfosis de el guerrero', 'Quentin Esteves', 1, 1),
#  ('Akira Urbina', 'La invasión de el viaje', 'Parvati Zambrano', 1, 0),
#  ('Darya Diniz', 'El castillo de la trampa', 'Chiyoko Teles', 1, 0),
#  ('Rashid Mendes', 'La metamorfosis de el encuentro', 'Qiu Oliveira', 1, 0),
#  ('Xavier Etxebarria', 'La maldición del vampiro de la corrupción', 'Jasmin Teixeira', 1, 0),
#  ('Quintus Diniz', 'La travesía del océano de el hechizo', 'Rashid Wu', 1, 1),
#  ('Emiko Yamamoto', 'La fuente de la guerra', 'Beatriz Montenegro', 1, 0),
#  ('Patricia Bianchi', 'El bosque encantado de la montaña', 'Wang Martinez', 1, 0),
#  ('Quentin Carvalho', 'La resurrección de la estrella', 'Giovanni Zapata', 1, 0),
#  ('Quentin Queiroz', 'Las aventuras de la aventura', 'Yusef Yilmaz', 3, 3),
#  ('Salim Teixeira', 'La batalla de la promesa', 'Sakura Almeida', 1, 0),
#  ('Tatiana Quintana', 'El prisionero de el guerrero', 'Akira Borges', 1, 0),
#  ('Rashid Mendes', 'El secreto oscuro de el viaje', 'Alessandro Teixeira', 1, 0),
#  ('Tatjana Abadi', 'El secreto de la aventura', 'Parvati Vargas', 1, 0),
#  ('Oscar Martinez', 'El último viaje de el héroe', 'Oscar Fernandes', 1, 1),
#  ('Jin Teixeira', 'La travesía sin retorno de el destino', 'Alessandro Urbina', 1, 0),
#  ('Yusef Bianchi', 'La búsqueda del tesoro de la bruja', 'Mina Gao', 1, 0),
#  ('Theresa Nogueira', 'El renacimiento de el rincón', 'Wan Kumar', 1, 0),
#  ('Sakura Pacheco', 'El cuento de hadas de el renacer', 'Elena Kawaguchi', 1, 0),
#  ('Bianca Henriquez', 'El guardián de la fortuna', 'Theresa Watanabe', 1, 0),
#  ('Tatiana Quintana', 'El refugio de la promesa', 'Pilar Uchoa', 1, 0),
#  ('Darius Yilmaz', 'La leyenda perdida de el amor', 'Tatjana Jimenez', 1, 0),
#  ('Kamala Cruz', 'El último viaje de la magia', 'Wang Queiroz', 1, 0),
#  ('Hiroko Ramos', 'El resurgimiento de la bestia', 'Kamala Vargas', 1, 1),
#  ('Lakshmi Montenegro', 'El cuento de hadas de el abismo', 'Giovanni Zapata', 1, 0),
#  ('Sakura Alvarez', 'El castillo de la alianza', 'Khaled Watanabe', 1, 0),
#  ('Irina Santos', 'La tormenta de el mar', 'Orhan Hernandez', 1, 0),
#  ('Giovanni Hernandez', 'El refugio de el viajero', 'Alessandro Teixeira', 1, 0),
#  ('Tatjana Zapata', 'El destino de la batalla', 'Isa Santos', 1, 1),
#  ('Orhan Uchoa', 'La resurrección de la prisión', 'Rosa Vargas', 1, 1),
#  ('Mehmet Nguyen', 'El despertar de el amor', 'Chidike Yan', 1, 0),
#  ('Han Abadi', 'El secreto oscuro de la alianza', 'Qiu Urbina', 2, 2),
#  ('Pilar Zhang', 'La maldición de el sueño', 'Isa Santos', 1, 1),
#  ('Rashid Montenegro', 'La travesía de la noche', 'Tatjana Diniz', 1, 0),
#  ('Genghis Inácio', 'La odisea de el susurro', 'Samir Zambrano', 1, 0),
#  ('Irina Inácio', 'La venganza de el atardecer', 'Wan Vieira', 1, 1),
#  ('Rashid Montenegro', 'La sombra de el horizonte', 'Giovanni Zapata', 1, 0),
#  ('Omar Teixeira', 'La danza de la bruja', 'Sakura Gao', 1, 0),
#  ('Sakura Nguyen', 'El camino hacia el sol', 'Irina Sousa', 1, 0),
#  ('Jin Bianchi', 'El tesoro de la magia', 'Zara Borges', 1, 0),
#  ('Valeria Lopes', 'La escalada de la compañía', 'Yasmin Zapata', 1, 0),
#  ('Quentin Queiroz', 'El caballero de la magia', 'Patricia Watanabe', 1, 0),
#  ('Chidike Xia', 'El lamento de el puente', 'Mina Teles', 1, 0),
#  ('Omar Lima', 'La maldición del vampiro de la corrupción', 'Jasmin Teixeira', 1, 0),
#  ('Alessandro Lopez', 'La travesía sin retorno de la tormenta', 'Wan Urbina', 1, 0),
#  ('Omar Teixeira', 'La fortuna de la oscuridad', 'Elena Kawaguchi', 1, 0),
#  ('Valeria Lopes', 'La maldición de la criatura', 'Leticia Correia', 1, 0),
#  ('Bianca Olivares', 'El enigma de el guerrero', 'Khaled Carvalho', 1, 0),
#  ('Tatiana Wu', 'La trampa de la guerra', 'Emiko Figueiredo', 1, 0),
#  ('Zafar Rodriguez', 'La senda de la magia', 'Leonardo Oliveira', 1, 0),
#  ('Valeria Wu', 'La travesura de el tesoro', 'Yasmin Zapata', 1, 0),
#  ('Genghis Inácio', 'El refugio de el faro', 'Mikhail Correia', 1, 0),
#  ('Jasmin Duarte', 'El lamento de el misterio', 'Leticia Almeida', 1, 0),
#  ('Mehmet Nguyen', 'La trampa de la aldea', 'Wang Hidalgo', 1, 0),
#  ('Alessandro Carvalho', 'El laberinto de la sirena', 'Hiroko Ramos', 1, 0),
#  ('Xin Xia', 'La búsqueda del tesoro de el mago', 'Qiu Urbina', 2, 2),
#  ('Akira Santos', 'La leyenda de el sol', 'Jin Olivares', 1, 0),
#  ('Parvati Inácio', 'El eclipse de el puente', 'Xin Esteves', 1, 1),
#  ('Emiko Wu', 'La fuga de el árbol', 'Nadia Zapata', 1, 0),
#  ('Aarav Estevez', 'La búsqueda de la guerra', 'Theresa Borges', 1, 0),
#  ('Jasmin Alvarez', 'El guardián de la bailarina', 'Yusef Abadi', 1, 0),
#  ('Yasmin Figueiredo', 'El viajero de la selva', 'Isa Vieira', 1, 0),
#  ('Beatriz Zambrano', 'La travesía sin retorno de el destino', 'Ilya Yan', 1, 0),
#  ('Tatiana Quintana', 'El viaje de la compañía', 'Emiko Yan', 1, 1),
#  ('Wan Carvalho', 'La tormenta de el bosque', 'Wang Rocha', 1, 1),
#  ('Yusef Bianchi', 'El eclipse de el árbol', 'Genghis Xavier', 1, 0),
#  ('Orhan Urbina', 'La escalada de el faro', 'Parvati Zambrano', 1, 0),
#  ('Theresa Pereira', 'El guardián de el peligro', 'Xin Esteves', 1, 1),
#  ('Akira Martinez', 'El bosque encantado de la princesa', 'Sakura Santos', 1, 0),
#  ('Mina Mendes', 'La leyenda de la aventura', 'Xavier Goncalves', 1, 1),
#  ('Han Iglesias', 'El cuento de hadas de el misterio', 'Chiyoko Inácio', 1, 0),
#  ('Elena Hidalgo', 'El resurgimiento de la bestia', 'Kamala Vargas', 1, 1),
#  ('Emiko Yamamoto', 'La fortuna de la guerra', 'Isa Xia', 1, 0),
#  ('Zafar Rodriguez', 'Las aventuras de la flor', 'Lakshmi Xia', 1, 0),
#  ('Jasmin Duarte', 'El eclipse de el puente', 'Xin Esteves', 1, 1),
#  ('Xin Xia', 'La travesía del océano de el susurro', 'Wan Urbina', 1, 0),
#  ('Lakshmi Santana', 'El canto de sirena de el muro', 'Salim Montenegro', 1, 0),
#  ('Aarav Urbina', 'La estrella fugaz de el camino', 'Wang Diniz', 1, 0),
#  ('Han Barros', 'La maldición de la batalla', 'Orhan Velez', 1, 0),
#  ('Bianca Ferreira', 'Las aventuras de la pesadilla', 'Fadhila Zapata', 1, 0),
#  ('Emiko Queiroz', 'La resurrección de la prisión', 'Rosa Vargas', 1, 1),
#  ('Akira Olivares', 'La leyenda perdida de la muralla', 'Zoya Hernandez', 1, 1),
#  ('Theresa Pereira', 'La rebelión de el tesoro', 'Hiroko Xavier', 1, 0),
#  ('Jin Gao', 'El vuelo de la puerta', 'Rashid Kumar', 1, 0),
#  ('Omar Teixeira', 'La invasión de el viaje', 'Parvati Zambrano', 1, 0),
#  ('Vivek Yan', 'El secreto de el guardián', 'Fadhila Zapata', 1, 0),
#  ('Bianca Olivares', 'La metamorfosis de el amanecer', 'Valeria Hernandez', 1, 1),
#  ('Wan Carvalho', 'El canto de sirena de la caza', 'Salim Montenegro', 1, 0),
#  ('Elena Hidalgo', 'El vuelo de la traición', 'Rosa Vargas', 1, 1),
#  ('Kamala Estevez', 'El resurgimiento de la tormenta', 'Akira Borges', 1, 0),
#  ('Emiko Wu', 'La llave de el descubrimiento', 'Leticia Almeida', 1, 0),
#  ('Darya Diniz', 'El resurgimiento de la sombra', 'Isa Yan', 1, 0),
#  ('Omar Lima', 'La escalada de el faro', 'Parvati Zambrano', 1, 0),
#  ('Natalia Duarte', 'El arco iris de el puente', 'Chiyoko Lopes', 1, 1),
#  ('Jin Gao', 'La travesía de el árbol', 'Elena Kawaguchi', 1, 0),
#  ('Patricia Figueiredo', 'El canto de sirena de la traición', 'Jasmin Abadi', 1, 0),
#  ('Yasmin Olivares', 'La leyenda de la bruma', 'Natalia Dutta', 1, 0),
#  ('Umberto Nogueira', 'La tormenta de la alianza', 'Isa Watanabe', 1, 0),
#  ('Quintus Rocha', 'La senda de la magia', 'Leonardo Oliveira', 1, 0),
#  ('Chiyoko Queiroz', 'La fuga de la esperanza', 'Theresa Watanabe', 1, 0),
#  ('Ximena Olivares', 'La travesura de la flor', 'Irina Xavier', 1, 1),
#  ('Quintus Diniz', 'La odisea de la redención', 'Mikhail Pereira', 1, 0),
#  ('Elif Ramos', 'El eclipse de el sacrificio', 'Sakura Santos', 1, 0),
#  ('Quintus Diniz', 'El tesoro de el misterio', 'Jasmin Esteves', 1, 0),
#  ('Quentin Carvalho', 'El ritual de la espada', 'Qiu Henriquez', 1, 1),
#  ('Chiyoko Queiroz', 'El cuento de hadas de la resistencia', 'Genghis Montenegro', 1, 0),
#  ('Sakura Pacheco', 'La odisea de el susurro', 'Samir Zambrano', 1, 0),
#  ('Xavier Etxebarria', 'El hechizo de la esperanza', 'Zafar Carvalho', 1, 0),
#  ('Han Iglesias', 'El prisionero de la travesía', 'Mina Oliveira', 1, 0),
#  ('Yusef Bianchi', 'El cuento de hadas de el misterio', 'Chiyoko Inácio', 1, 0),
#  ('Tatjana Santana', 'La senda de el tesoro', 'Theresa Watanabe', 1, 0),
#  ('Mina Mendes', 'El guardián de la escuela', 'Qiu Oliveira', 1, 0),
#  ('Pilar Olivares', 'La estrella fugaz de la magia', 'Tatjana Diniz', 1, 0),
#  ('Han Iglesias', 'La rebelión de la cueva', 'Mina Teles', 1, 0),
#  ('Bianca Sousa', 'La fortuna de el puente', 'Oscar Oliveira', 1, 0),
#  ('Gustavo Yilmaz', 'La travesura de el muro', 'Sakura Almeida', 1, 0),
#  ('Tatjana Santana', 'La estrella fugaz de el camino', 'Wang Diniz', 1, 0),
#  ('Chiyoko Queiroz', 'La leyenda perdida de el sacrificio', 'Isa Vieira', 1, 0),
#  ('Elena Hidalgo', 'La travesura de la flor', 'Irina Xavier', 1, 1),
#  ('Samir Ferreira', 'La odisea de el mar', 'Theresa Yamamoto', 1, 0),
#  ('Ximena Olivares', 'La metamorfosis de el encuentro', 'Qiu Oliveira', 1, 0),
#  ('Akira Martinez', 'El canto de sirena de la heroína', 'Hiroko Xavier', 1, 0),
#  ('Omar Lima', 'La maldición de la criatura', 'Leticia Correia', 1, 0),
#  ('Giovanni Hernandez', 'El ritual de la aventura', 'Abdullah Ivanov', 1, 0),
#  ('Salim Teixeira', 'El viajero de el hechizo', 'Yuri Dutta', 1, 0),
#  ('Quintus Dutta', 'La conquista de el peligro', 'Xin Ferreira', 1, 0),
#  ('Patricia Abadi', 'El pacto de el guardián', 'Rania Bianchi', 1, 0),
#  ('Abdullah Jimenez', 'La búsqueda del tesoro de la bruja', 'Mina Gao', 1, 0),
#  ('Bianca Henriquez', 'La danza de la isla', 'Fadhila Kawaguchi', 1, 0),
#  ('Darya Pereira', 'La estrella fugaz de la senda', 'Salim Montenegro', 1, 0),
#  ('Valeria Lopes', 'El secreto oscuro de el dragón', 'Wan Urbina', 1, 0),
#  ('Wang Zhang', 'La trampa de el amanecer', 'Orhan Velez', 1, 0),
#  ('Javier Fernandes', 'El canto de sirena de el amor', 'Jin Olivares', 1, 0),
#  ('Rashid Olivares', 'La metamorfosis de la bruja', 'Hiroko Queiroz', 1, 0),
#  ('Rashid Mendes', 'La canción de la bestia', 'Mehmet Nguyen', 1, 0),
#  ('Valeria Henriquez', 'El castillo de la alianza', 'Khaled Watanabe', 1, 0),
#  ('Aarav Estevez', 'El último viaje de la tormenta', 'Han Mendes', 1, 0),
#  ('Jin Bianchi', 'El caballero de la magia', 'Patricia Watanabe', 1, 0),
#  ('Han Barros', 'El secreto de el guardián', 'Fadhila Zapata', 1, 0),
#  ('Darius Yilmaz', 'El espejismo de la criatura', 'Oscar Xavier', 1, 0),
#  ('Natalia Martinez', 'El prisionero de el guerrero', 'Akira Borges', 1, 0),
#  ('Oscar Martinez', 'La llegada de la pasión', 'Irina Sousa', 1, 0),
#  ('Chiyoko Queiroz', 'El resurgimiento de la ciudad', 'Theresa Borges', 1, 0),
#  ('Akira Olivares', 'El cuento de hadas de el abismo', 'Giovanni Zapata', 1, 0),
#  ('Rania Gao', 'La fuente de la oscuridad', 'Theresa Borges', 1, 0),
#  ('Alessandro Carvalho', 'La trampa de la guerra', 'Emiko Figueiredo', 1, 0),
#  ('Yasmin Olivares', 'La misión de la guerra', 'Orhan Hernandez', 1, 0),
#  ('Mikhail Montenegro', 'El príncipe de la criatura', 'Oscar Zapata', 1, 0),
#  ('Qiu Correia', 'El tesoro escondido de la desgracia', 'Fatemeh Janssen', 1, 0),
#  ('Jasmin Alvarez', 'El prisionero de la travesía', 'Mina Oliveira', 1, 0),
#  ('Kamala Estevez', 'El canto de sirena de el muro', 'Salim Montenegro', 1, 0),
#  ('Wang Yan', 'El camino hacia la aldea', 'Rania Martinez', 1, 0),
#  ('Jin Teixeira', 'La leyenda de el sol', 'Jin Olivares', 1, 0),
#  ('Jasmin Alvarez', 'La fuga de la aventura', 'Xin Esteves', 1, 0),
#  ('Emiko Queiroz', 'El prisionero de el hechicero', 'Abdullah Uchoa', 1, 0),
#  ('Yuri Urbina', 'El lamento de el puente', 'Mina Teles', 1, 0),
#  ('Oscar Joaquim', 'La sombra de el horizonte', 'Giovanni Zapata', 1, 0),
#  ('Rania Gao', 'La travesura de el muro', 'Sakura Almeida', 1, 0),
#  ('Omar Lima', 'El destino de la pesadilla', 'Rosa Vargas', 1, 1),
#  ('Akira Urbina', 'La sombra de el horizonte', 'Giovanni Zapata', 1, 0),
#  ('Genghis Inácio', 'La fuga de la esperanza', 'Theresa Watanabe', 1, 0),
#  ('Tatjana Qian', 'La búsqueda del tesoro de la batalla', 'Valentina Esteves', 1, 1),
#  ('Patricia Inácio', 'El canto de sirena de la redención', 'Kamala Vargas', 1, 1),
#  ('Jin Mendes', 'El último viaje de la tormenta', 'Han Mendes', 1, 0),
#  ('Pilar Rodriguez', 'El eclipse de el puente', 'Xin Esteves', 1, 1),
#  ('Emiko Yamamoto', 'El grito de la esperanza', 'Dmitri Uchoa', 1, 0),
#  ('Samir Ferreira', 'El destino de el caos', 'Zara Ivanov', 1, 0),
#  ('Chen Abadi', 'La conquista de el peligro', 'Xin Ferreira', 1, 0),
#  ('Genghis Mendes', 'El eclipse de el puente', 'Xin Esteves', 1, 1),
#  ('Darius Mendes', 'El prisionero de el guerrero', 'Akira Borges', 1, 0),
#  ('Oscar Joaquim', 'La cripta de la montaña', 'Parvati Martinez', 1, 1),
#  ('Beatriz Estevez', 'El prisionero de el guerrero', 'Akira Borges', 1, 0),
#  ('Jin Bianchi', 'El destino de la batalla', 'Isa Santos', 1, 1),
#  ('Yasmin Figueiredo', 'El resurgimiento de la espada mágica', 'Fatemeh Nunes', 1, 0),
#  ('Ximena Olivares', 'La redención de el laberinto', 'Quentin Ramos', 1, 0),
#  ('Darya Pereira', 'La maldición del vampiro de la cascada', 'Sakura Gao', 1, 0),
#  ('Leonardo Iglesias', 'La leyenda de la bruma', 'Natalia Dutta', 1, 0),
#  ('Patricia Figueiredo', 'El destino de la pesadilla', 'Rosa Vargas', 1, 1),
#  ('Mikhail Montenegro', 'La trampa de el puente', 'Bianca Vieira', 1, 0),
#  ('Emiko Yamamoto', 'La maldición de la guerra', 'Wang Diniz', 1, 0),
#  ('Han Barros', 'La llave de el descubrimiento', 'Leticia Almeida', 1, 0),
#  ('Chiyoko Vargas', 'El castillo de la perdición', 'Aarav Qian', 1, 0),
#  ('Tatjana Santana', 'El secreto de la aventura', 'Parvati Vargas', 1, 0),
#  ('Wan Gomes', 'Las aventuras de la flor', 'Lakshmi Xia', 1, 0),
#  ('Wang Yan', 'La búsqueda del tesoro de el mago', 'Qiu Urbina', 2, 2),
#  ('Aarav Estevez', 'La llave de la sirena', 'Wilhelmina Montenegro', 1, 0),
#  ('Giovanni Alvarez', 'La venganza de la ola', 'Qiu Urbina', 2, 2),
#  ('Xin Barros', 'La metamorfosis de el amanecer', 'Valeria Hernandez', 1, 1),
#  ('Omar Lima', 'La estrella fugaz de la profecía', 'Wang Queiroz', 1, 0),
#  ('Emiko Uchoa', 'La estrella fugaz de el camino', 'Wang Diniz', 1, 0),
#  ('Giovanni Duarte', 'El refugio de el viajero', 'Alessandro Teixeira', 1, 0),
#  ('Elena Fernandes', 'El refugio de la promesa', 'Pilar Uchoa', 1, 0),
#  ('Patricia Bianchi', 'La tormenta de el bosque', 'Wang Rocha', 1, 1),
#  ('Tatjana Abadi', 'El vuelo de la traición', 'Rosa Vargas', 1, 1),
#  ('Wan Carvalho', 'La canción de la gárgola', 'Bianca Diniz', 2, 2),
#  ('Han Barros', 'La danza de el desafío', 'Quentin Esteves', 1, 1),
#  ('Yasmin Olivares', 'La maldición de la criatura', 'Leticia Correia', 1, 0),
#  ('Wang Yan', 'El arco iris de el faro', 'Wang Rocha', 1, 1),
#  ('Khaled Yilmaz', 'La conquista de el peligro', 'Xin Ferreira', 1, 0),
#  ('Mehmet Sousa', 'El canto de sirena de la traición', 'Jasmin Abadi', 1, 0),
#  ('Quintus Lopes', 'La metamorfosis de el amanecer', 'Valeria Hernandez', 1, 1),
#  ('Emiko Queiroz', 'El tesoro escondido de el león', 'Aarav Quintana', 1, 0),
#  ('Ilya Zhang', 'La fortuna de la ley', 'Chiyoko Lopes', 1, 1),
#  ('Tatiana Quintana', 'El regreso de la luz', 'Rania Esteves', 1, 0),
#  ('Leticia Urbina', 'El canto de sirena de el amor', 'Jin Olivares', 1, 0),
#  ('Emiko Uchoa', 'El misterio de el caos', 'Fadhila Zapata', 1, 0),
#  ('Wang Yan', 'La travesura de la heroína', 'Han Xavier', 1, 0),
#  ('Leticia Xu', 'La fuga de la aventura', 'Xin Esteves', 1, 0),
#  ('Jasmin Lopez', 'La fuente de el valle', 'Dmitri Uchoa', 1, 0),
#  ('Gustavo Urbina', 'El lamento de el puente', 'Mina Teles', 1, 0),
#  ('Nadia Yamamoto', 'La tormenta de el bosque', 'Wang Rocha', 1, 1),
#  ('Han Iglesias', 'El refugio de el faro', 'Mikhail Correia', 1, 0),
#  ('Quentin Carvalho', 'La estrella fugaz de la prisión', 'Wang Rocha', 1, 1),
#  ('Pilar Ivanov', 'El amanecer de la oscuridad', 'Alessandro Janssen', 1, 0),
#  ('Irina Santos', 'La búsqueda del tesoro de el mago', 'Qiu Urbina', 2, 2),
#  ('Rashid Mendes', 'La senda de el rey', 'Zafar Carvalho', 1, 0),
#  ('Beatriz Zambrano', 'La rebelión de la cueva', 'Mina Teles', 1, 0),
#  ('Parvati Inácio', 'El vuelo mágico de el lamento', 'Rosa Vargas', 1, 1),
#  ('Xin Joaquim', 'La sombra de el vuelo', 'Aarav Quintana', 1, 0),
#  ('Valentina Figueiredo', 'La maldición del vampiro de la espada mágica', 'Fadhila Kawaguchi', 1, 0),
#  ('Quintus Dutta', 'La llegada de la estrella', 'Chiyoko Inácio', 1, 0),
#  ('Zafar Rodriguez', 'La metamorfosis de el rincón', 'Fadhila Abadi', 1, 1),
#  ('Darya Alvarez', 'El último viaje de la magia', 'Wang Queiroz', 1, 0),
#  ('Fabiana Urbina', 'La senda de el rey', 'Zafar Carvalho', 1, 0),
#  ('Akira Figueiredo', 'El refugio de el viajero', 'Alessandro Teixeira', 1, 0),
#  ('Natalia Martinez', 'La doncella de el sueño', 'Leticia Correia', 1, 0),
#  ('Lakshmi Santana', 'La estrella fugaz de la profecía', 'Wang Queiroz', 1, 0),
#  ('Gustavo Janssen', 'La trampa de la guerra', 'Wang Diniz', 1, 0),
#  ('Patricia Abadi', 'El amanecer de el jardín', 'Kamala Vargas', 1, 1),
#  ('Patricia Abadi', 'El tesoro escondido de el valle', 'Yasmin Joaquim', 1, 1),
#  ('Elena Hidalgo', 'El cuento de hadas de el viajero', 'Han Mendes', 1, 0),
#  ('Fabiana Urbina', 'El enigma de el encuentro', 'Chiyoko Lopes', 1, 1),
#  ('Pilar Ivanov', 'La leyenda perdida de el sacrificio', 'Isa Vieira', 1, 0),
#  ('Orhan Uchoa', 'El resurgimiento de la tormenta', 'Akira Borges', 1, 0),
#  ('Darya Alvarez', 'El lamento de el renacimiento', 'Fadhila Kawaguchi', 1, 0),
#  ('Natalia Duarte', 'La búsqueda del tesoro de la batalla', 'Valentina Esteves', 1, 1),
#  ('Jasmin Alvarez', 'El ritual de el dragón', 'Hiroko Queiroz', 1, 0),
#  ('Chiyoko Queiroz', 'La travesía de la prisión', 'Orhan Cruz', 1, 0),
#  ('Fabiana Estevez', 'El destino de la pesadilla', 'Rosa Vargas', 1, 1),
#  ('Yusef Esteves', 'La senda de la magia', 'Leonardo Oliveira', 1, 0),
#  ('Tatjana Zapata', 'El resurgimiento de la bestia', 'Kamala Vargas', 1, 1),
#  ('Mehmet Nguyen', 'La fortuna de el puente', 'Oscar Oliveira', 1, 0),
#  ('Jin Mendes', 'Las aventuras de la pesadilla', 'Fadhila Zapata', 1, 0),
#  ('Aarav Urbina', 'El canto de sirena de la heroína', 'Hiroko Xavier', 1, 0),
#  ('Valentina Nogueira', 'El canto de sirena de el muro', 'Salim Montenegro', 1, 0),
#  ('Wang Yan', 'El ritual de la fortuna', 'Emiko Yan', 1, 1),
#  ('Tatjana Sousa', 'El canto de sirena de la traición', 'Jasmin Abadi', 1, 0),
#  ('Wan Carvalho', 'El guardián de la escuela', 'Qiu Oliveira', 1, 0),
#  ('Ximena Xu', 'El guardián de el peligro', 'Xin Esteves', 1, 1),
#  ('Irina Santos', 'La leyenda de la aventura', 'Xavier Goncalves', 1, 1),
#  ('Lakshmi Santana', 'La llave de la bienvenida', 'Nadia Diniz', 1, 0),
#  ('Akira Urbina', 'La maldición de la criatura', 'Leticia Correia', 1, 0),
#  ('Rashid Olivares', 'El laberinto de la sirena', 'Hiroko Ramos', 1, 0),
#  ('Pilar Yan', 'La metamorfosis de el amanecer', 'Valeria Hernandez', 1, 1),
#  ('Gustavo Urbina', 'La venganza de la sonrisa', 'Beatriz Montenegro', 1, 0),
#  ('Theresa Pereira', 'El cuento de hadas de la resistencia', 'Genghis Montenegro', 1, 0),
#  ('Darius Mendes', 'La venganza de el amor', 'Abdullah Abadi', 1, 0),
#  ('Mehmet Goncalves', 'La travesura de la flor', 'Irina Xavier', 1, 1),
#  ('Bianca Henriquez', 'La rebelión de la bienvenida', 'Valeria Hernandez', 1, 1),
#  ('Han Barros', 'La llave de el unicornio', 'Khaled Watanabe', 1, 0),
#  ('Jin Bianchi', 'El secreto oscuro de la estrella', 'Yusef Nogueira', 1, 1),
#  ('Akira Inácio', 'La senda de el tesoro', 'Theresa Watanabe', 1, 0),
#  ('Xin Barros', 'La metamorfosis de el guerrero', 'Quentin Esteves', 1, 1),
#  ('Pilar Ivanov', 'La invasión de la cascada', 'Yusef Yilmaz', 3, 3),
#  ('Gustavo Janssen', 'La venganza de el atardecer', 'Wan Vieira', 1, 1),
#  ('Elif Hernandez', 'El lamento de el renacimiento', 'Fadhila Kawaguchi', 1, 0),
#  ('Umberto Nogueira', 'La rebelión de el tesoro', 'Hiroko Xavier', 1, 0),
#  ('Ilya Zhang', 'El camino hacia la aldea', 'Rania Martinez', 1, 0),
#  ('Jasmin Lopez', 'La estrella fugaz de el camino', 'Wang Diniz', 1, 0),
#  ('Valeria Wu', 'La fuga de la aventura', 'Xin Esteves', 1, 0),
#  ('Omar Ivanov', 'La profecía de el jardín', 'Irina Sousa', 1, 0),
#  ('Giovanni Alvarez', 'El último viaje de la tormenta', 'Han Mendes', 1, 0),
#  ('Jin Alvarez', 'La búsqueda de la guerra', 'Theresa Borges', 1, 0),
#  ('Chiyoko Nunes', 'La estirpe de el misterio', 'Wan Alvarez', 1, 0),
#  ('Mikhail Borges', 'El secreto oscuro de la perdición', 'Wan Urbina', 1, 0),
#  ('Han Abadi', 'La leyenda de la luz', 'Qiu Urbina', 2, 2),
#  ('Bianca Henriquez', 'La profecía de el jardín', 'Irina Sousa', 1, 0),
#  ('Oscar Joaquim', 'La llegada de la senda', 'Wan Vieira', 1, 1),
#  ('Giovanni Alvarez', 'La canción de el sol', 'Alessandro Urbina', 1, 0),
#  ('Valeria Henriquez', 'La llegada de la senda', 'Wan Vieira', 1, 1),
#  ('Mina Wu', 'El resurgimiento de la espada mágica', 'Fatemeh Nunes', 1, 0),
#  ('Akira Santos', 'El ritual de la fortuna', 'Emiko Yan', 1, 1),
#  ('Leticia Urbina', 'La estirpe de el misterio', 'Wan Alvarez', 1, 0),
#  ('Samir Ferreira', 'El destino de el sapo', 'Isa Xia', 1, 0),
#  ('Pilar Rodriguez', 'La trampa de la guerra', 'Wang Diniz', 1, 0),
#  ('Tatiana Wu', 'El príncipe de la criatura', 'Oscar Zapata', 1, 0),
#  ('Elif Ramos', 'La sombra de el vuelo', 'Aarav Quintana', 1, 0),
#  ('Quintus Lopes', 'El secreto oscuro de la alianza', 'Qiu Urbina', 2, 2),
#  ('Oscar Joaquim', 'El prisionero de el hechicero', 'Abdullah Uchoa', 1, 0),
#  ('Fabiana Estevez', 'El guardián de el peligro', 'Xin Esteves', 1, 1),
#  ('Alessandro Lopez', 'La metamorfosis de el encuentro', 'Qiu Oliveira', 1, 0),
#  ('Qiu Correia', 'El despertar de el abismo', 'Valentina Esteves', 1, 1),
#  ('Akira Olivares', 'El guardián de la bruja', 'Salim Montenegro', 1, 0),
#  ('Darius Yilmaz', 'El lamento de el puente', 'Mina Teles', 1, 0),
#  ('Oscar Martinez', 'La danza de la isla', 'Fadhila Kawaguchi', 1, 0),
#  ('Omar Lima', 'El lamento de el puente', 'Mina Teles', 1, 0),
#  ('Qiu Correia', 'La invasión de el viaje', 'Parvati Zambrano', 1, 0),
#  ('Giovanni Duarte', 'El caballero de la magia', 'Patricia Watanabe', 1, 0),
#  ('Patricia Inácio', 'La fuga de la esperanza', 'Theresa Watanabe', 1, 0),
#  ('Elif Queiroz', 'La invasión de la cascada', 'Yusef Yilmaz', 3, 3),
#  ('Han Iglesias', 'La doncella de el sueño', 'Qiu Ferreira', 1, 0),
#  ('Darya Gao', 'La travesía de el árbol', 'Elena Kawaguchi', 1, 0),
#  ('Natalia Olivares', 'El resurgimiento de la espada mágica', 'Fatemeh Nunes', 1, 0),
#  ('Emiko Yamamoto', 'El secreto oscuro de el laberinto', 'Tatjana Figueiredo', 1, 0),
#  ('Alessandro Diniz', 'El bosque encantado de el descubrimiento', 'Yusef Nogueira', 1, 1),
#  ('Akira Martinez', 'El guardián de la escuela', 'Qiu Oliveira', 1, 0),
#  ('Xin Xia', 'El misterio de la profecía', 'Nina Sousa', 1, 0),
#  ('Patricia Abadi', 'La metamorfosis de el amanecer', 'Valeria Hernandez', 1, 1),
#  ('Tatjana Santana', 'El guardián de la bruja', 'Salim Montenegro', 1, 0),
#  ('Leonardo Iglesias', 'La canción de la gárgola', 'Bianca Diniz', 2, 2)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
